# %%
import pickle

# %%
filename = "terrain_img.pickle"
f = open(f'./{filename}', 'rb')
loaded_minimaps = pickle.load(f)
f.close()
import matplotlib.pyplot as plt
import cv2
plt.imshow(loaded_minimaps)
cv2.imwrite("./img.jpg", loaded_minimaps)
# Out:
# True

# %%
# Out:
# True
