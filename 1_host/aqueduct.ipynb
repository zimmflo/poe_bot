# %%
import time
import random
import sys
from ast import literal_eval

from utils.gamehelper import PoeBot
from utils.controller import VMHostPuppeteer
from utils.mover import Mover
from utils.loot_filter import CustomLootFilter

# %%
time_now = 0
notebook_dev = False
# readability
poe_bot: PoeBot
bot_controls:VMHostPuppeteer
mover: Mover

# %%
default_config = {
  "REMOTE_IP": '172.28.180.101', # z2
  "unique_id": "incorrect",
  "build": "EaBallistasEle",
  "password": None,
  "max_lvl": 101,
  "chromatics_recipe": True,
  "force_reset_temp": False,
}



try:
  i = sys.argv[1]
  print(i)
  parsed_config = literal_eval(i)
  print(f'successfully parsed cli config')
  print(f'parsed_config: {parsed_config}')
except:
  print(f'cannot parse config from cli, using default\dev one')
  notebook_dev = True
  parsed_config = default_config
  parsed_config['unique_id'] = PoeBot.getDevKey()

config = {

}

for key in default_config.keys():
  config[key] = parsed_config.get(key, default_config[key])

print(f'config to run {config}')
# Out:
# --f=c:\Users\1\AppData\Roaming\jupyter\runtime\kernel-v2-17592AtMqAaTxCPn0.json
# cannot parse config from cli, using default\dev one
# config to run {'REMOTE_IP': '172.28.180.101', 'UNIQUE_ID': '7d1165934e24534a1ba5', 'build': 'EaBallistasEle', 'password': None, 'max_lvl': 101, 'chromatics_recipe': True, 'force_reset_temp': False}

# %%
REMOTE_IP = config['REMOTE_IP'] # REMOTE_IP
UNIQUE_ID = config['unique_id'] # unique id
MAX_LVL = config.get('max_lvl')
CHROMATICS_RECIPE = config['chromatics_recipe']
BUILD_NAME = config['build'] # build_name
password = config['password']
force_reset_temp = config['force_reset_temp']
print(f'running aqueduct using: REMOTE_IP: {REMOTE_IP} unique_id: {UNIQUE_ID} max_lvl: {MAX_LVL} chromatics_recipe: {CHROMATICS_RECIPE} force_reset_temp: {force_reset_temp}')
# Out:
# running aqueduct using: REMOTE_IP: 172.28.180.101 unique_id: 7d1165934e24534a1ba5 max_lvl: 101 chromatics_recipe: True force_reset_temp: False

# %%
poe_bot = PoeBot(unique_id = UNIQUE_ID, remote_ip = REMOTE_IP, password=password)
bot_controls = poe_bot.bot_controls
mover = poe_bot.mover
poe_bot.refreshAll()
poe_bot.combat_module.assignBuild(BUILD_NAME)
# Out:
# [temp] loaded from file StashTempData
# [temp] loaded from file AfkTempData
# build is not assigned, using any functions may throw errors
# [key checker] 7d1165934e24534a1ba5 has 25562568 seconds left
# poe bot, v: 3.25.7 init at 1725438706.1970913

# %%
class AqueductSettings:
  rares_detection_radius = 50
  blues_detection_radius = 50
class Aqueduct:
  look_for_objects_orig = ["Waypoint", "Highgate"]
  look_for_objects = ["Waypoint", "Highgate"]
  def __init__(self, poe_bot:PoeBot) -> None:
    self.poe_bot = poe_bot
  def run(self):
    self.poe_bot.on_death_function = self.onDeathFunction
    if poe_bot.game_data.area_raw_name == "2_9_town":
      inventory = poe_bot.ui.inventory
      stashed = False
      inventory.update()
      filled_slots_count = len(inventory.getFilledSlots())
      if filled_slots_count > 30:
        stash_box = next((e for e in poe_bot.game_data.entities.all_entities if "Stash" in e.path), None)
        if stash_box is None:
          poe_bot.raiseLongSleepException('stashbox is not found in highgate')
        mover.goToEntitysPoint(stash_box, release_mouse_on_end=True)
        stash = poe_bot.ui.stash
        stash.open()
        inventory.update()
        stash.placeItemsAcrossStash(inventory.items)
      poe_bot.ui.closeAll()

      aqueduct_transition = next((e for e in poe_bot.game_data.entities.all_entities if e.render_name == "The Blood Aqueduct"), None)



      if aqueduct_transition.distance_to_player > 40:
        mover.goToEntitysPoint(aqueduct_transition, release_mouse_on_end=True)

      for i in range(random.randint(5,10)):
        poe_bot.helper_functions.lvlUpGem()

      time.sleep(random.randint(20,40)/10)
      poe_bot.refreshInstanceData()
      aqueduct_transition = next((e for e in poe_bot.game_data.entities.all_entities if e.render_name == "The Blood Aqueduct"), None)

      # ctrl + click 196 365
      bot_controls.keyboard_pressKey('DIK_LCONTROL')
      pos_x,pos_y = poe_bot.convertPosXY(aqueduct_transition.location_on_screen.x,aqueduct_transition.location_on_screen.y)
      print(pos_x,pos_y)
      poe_bot.bot_controls.mouse.setPosSmooth(int(pos_x),int(pos_y))
      time.sleep(0.2)
      poe_bot.bot_controls.mouseClick(int(pos_x),int(pos_y))
      time.sleep(0.8)
      # release ctrl
      bot_controls.keyboard_releaseKey('DIK_LCONTROL')
      time.sleep(3) # till window is loaded

      # click new instance 165 240
      pos_x,pos_y = poe_bot.convertPosXY(165,240)
      print(pos_x,pos_y)
      poe_bot.bot_controls.mouse.setPosSmooth(int(pos_x),int(pos_y))
      time.sleep(0.2)
      poe_bot.bot_controls.mouseClick(int(pos_x),int(pos_y))
      time.sleep(0.8)
      time.sleep(5)
      raise 404
    elif poe_bot.game_data.area_raw_name == "2_9_1":
      poe_bot.combat_module.build.doPreparations()
    else:
      poe_bot.raiseLongSleepException('bring me to aqueduct or highgate')
  def aqueductFinishFunction(self):
    target = list(filter(lambda e: e.render_name in self.look_for_objects, poe_bot.game_data.entities.all_entities))
    if target:
      return True
  def resetInstance(self):
    targets = list(filter(lambda e: e.render_name in self.look_for_objects_orig, poe_bot.game_data.entities.all_entities))
    target = targets[0]
    if target.render_name == "Highgate":
      mover.goToEntitysPoint(target)
      target.clickTillNotTargetable()
    if target.render_name == "Waypoint":
      mover.goToEntitysPoint(target, release_mouse_on_end=True)
      for i in range(random.randint(5,10)):
        poe_bot.helper_functions.lvlUpGem()
      target.openWaypoint()
      # part 2 280 82
      pos_x,pos_y = poe_bot.convertPosXY(240,82)
      print(f"clicking part2 {pos_x,pos_y}")
      poe_bot.bot_controls.mouse.setPosSmooth(int(pos_x),int(pos_y))
      time.sleep(0.2)
      poe_bot.bot_controls.mouseClick(int(pos_x),int(pos_y))
      time.sleep(0.8)


      quest_flags = poe_bot.backend.getQuestFlags()
      a9_boss_killed = quest_flags.get("A9Q1KilledBoss", False)
      print(f"a9_boss_killed {a9_boss_killed}")
      if a9_boss_killed is True:
        # act 9 285 105 if act10 town is opened
        pos_x,pos_y = poe_bot.convertPosXY(285,105)
      else:
        # act 9 319 105 if act10 town is closed
        pos_x,pos_y = poe_bot.convertPosXY(319,105)

      print(f"clicking a9 {pos_x,pos_y}")
      poe_bot.bot_controls.mouse.setPosSmooth(int(pos_x),int(pos_y))
      time.sleep(0.2)
      poe_bot.bot_controls.mouseClick(int(pos_x),int(pos_y))
      time.sleep(0.8)

      # ctrl + click 196 365
      bot_controls.keyboard_pressKey('DIK_LCONTROL')
      pos_x,pos_y = poe_bot.convertPosXY(196,365)
      print(pos_x,pos_y)
      poe_bot.bot_controls.mouse.setPosSmooth(int(pos_x),int(pos_y))
      time.sleep(0.2)
      poe_bot.bot_controls.mouseClick(int(pos_x),int(pos_y))
      time.sleep(0.8)
      # release ctrl
      bot_controls.keyboard_releaseKey('DIK_LCONTROL')
      time.sleep(3) # till window is loaded

      # click new instance 165 240
      pos_x,pos_y = poe_bot.convertPosXY(165,240)
      print(pos_x,pos_y)
      poe_bot.bot_controls.mouse.setPosSmooth(int(pos_x),int(pos_y))
      time.sleep(0.2)
      poe_bot.bot_controls.mouseClick(int(pos_x),int(pos_y))
      time.sleep(0.8)

      waypoint_grid_pos_sum = target.grid_position.x + target.grid_position.y
      time.sleep(5)
      poe_bot.refreshInstanceData()
      # supposed to throw error that loc has changed
      targets = list(filter(lambda e: e.render_name in self.look_for_objects, poe_bot.game_data.entities.all_entities))
      target = targets[0]
      new_waypoint_grid_pos_sum = target.grid_position.x + target.grid_position.y
      # if waypoint_grid_pos_sum == new_waypoint_grid_pos_sum:
      #   poe_bot.raiseLongSleepException('couldnt create new area')
  def onDeathFunction(self):
    poe_bot.resurrectAtCheckpoint()
    poe_bot.refreshInstanceData()
    self.resetInstance()
    raise Exception('died resetting')

# %%
aqueduct_module = Aqueduct(poe_bot=poe_bot)
aqueduct_module.run()
# Out:
# portal_gem_in_skills False
# weapons swapped
# damage_over_time_aura is blessing
# damage_over_time_aura is blessing
# aura_accuracy_and_crits already activated
# need to activate haste
# grace already activated
# purity already activated
# total need to activate ['haste']
# indexes to activate [1]
# keys to activate ['middle']

# %%
poe_bot.mover.default_continue_function = poe_bot.combat_module.build.usualRoutine
aqueduct_loot_filter = CustomLootFilter(collect_links=None,collect_small_rgb=CHROMATICS_RECIPE)
poe_bot.loot_picker.loot_filter.special_rules = [aqueduct_loot_filter.isItemPickable]

# %%
rares_detection_radius = 50
blues_detection_radius = 50
look_for_objects_orig = ["Waypoint", "Highgate"]
look_for_objects = ["Waypoint", "Highgate"]

waypoints_or_transitions = list(filter(lambda e: e.render_name == "Waypoint" or e.render_name == "Highgate", poe_bot.game_data.entities.all_entities))
for entity in waypoints_or_transitions:
  entity_index = look_for_objects.index(entity.render_name)
  look_for_objects.pop(entity_index)

if len(look_for_objects) == 0:
  poe_bot.raiseLongSleepException("len(look_for_objects) == 0")

# %%
def aqueductFinishFunction():
  target = list(filter(lambda e: e.render_name in look_for_objects, poe_bot.game_data.entities.all_entities))
  if target:
    return True
def aqueductRunRoutine(self, mover=None):
  '''
  if function returns something other than bool:False, itll regenerate it's path
  '''
  if rares_detection_radius != 0:
    rares_nearby = list(filter(lambda e: e.distance_to_player < rares_detection_radius, poe_bot.game_data.entities.attackable_entities_rares))
    for rare_mob in rares_nearby:
      updated_entity = list(filter(lambda e: e.id == rare_mob.id, poe_bot.game_data.entities.attackable_entities_rares))
      if len(updated_entity) != 0:
        updated_entity = updated_entity[0]
        poe_bot.combat_module.killUsualEntity(updated_entity)
        return True

  if blues_detection_radius != 0:
    rares_nearby = list(filter(lambda e: e.distance_to_player < blues_detection_radius, poe_bot.game_data.entities.attackable_entities_blue))
    for blue_mob in rares_nearby:
      updated_entity = list(filter(lambda e: e.id == blue_mob.id, poe_bot.game_data.entities.attackable_entities_blue))
      if len(updated_entity) != 0:
        updated_entity = updated_entity[0]
        poe_bot.combat_module.killUsualEntity(updated_entity)
        return True
      
  loot_collected = poe_bot.loot_picker.collectLoot()
  if loot_collected is True:
    return loot_collected
  #   if len(inventory.getFilledSlots()) > 51:
  #     self.can_pick_drop = False
  #   else:
  #     self.can_pick_drop = True
  if aqueductFinishFunction() is True:
    return True
  return False

# %%
from utils.pathing import TSP

mover_custom_break_function = aqueductRunRoutine
explorer_break_function = aqueductFinishFunction

tsp = TSP(poe_bot=poe_bot)
# tsp.generatePointsForDiscovery()
mover = poe_bot.mover
map_complete = False
while map_complete is False:
  poe_bot.refreshInstanceData()
  print(f'generating pathing points')
  discovery_points = tsp.generateSortedPointsForBossRush()
  print(f'len(discovery_points) {len(discovery_points)}')
  discovery_points = list(filter(lambda p: poe_bot.helper_functions.checkIfEntityOnCurrenctlyPassableArea(p[0], p[1]), discovery_points))
  print(f'len(discovery_points) {len(discovery_points)} after sorting')
  if len(discovery_points) == 0:
    print(f'len(discovery_points) == 0 after points generation')
    map_complete = True
    break
  point_to_go = discovery_points.pop(0)
  while point_to_go is not None:
    need_to_explore = True
    if need_to_explore is True:
      print(f'exploring point {point_to_go}')
    else:
      print(f'surrounding around {point_to_go} discovered, skipping')
      try:
        point_to_go = discovery_points.pop(0)
      except:
        point_to_go = None
      continue

    # go to point to make it explored
    result = mover.goToPoint(
      point=point_to_go,
      min_distance=50,
      release_mouse_on_end=False,
      custom_break_function=mover_custom_break_function,
      step_size=random.randint(30,35)
    )
    # then, it result is True, False or None
    print(f"mover.goToPoint result {result}")


    # if we arrived to discovery point and nothing happened
    if result is None:
      while True:
        if len(discovery_points) == 0:
          point_to_go = None
          map_complete = True
          print(f'len(discovery_points) == 0, breaking')
          break

        point_to_go = discovery_points.pop(0)
        print(f'willing to explore next point {point_to_go}')
        need_to_explore = poe_bot.helper_functions.needToExplore(point_to_go=point_to_go)

        if need_to_explore is True:
          print(f'exploring point {point_to_go}')
          break
        else:
          print(f'surrounding around {point_to_go} discovered, skipping')
          continue
    
    if explorer_break_function() is True:
      map_complete = True
      break

    poe_bot.refreshInstanceData()
    poe_bot.last_action_time = 0
  # if possible_transition to explore, go to it, run discovery again
# Out:
# generating pathing points
# len(discovery_points) 7
# len(discovery_points) 7 after sorting
# exploring point (410, 4091)
# #goToPoint point: (410, 4091), min_distance: 50, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: True, random_val: 1
# custom_break_function:<function aqueductRunRoutine at 0x000001E6283E4CA0>, custom_continue_function:None
# heist_transition: False, step_size: 35possible_transition: False
# #LootPicker.collectLoot call at 1721298028.667378
# end pos to go 411 4090
# mover.distance_to_target: 3646.315949009356
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298028.7693772
# making step to (787, 656)
# making first step, placing a mouse on (787, 656) and going
# mover.distance_to_target: 3646.315949009356
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298028.9703798
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# player_aura_damage_over_time is not in buff list, forcing to cast it
# using damage_over_time_aura at 1721298028.9833825
# successfully used damage_over_time_aura at 1721298029.230373
# nearby_enemies_on_screen: []
# distance_to_next_step 58.0
# using flame_dash at 1721298029.2313788
# successfully used flame_dash at 1721298029.314372
# mover.distance_to_target: 3643.3162091698823
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298031.6942677
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: []
# distance_to_next_step 58.0
# using flame_dash at 1721298031.7169325
# successfully used flame_dash at 1721298031.7938628
# mover.distance_to_target: 3498.6415935331247
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298031.8214028
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E6291FC040>, <utils.gamehelper.Entity object at 0x000001E6291FCAF0>, <utils.gamehelper.Entity object at 0x000001E6291FCE20>, <utils.gamehelper.Entity object at 0x000001E6284C0220>, <utils.gamehelper.Entity object at 0x000001E6284C04F0>, <utils.gamehelper.Entity object at 0x000001E6284C07C0>, <utils.gamehelper.Entity object at 0x000001E6284C0D60>, <utils.gamehelper.Entity object at 0x000001E6284BE070>, <utils.gamehelper.Entity object at 0x000001E6284BE340>, <utils.gamehelper.Entity object at 0x000001E6284BE610>, <utils.gamehelper.Entity object at 0x000001E6284BE8E0>, <utils.gamehelper.Entity object at 0x000001E6284BEBB0>]
# nearby totems []
# using explosive_arrow_weapon at 1721298031.842919
# successfully used explosive_arrow_weapon at 1721298032.4050078
# mover.distance_to_target: 3518.341228476851
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298032.423363
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E6291FA070>, <utils.gamehelper.Entity object at 0x000001E6291FA640>, <utils.gamehelper.Entity object at 0x000001E6291FA370>, <utils.gamehelper.Entity object at 0x000001E6284C4250>, <utils.gamehelper.Entity object at 0x000001E6284C4520>, <utils.gamehelper.Entity object at 0x000001E6284C47F0>, <utils.gamehelper.Entity object at 0x000001E6284C4AC0>, <utils.gamehelper.Entity object at 0x000001E6284C4D90>, <utils.gamehelper.Entity object at 0x000001E6284C4FA0>]
# using frenzy at 1721298032.449877
# successfully used frenzy at 1721298032.8225565
# mover.distance_to_target: 3518.227394583813
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298032.834997
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# using damage_over_time_aura at 1721298032.834997
# successfully used damage_over_time_aura at 1721298033.0446465
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E6284C01F0>, <utils.gamehelper.Entity object at 0x000001E6284C0040>, <utils.gamehelper.Entity object at 0x000001E6284C07C0>, <utils.gamehelper.Entity object at 0x000001E6291FA670>, <utils.gamehelper.Entity object at 0x000001E6291FA3A0>, <utils.gamehelper.Entity object at 0x000001E6291FA940>, <utils.gamehelper.Entity object at 0x000001E6291FAC10>, <utils.gamehelper.Entity object at 0x000001E6291FAEE0>, <utils.gamehelper.Entity object at 0x000001E6284C41F0>]
# nearby totems [<utils.gamehelper.Entity object at 0x000001E6284C0BE0>, <utils.gamehelper.Entity object at 0x000001E6291FA220>]
# distance_to_next_step 58.54912467321778
# using flame_dash at 1721298033.0456457
# successfully used flame_dash at 1721298033.1479933
# mover.distance_to_target: 3518.227394583813
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298033.1792033
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E6284C4160>, <utils.gamehelper.Entity object at 0x000001E6284C4280>, <utils.gamehelper.Entity object at 0x000001E6284C44C0>, <utils.gamehelper.Entity object at 0x000001E6291FAAF0>, <utils.gamehelper.Entity object at 0x000001E6291FADC0>, <utils.gamehelper.Entity object at 0x000001E6291FAFA0>, <utils.gamehelper.Entity object at 0x000001E6291FAF40>, <utils.gamehelper.Entity object at 0x000001E6291FA070>, <utils.gamehelper.Entity object at 0x000001E6284BE1F0>]
# nearby totems [<utils.gamehelper.Entity object at 0x000001E6284C4EE0>, <utils.gamehelper.Entity object at 0x000001E6291FA550>]
# making step to (821, 656)
# mover.distance_to_target: 3518.227394583813
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298033.3014135
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E6284BE2B0>, <utils.gamehelper.Entity object at 0x000001E6284BE1C0>, <utils.gamehelper.Entity object at 0x000001E6284BE790>, <utils.gamehelper.Entity object at 0x000001E6291F8E80>, <utils.gamehelper.Entity object at 0x000001E6291F8B20>, <utils.gamehelper.Entity object at 0x000001E6291F8760>, <utils.gamehelper.Entity object at 0x000001E6291F85B0>, <utils.gamehelper.Entity object at 0x000001E6291F8FD0>, <utils.gamehelper.Entity object at 0x000001E6291FA490>]
# nearby totems [<utils.gamehelper.Entity object at 0x000001E6284BE910>, <utils.gamehelper.Entity object at 0x000001E6291F8370>]
# making step to (821, 656)
# mover.distance_to_target: 3477.3594867370266
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298033.4247394
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E67F8A8850>, <utils.gamehelper.Entity object at 0x000001E6291FC580>, <utils.gamehelper.Entity object at 0x000001E6291FC220>, <utils.gamehelper.Entity object at 0x000001E6291FC700>, <utils.gamehelper.Entity object at 0x000001E6291FCCD0>, <utils.gamehelper.Entity object at 0x000001E62921BA90>, <utils.gamehelper.Entity object at 0x000001E6291F9D30>, <utils.gamehelper.Entity object at 0x000001E6284BEF70>, <utils.gamehelper.Entity object at 0x000001E6291FA2E0>, <utils.gamehelper.Entity object at 0x000001E6291FA9D0>, <utils.gamehelper.Entity object at 0x000001E6291F8CA0>, <utils.gamehelper.Entity object at 0x000001E6291F8D90>, <utils.gamehelper.Entity object at 0x000001E6291F8730>, <utils.gamehelper.Entity object at 0x000001E6291F8430>, <utils.gamehelper.Entity object at 0x000001E6291F8340>, <utils.gamehelper.Entity object at 0x000001E6291F80A0>]
# nearby totems [<utils.gamehelper.Entity object at 0x000001E6291FA7F0>]
# using explosive_arrow_weapon at 1721298033.4247394
# successfully used explosive_arrow_weapon at 1721298033.9902213
# mover.distance_to_target: 3465.360731583366
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298034.025021
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E6292165B0>, <utils.gamehelper.Entity object at 0x000001E6291FC250>, <utils.gamehelper.Entity object at 0x000001E6291FC7C0>, <utils.gamehelper.Entity object at 0x000001E6291FC5B0>, <utils.gamehelper.Entity object at 0x000001E6291FCA60>, <utils.gamehelper.Entity object at 0x000001E6291FCC70>, <utils.gamehelper.Entity object at 0x000001E62921B7F0>, <utils.gamehelper.Entity object at 0x000001E62921BDC0>, <utils.gamehelper.Entity object at 0x000001E6291F9B50>, <utils.gamehelper.Entity object at 0x000001E6284C08E0>, <utils.gamehelper.Entity object at 0x000001E6284C0760>, <utils.gamehelper.Entity object at 0x000001E6284C0490>, <utils.gamehelper.Entity object at 0x000001E6291F8E20>, <utils.gamehelper.Entity object at 0x000001E6291F8640>, <utils.gamehelper.Entity object at 0x000001E6291F8280>, <utils.gamehelper.Entity object at 0x000001E6291F8D60>, <utils.gamehelper.Entity object at 0x000001E6284C92E0>, <utils.gamehelper.Entity object at 0x000001E6284C95B0>]
# distance_to_next_step 58.034472514187634
# using flame_dash at 1721298034.025021
# successfully used flame_dash at 1721298034.0990226
# mover.distance_to_target: 3465.360731583366
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298034.151021
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E67F89CB50>, <utils.gamehelper.Entity object at 0x000001E6283F6F10>, <utils.gamehelper.Entity object at 0x000001E6283F6C40>, <utils.gamehelper.Entity object at 0x000001E67F8A8850>, <utils.gamehelper.Entity object at 0x000001E6291FC2B0>, <utils.gamehelper.Entity object at 0x000001E6291FCB50>, <utils.gamehelper.Entity object at 0x000001E6291FC760>, <utils.gamehelper.Entity object at 0x000001E6291FCE50>, <utils.gamehelper.Entity object at 0x000001E62921BFD0>, <utils.gamehelper.Entity object at 0x000001E6284CB6A0>, <utils.gamehelper.Entity object at 0x000001E6284CBC40>]
# making step to (926, 656)
# mover.distance_to_target: 3465.360731583366
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298034.280022
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E6292165B0>, <utils.gamehelper.Entity object at 0x000001E6283F6F10>, <utils.gamehelper.Entity object at 0x000001E6283F6C40>, <utils.gamehelper.Entity object at 0x000001E67F897A30>, <utils.gamehelper.Entity object at 0x000001E6291FCEB0>, <utils.gamehelper.Entity object at 0x000001E6291FC520>, <utils.gamehelper.Entity object at 0x000001E6291FCCA0>, <utils.gamehelper.Entity object at 0x000001E62921BFD0>]
# making step to (926, 656)
# mover.distance_to_target: 3465.360731583366
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298034.4010215
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E67F8A8850>, <utils.gamehelper.Entity object at 0x000001E6283F6E20>, <utils.gamehelper.Entity object at 0x000001E6283F6BB0>, <utils.gamehelper.Entity object at 0x000001E67F8977C0>, <utils.gamehelper.Entity object at 0x000001E62921BE80>, <utils.gamehelper.Entity object at 0x000001E62921B820>, <utils.gamehelper.Entity object at 0x000001E6284B1640>, <utils.gamehelper.Entity object at 0x000001E6284B1BE0>]
# making step to (926, 656)
# mover.distance_to_target: 3418.380464488995
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298034.5406706
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E67F8A8700>, <utils.gamehelper.Entity object at 0x000001E6283F6130>, <utils.gamehelper.Entity object at 0x000001E6283F6D90>, <utils.gamehelper.Entity object at 0x000001E6283DBEE0>, <utils.gamehelper.Entity object at 0x000001E6291FCEB0>, <utils.gamehelper.Entity object at 0x000001E6291FC970>, <utils.gamehelper.Entity object at 0x000001E6291FC430>, <utils.gamehelper.Entity object at 0x000001E62921B640>, <utils.gamehelper.Entity object at 0x000001E6284B47C0>]
# making step to (897, 656)
# mover.distance_to_target: 3418.380464488995
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298034.6876748
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E67F897340>, <utils.gamehelper.Entity object at 0x000001E6283F6CD0>, <utils.gamehelper.Entity object at 0x000001E6283F6A90>, <utils.gamehelper.Entity object at 0x000001E6283DBEE0>, <utils.gamehelper.Entity object at 0x000001E62921B940>, <utils.gamehelper.Entity object at 0x000001E62921BB50>, <utils.gamehelper.Entity object at 0x000001E6284BB880>, <utils.gamehelper.Entity object at 0x000001E6284BBBB0>, <utils.gamehelper.Entity object at 0x000001E6284C6400>, <utils.gamehelper.Entity object at 0x000001E6284CDCA0>, <utils.gamehelper.Entity object at 0x000001E6284CD2B0>, <utils.gamehelper.Entity object at 0x000001E6284CD580>, <utils.gamehelper.Entity object at 0x000001E6284CD850>, <utils.gamehelper.Entity object at 0x000001E6284CDB20>]
# nearby totems [<utils.gamehelper.Entity object at 0x000001E6291FACD0>, <utils.gamehelper.Entity object at 0x000001E6291FA250>]
# distance_to_next_step 58.07753438292642
# using flame_dash at 1721298034.6876748
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (939, 656)
# mover.distance_to_target: 3414.337417420839
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298034.8316712
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E6291F6790>, <utils.gamehelper.Entity object at 0x000001E6291F6700>, <utils.gamehelper.Entity object at 0x000001E6291F6220>, <utils.gamehelper.Entity object at 0x000001E6291F66D0>, <utils.gamehelper.Entity object at 0x000001E6291F65E0>, <utils.gamehelper.Entity object at 0x000001E6283F6F10>, <utils.gamehelper.Entity object at 0x000001E6284BB3D0>, <utils.gamehelper.Entity object at 0x000001E6284BB820>, <utils.gamehelper.Entity object at 0x000001E6284CD910>, <utils.gamehelper.Entity object at 0x000001E6291F8220>, <utils.gamehelper.Entity object at 0x000001E6291F8760>, <utils.gamehelper.Entity object at 0x000001E6291F8FA0>, <utils.gamehelper.Entity object at 0x000001E6291F8040>, <utils.gamehelper.Entity object at 0x000001E6291F8490>]
# nearby totems [<utils.gamehelper.Entity object at 0x000001E6291FACD0>, <utils.gamehelper.Entity object at 0x000001E6291FA250>]
# distance_to_next_step 58.0
# using flame_dash at 1721298034.8316712
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (880, 656)
# mover.distance_to_target: 3405.271501657393
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298034.952676
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E6284BE730>, <utils.gamehelper.Entity object at 0x000001E6284BE2B0>, <utils.gamehelper.Entity object at 0x000001E6284BE8B0>, <utils.gamehelper.Entity object at 0x000001E6284BED60>, <utils.gamehelper.Entity object at 0x000001E6284BEAF0>, <utils.gamehelper.Entity object at 0x000001E6291F62B0>, <utils.gamehelper.Entity object at 0x000001E6291F6040>, <utils.gamehelper.Entity object at 0x000001E6291F67C0>, <utils.gamehelper.Entity object at 0x000001E6291F8430>, <utils.gamehelper.Entity object at 0x000001E6284AF0A0>, <utils.gamehelper.Entity object at 0x000001E6284AF1F0>, <utils.gamehelper.Entity object at 0x000001E6284AF4C0>, <utils.gamehelper.Entity object at 0x000001E6284AF9D0>, <utils.gamehelper.Entity object at 0x000001E6284AFD30>]
# nearby totems [<utils.gamehelper.Entity object at 0x000001E6291FACD0>, <utils.gamehelper.Entity object at 0x000001E6291FA250>]
# distance_to_next_step 58.21511831131153
# using flame_dash at 1721298034.953677
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (849, 656)
# mover.distance_to_target: 3398.247342381069
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298035.089638
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E629224460>, <utils.gamehelper.Entity object at 0x000001E629224190>, <utils.gamehelper.Entity object at 0x000001E629224820>, <utils.gamehelper.Entity object at 0x000001E629224340>, <utils.gamehelper.Entity object at 0x000001E629224C40>, <utils.gamehelper.Entity object at 0x000001E6291FC190>, <utils.gamehelper.Entity object at 0x000001E6291FCBE0>, <utils.gamehelper.Entity object at 0x000001E6291FC550>, <utils.gamehelper.Entity object at 0x000001E6284AFC10>, <utils.gamehelper.Entity object at 0x000001E6284C23A0>, <utils.gamehelper.Entity object at 0x000001E6284C2B50>, <utils.gamehelper.Entity object at 0x000001E6284C2CD0>, <utils.gamehelper.Entity object at 0x000001E6284C21C0>, <utils.gamehelper.Entity object at 0x000001E6284C28B0>]
# nearby totems []
# using explosive_arrow_weapon at 1721298035.089638
# successfully used explosive_arrow_weapon at 1721298035.6427472
# mover.distance_to_target: 3388.24807238195
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298035.6617472
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E6291F6FA0>, <utils.gamehelper.Entity object at 0x000001E6291F6F40>, <utils.gamehelper.Entity object at 0x000001E6291F67C0>, <utils.gamehelper.Entity object at 0x000001E6284BB9A0>, <utils.gamehelper.Entity object at 0x000001E6284BB490>]
# distance_to_next_step 11.40175425099138
# making step to (602, 472)
# mover.distance_to_target: 3388.24807238195
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298035.792747
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: [<utils.gamehelper.Entity object at 0x000001E6284BBDF0>, <utils.gamehelper.Entity object at 0x000001E6284BBC70>, <utils.gamehelper.Entity object at 0x000001E6284BBEE0>, <utils.gamehelper.Entity object at 0x000001E62849D430>]
# distance_to_next_step 11.40175425099138
# making step to (602, 472)
# unable to use the script since its outdated
# unable to use the script since the computer time is outdated
# mover.distance_to_target: 3385.273105674046
# len(current_path) 1
# #LootPicker.collectLoot call at 1721298036.7084646
# activating blessing <utils.combat.BlessingSkill object at 0x000001E6283DB1C0>
# nearby_enemies_on_screen: []
# distance_to_next_step 7.0710678118654755
# sent reboot script to worker
# http://172.28.180.101:50006/getScreenPos?y=3430&x=363
# http://172.28.180.101:50006/getScreenPos?y=3430&x=363 , raiseLongSleepException
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[11], line 35
#      32   continue
#      34 # go to point to make it explored
# ---> 35 result = mover.goToPoint(
#      36   point=point_to_go,
#      37   min_distance=50,
#      38   release_mouse_on_end=False,
#      39   custom_break_function=mover_custom_break_function,
#      40   step_size=random.randint(30,35)
#      41 )
#      42 # then, it result is True, False or None
#      43 print(f"mover.goToPoint result {result}")
#
# File c:\poe_bot\1_host\utils\mover.py:459, in Mover.goToPoint(self, point, min_distance, release_mouse_on_end, release_mouse_on_start, randomize_grid_pos_to_go, random_val, custom_break_function, custom_continue_function, heist_transition, step_size, possible_transition, time_limit)
#     456 if bot_controls.mouse_pressed['left'] is True and custom_continue_function(self) is True:
#     457   continue
# --> 459 pos_to_click = poe_bot.getPositionOfThePointOnTheScreen(current_path[-1][0], current_path[-1][1])
#     460 pos_x,pos_y = poe_bot.convertPosXY(pos_to_click[0], pos_to_click[1])
#     461 self.pos_x,self.pos_y = pos_x,pos_y
#
# File c:\poe_bot\1_host\utils\gamehelper.py:214, in PoeBot.getPositionOfThePointOnTheScreen(self, y, x)
#     212 # cos maps is upside down
#     213 y = self.game_data.terrain.terrain_image.shape[0] - y
# --> 214 data = self.backend.getPositionOfThePointOnTheScreen(y,x)
#     215 return data
#
# File c:\poe_bot\1_host\utils\backend.py:312, in Backend.getPositionOfThePointOnTheScreen(self, y, x)
#     310 x = int(x)
#     311 y = int(y)
# --> 312 r = requests.get(f'{self.endpoint}/getScreenPos?y={y}&x={x}')
#     313 data = r.json()
#     315 if self.debug: print(f'#getPositionOfThePointOnTheScreen return {time.time()}')
#
# File c:\poe_bot\1_host\utils\gamehelper.py:358, in PoeBot.raiseLongSleepException(self, text, *args, **kwargs)
#     356 self.logger.writeLine(text)
#     357 self.coordinator.sendErrorMessage(text)
# --> 358 raiseLongSleepException(text)
#
# File c:\poe_bot\1_host\utils\utils.py:26, in raiseLongSleepException(text)
#      24 print(f'{text} , raiseLongSleepException')
#      25 run_debug = input("y if run pdb")
# ---> 26 raise Exception(f'{text} , sleep 3600*24')
#
# Exception: http://172.28.180.101:50006/getScreenPos?y=3430&x=363 , sleep 3600*24

# %%
aqueduct_module.resetInstance()
# Out:
# #goToPoint point: [364, 435], min_distance: 20, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: False, random_val: 1
# custom_break_function:<function alwaysFalseFunction at 0x000001FD966C6310>, custom_continue_function:<bound method EaBallistasEle.usualRoutine of <utils.combat.EaBallistasEle object at 0x000001FD973BAA30>>
# heist_transition: False, step_size: 34possible_transition: False
# end pos to go 364 435
# mover.distance_to_target: 151.647617851386
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 56.03570290448759
# using flame_dash at 1721297809.8971932
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (338, 229)
# making first step, placing a mouse on (338, 229) and going
# mover.distance_to_target: 149.6562728387955
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 56.03570290448759
# using flame_dash at 1721297809.9691932
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (336, 217)
# mover.distance_to_target: 140.69825869569246
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 56.32051136131489
# using flame_dash at 1721297810.119559
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (346, 164)
# mover.distance_to_target: 135.72398461583714
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 56.32051136131489
# using flame_dash at 1721297810.214623
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (334, 151)
# mover.distance_to_target: 129.75746606650424
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 56.435804238089844
# using flame_dash at 1721297810.348623
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (350, 150)
# mover.distance_to_target: 121.80722474467595
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 56.568542494923804
# using flame_dash at 1721297810.4711099
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (357, 153)
# mover.distance_to_target: 111.87939935484101
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 56.568542494923804
# using flame_dash at 1721297810.5988638
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (328, 99)
# mover.distance_to_target: 105.92922165295089
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 56.568542494923804
# using flame_dash at 1721297810.7368562
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (347, 99)
# mover.distance_to_target: 97.86725703727473
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 56.718603649948925
# using flame_dash at 1721297810.848858
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (372, 99)
# mover.distance_to_target: 91.92388155425118
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 56.718603649948925
# using flame_dash at 1721297810.960703
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (379, 99)
# mover.distance_to_target: 85.98837130682264
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 56.718603649948925
# using flame_dash at 1721297811.1198852
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (397, 99)
# mover.distance_to_target: 75.66372975210777
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 56.32051136131489
# using flame_dash at 1721297811.2088797
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (380, 99)
# mover.distance_to_target: 69.58448102845921
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 56.222771187482394
# using flame_dash at 1721297811.319878
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (380, 99)
# mover.distance_to_target: 63.63961030678928
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 56.222771187482394
# using flame_dash at 1721297811.4408786
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (375, 99)
# mover.distance_to_target: 53.75872022286244
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# distance_to_next_step 52.77309920783504
# using flame_dash at 1721297811.5594592
# cant use skill flame_dash cos 0 in can_use_skills_indexes_raw
# making step to (393, 99)
# mover.distance_to_target: 47.853944456021594
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# making step to (406, 101)
# mover.distance_to_target: 40.024992192379
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# making step to (441, 161)
# mover.distance_to_target: 30.364452901377952
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# making step to (477, 219)
# mover.distance_to_target: 26.248809496813376
# len(current_path) 1
# activating blessing <utils.combat.BlessingSkill object at 0x000001FDEE9C4910>
# nearby_enemies_on_screen: []
# making step to (498, 256)
# mover.distance_to_target: 18.681541692269406
# 20 points to target, almost arrived player_pos: x:359 y: 453
# #clickTillNotTargetable call 1721297812.1982727 {'ls': [-74, -325], 'p': 'Metadata/MiscellaneousObjects/AreaTransition', 'r': 'White', 'i': 22, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'em': 0, 'b': 1, 'gp': [364, 435], 'wp': [4004, 40319, -454], 'l': None, 'rn': 'Highgate', 'et': 'at', 'distance_to_player': 161.60754932861275}
# #goToPoint point: [364, 435], min_distance: 30, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: True, random_val: 1
# custom_break_function:<function alwaysFalseFunction at 0x000001FD966C6310>, custom_continue_function:<bound method EaBallistasEle.usualRoutine of <utils.combat.EaBallistasEle object at 0x000001FD973BAA30>>
# heist_transition: False, step_size: 31possible_transition: False
# end pos to go 364 436
# useless call of gotopoint arrived = True
# arrived to activator
# sent reboot script to worker
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 aqueduct_module.resetInstance()
#
# Cell In[6], line 75, in Aqueduct.resetInstance(self)
#      73 if target.render_name == "Highgate":
#      74   mover.goToEntitysPoint(target)
# ---> 75   target.clickTillNotTargetable()
#      76 if target.render_name == "Waypoint":
#      77   mover.goToEntitysPoint(target, release_mouse_on_end=True)
#
# File c:\poe_bot\1_host\utils\gamehelper.py:723, in Entity.clickTillNotTargetable(self, custom_break_condition)
#     721 if activated is False:
#     722   activator.click()
# --> 723   self.poe_bot.refreshInstanceData()
#     724 else:
#     725   break
#
# File c:\poe_bot\1_host\utils\gamehelper.py:274, in PoeBot.refreshInstanceData(self, refreshed_data, force, check_if_lag, reset_timer, raise_if_loading)
#     271     time.sleep(wait_till_next_action)
#     273 if refreshed_data is None:
# --> 274   refreshed_data = self.getData("partial")
#     275   # disconnect?
#     276   if refreshed_data["area_raw_name"] is None:
#
# File c:\poe_bot\1_host\utils\gamehelper.py:202, in PoeBot.getData(self, request_type)
#     200 if request_type == "partial":
#     201   self.bot_controls.restartScript()
# --> 202   raise Exception("area is loading on partial request")
#     203 else:
#     204   time.sleep(0.1)
#
# Exception: area is loading on partial request

# %%
raise Exception('finished, all good')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 raise Exception('finished, all good')
#
# Exception: finished, all good
# [key checker] checking key b930676c8593d53test
# [key checker] b930676c8593d53test has 269248096 seconds left
# [key checker] checking key b930676c8593d53test
# [key checker] b930676c8593d53test has 269248081 seconds left
# [key checker] checking key b930676c8593d53test
# [key checker] b930676c8593d53test has 269248066 seconds left
# [key checker] checking key b930676c8593d53test
# [key checker] b930676c8593d53test has 269248051 seconds left
# [key checker] checking key b930676c8593d53test
# [key checker] b930676c8593d53test has 269248035 seconds left
# [key checker] checking key b930676c8593d53test
# [key checker] b930676c8593d53test has 269248020 seconds left
# [key checker] checking key b930676c8593d53test
# [key checker] b930676c8593d53test has 269248005 seconds left
# [key checker] checking key b930676c8593d53test
# [key checker] b930676c8593d53test has 269247990 seconds left
# [key checker] checking key b930676c8593d53test
# [key checker] b930676c8593d53test has 269247974 seconds left
# [key checker] checking key b930676c8593d53test
# [key checker] b930676c8593d53test has 269247959 seconds left

# %%
poe_bot.refreshAll()

list(filter(lambda e: e.life.health.current != 0 and not e.is_hostile and e.distance_to_player < 50 and "Metadata/Monsters/Totems/ShotgunTotem" in e.path, poe_bot.game_data.entities.all_entities))

# %%
list(filter(lambda e: e.life.health.current != 0 and not e.is_hostile and e.distance_to_player < 50 and "Metadata/Monsters/Totems/ShotgunTotem" in e.path, poe_bot.game_data.entities.all_entities))

# %%
nearby_totems = list(filter(lambda e: "Metadata/Monsters/Totems/ShotgunTotem" in e.path, poe_bot.game_data.entities.all_entities))

# %%
nearby_totems[0].raw
