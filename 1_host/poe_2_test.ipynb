# %%
import time
import random
import sys
from ast import literal_eval

from utils.gamehelper import Poe2Bot

# %%
from utils.combat import InfernalistZoomancer

# %%
notebook_dev = False
# readability
poe_bot_class = Poe2Bot
poe_bot: poe_bot_class

# %%
default_config = {
  "REMOTE_IP": '172.22.159.221', # z2
  "unique_id": "poe_2_test",
  "build": "EaBallistasEle",
  "password": None,
  "max_lvl": 101,
  "chromatics_recipe": True,
  "force_reset_temp": False,
}



try:
  i = sys.argv[1]
  print(i)
  parsed_config = literal_eval(i)
  print(f'successfully parsed cli config')
  print(f'parsed_config: {parsed_config}')
except:
  print(f'cannot parse config from cli, using default\dev one')
  notebook_dev = True
  parsed_config = default_config
  parsed_config['unique_id'] = poe_bot_class.getDevKey()

config = {

}

for key in default_config.keys():
  config[key] = parsed_config.get(key, default_config[key])

print(f'config to run {config}')
# Out:
# --f=c:\Users\1\AppData\Roaming\jupyter\runtime\kernel-v2-12992hV8BlJVpJNX7.json
# cannot parse config from cli, using default\dev one
# config to run {'REMOTE_IP': '172.22.159.221', 'unique_id': '7d1165934e24534a1ba5', 'build': 'EaBallistasEle', 'password': None, 'max_lvl': 101, 'chromatics_recipe': True, 'force_reset_temp': False}

# %%
REMOTE_IP = config['REMOTE_IP'] # REMOTE_IP
UNIQUE_ID = config['unique_id'] # unique id
MAX_LVL = config.get('max_lvl')
CHROMATICS_RECIPE = config['chromatics_recipe']
BUILD_NAME = config['build'] # build_name
password = config['password']
force_reset_temp = config['force_reset_temp']
print(f'running aqueduct using: REMOTE_IP: {REMOTE_IP} unique_id: {UNIQUE_ID} max_lvl: {MAX_LVL} chromatics_recipe: {CHROMATICS_RECIPE} force_reset_temp: {force_reset_temp}')
# Out:
# running aqueduct using: REMOTE_IP: 172.22.159.221 unique_id: 7d1165934e24534a1ba5 max_lvl: 101 chromatics_recipe: True force_reset_temp: False

# %%
poe_bot = Poe2Bot(unique_id = UNIQUE_ID, remote_ip = REMOTE_IP, password=password)
poe_bot.refreshAll()
# poe_bot.game_data.terrain.getCurrentlyPassableArea()
# Out:
# [Controller] establishing connection with ('172.22.159.221', 50007)
# [temp] loaded from file AfkTempData
# [temp] loaded from file StashTempData
# build is not assigned, using any functions may throw errors
# poe bot, v: 3.25.15 init at 1735060208.895105
# [temp] loaded from file StashTempData
# [poebot] #refreshAll call at 1735060208.8971055

# %%
from utils.loot_filter import PickableItemLabel

ARTS_TO_PICK = [
  "Art/2DItems/Currency/CurrencyModValues.dds", # divine
  "Art/2DItems/Currency/CurrencyGemQuality.dds", # gemcutter
  "Art/2DItems/Currency/CurrencyRerollRare.dds", # chaos
  "Art/2DItems/Currency/CurrencyAddModToRare.dds", # exalt
  "Art/2DItems/Currency/CurrencyUpgradeToUnique.dds", # chance
]

# big piles of gold
for tier in range(2,17):
  ARTS_TO_PICK.append(f"Art/2DItems/Currency/Ruthless/CoinPileTier{tier}.dds")
# waystones
for tier in range(1,17):
  ARTS_TO_PICK.append(f"Art/2DItems/Maps/EndgameMaps/EndgameMap{tier}.dds")

def isItemHasPickableKey(item_label:PickableItemLabel):
  if item_label.icon_render in ARTS_TO_PICK:
    return True
  return False
poe_bot.loot_picker.loot_filter.special_rules = [isItemHasPickableKey]

# %%
# poe_bot.mover.setMoveType('wasd')

# %%
poe_bot.combat_module.build = InfernalistZoomancer(poe_bot=poe_bot)
poe_bot.mover.default_continue_function = poe_bot.combat_module.build.usualRoutine
# Out:
# [InfernalistZoomancer.__init__] found minion_reaver_enrage_index 4

# %%
# raise 404

# %%
# poe_bot.game_data.terrain.getCurrentlyPassableArea()

# from utils.constants import ESSENCES_KEYWORD
# essences = list(filter(lambda e: e.is_targetable is True and ESSENCES_KEYWORD in e.path and poe_bot.game_data.terrain.checkIfPointPassable(e.grid_position.x, e.grid_position.y), poe_bot.game_data.entities.all_entities))
# essences[0].id

# %%
# poe_bot.backend.getVisibleLabels()

# %%
# raise 404

# %%
rares_detection_radius = 999

def runnerBreakFunction(*args, **kwargs):
  switch_nearby = next( (e for e in poe_bot.game_data.entities.all_entities if e.is_targetable and e.path == "Metadata/Terrain/Maps/Crypt/Objects/CryptSecretDoorSwitch" and e.distance_to_player < 30), None)
  if switch_nearby:
    poe_bot.mover.goToEntitysPoint(switch_nearby)
    poe_bot.combat_module.clearAreaAroundPoint(switch_nearby.grid_position.toList())
    switch_nearby.clickTillNotTargetable()
    return True

  if rares_detection_radius != 0:
    rares_nearby = list(filter(lambda e: e.distance_to_player < rares_detection_radius, poe_bot.game_data.entities.attackable_entities_rares))
    for rare_mob in rares_nearby:
      updated_entity = list(filter(lambda e: e.id == rare_mob.id, poe_bot.game_data.entities.attackable_entities_rares))
      if len(updated_entity) != 0:
        updated_entity = updated_entity[0]
        poe_bot.mover.goToEntitysPoint(updated_entity, min_distance=50)
        poe_bot.combat_module.killUsualEntity(updated_entity)
        return True

  loot_collected = poe_bot.loot_picker.collectLoot()
  if loot_collected is True:
    return loot_collected
  return False

# %%
# raise 404
poe_bot.refreshAll()
# Out:
# [poebot] #refreshAll call at 1735060209.192808

# %%
prefer_high_tier = True
alch_map_if_possible = True

# free inventory if neededS
poe_bot.ui.inventory.update()
empty_slots = poe_bot.ui.inventory.getEmptySlots()
if len(empty_slots) < 40:
  poe_bot.ui.stash.open()
  items_to_keep = []
  poe_bot.ui.inventory.update()
  waystones_to_keep = list(filter(lambda i: i.map_tier, poe_bot.ui.inventory.items))
  waystones_to_keep.sort(key=lambda i: i.map_tier, reverse=prefer_high_tier)
  items_to_keep.extend(waystones_to_keep[:4])
  alchemy_orbs = list(filter(lambda i: i.name == "Orb of Alchemy", poe_bot.ui.inventory.items))
  items_to_keep.extend(alchemy_orbs[:1])
  items_can_stash = list(filter(lambda i: i not in items_to_keep, poe_bot.ui.inventory.items))
  poe_bot.ui.clickMultipleItems(items_can_stash)
  poe_bot.ui.closeAll()
  time.sleep(random.uniform(0.3, 1.4))

# open map device
poe_bot.refreshInstanceData()
map_device_entity = next( (e for e in poe_bot.game_data.entities.all_entities if e.path == "Metadata/Terrain/Missions/Hideouts/Objects/MapDeviceVariants/ZigguratMapDevice"), None)
map_device_entity.hover()
poe_bot.refreshInstanceData()
map_device_entity = next( (e for e in poe_bot.game_data.entities.all_entities if e.path == "Metadata/Terrain/Missions/Hideouts/Objects/MapDeviceVariants/ZigguratMapDevice"), None)
if map_device_entity.is_targeted == True:
  print('targeted')
  map_device_entity.click()
  _i = 0
  while True:
    _i += 1
    if _i == 100:
      poe_bot.raiseLongSleepException('cannot open map device')

    poe_bot.ui.map_device.update()
    if poe_bot.ui.map_device.is_opened == True:
      break
    time.sleep(random.uniform(1.3, 1.4))
  time.sleep(random.uniform(1.3, 1.4))
else:
  poe_bot.raiseLongSleepException("couldnt target map device, restart or debug")
# move to map, open dropdown
poe_bot.ui.map_device.update()
possible_to_run_maps = list(filter(lambda m: 
  m.is_boss == False and # some bosses have unique logic?
  m.is_tower == False and# cant run tower maps yet
  m.name_raw != 'MapAugury_NoBoss' # activators
, poe_bot.ui.map_device.avaliable_maps))
map_obj = random.choice(possible_to_run_maps)
print(map_obj.raw)
poe_bot.ui.map_device.moveScreenTo(map_obj)
time.sleep(random.uniform(0.15, 0.35))


poe_bot.ui.map_device.update()
for i in range(3):
  updated_map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == map_obj.id))
  time.sleep(random.uniform(0.15, 0.35))
  updated_map_obj.hover()
  time.sleep(random.uniform(0.15, 0.35))
  updated_map_obj.click(hover=False)
  time.sleep(random.uniform(0.15, 0.35))
  poe_bot.ui.map_device.update()

  if poe_bot.ui.map_device.place_map_window_opened == True:
    break
if poe_bot.ui.map_device.place_map_window_opened != True:
  poe_bot.raiseLongSleepException("cant open dropdown for map device")
# Out:
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=891&y=393&mtm=-1&msm=1 at 1735060209.4298267
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=891&y=393&mtm=-1&msm=1 at 1735060209.494438
# targeted
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=891&y=393&mtm=-1&msm=1&wtr=1& at 1735060209.5384374
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=891&y=393&mtm=-1&msm=1&wtr=1& at 1735060209.5384374
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735060209.5394404
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735060209.6144285
# [Controller] debug sending action=mouseRelease&button=left at 1735060209.7508109
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735060209.754808
# {'sz': [1857, 1895, 1688, 1726], 'id': 13, 'name': 'Savannah', 'name_raw': 'MapSavanna_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentRitual.dds']}
# going to drag to 13
# {'sz': [1857, 1895, 1688, 1726], 'id': 13, 'name': 'Savannah', 'name_raw': 'MapSavanna_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentRitual.dds']}
# roi borders [397, 597, 149, 449]
# borders [25, 969, 80, 618]
# map_obj.screen_pos [1876, 1707]
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=1026&y=668&mtm=-1&msm=1 at 1735060212.7782073
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=1026&y=668&mtm=-1&msm=1 at 1735060212.8972077
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735060213.2508037
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735060213.2598114
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=785&y=435&mtm=-1&msm=1 at 1735060213.5678108
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=785&y=435&mtm=-1&msm=1 at 1735060213.6678152
# [Controller] debug sending action=mouseRelease&button=left at 1735060214.0118148
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735060214.0138154
# {'sz': [1388, 1426, 1358, 1396], 'id': 13, 'name': 'Savannah', 'name_raw': 'MapSavanna_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentRitual.dds']}
# roi borders [397, 597, 149, 449]
# borders [25, 969, 80, 618]
# map_obj.screen_pos [1407, 1377]
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=995&y=668&mtm=-1&msm=1 at 1735060214.4433806
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=995&y=668&mtm=-1&msm=1 at 1735060214.549993
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735060214.8940072
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735060214.924993
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=785&y=435&mtm=-1&msm=1 at 1735060215.3226156
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=785&y=435&mtm=-1&msm=1 at 1735060215.4296184
# [Controller] debug sending action=mouseRelease&button=left at 1735060215.7332132
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735060215.7352104
# {'sz': [1021, 1059, 1067, 1105], 'id': 13, 'name': 'Savannah', 'name_raw': 'MapSavanna_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentRitual.dds']}
# roi borders [397, 597, 149, 449]
# borders [25, 969, 80, 618]
# map_obj.screen_pos [1040, 1086]
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=960&y=668&mtm=-1&msm=1 at 1735060216.066234
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=960&y=668&mtm=-1&msm=1 at 1735060216.157232
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735060216.5425
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735060216.568501
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=785&y=435&mtm=-1&msm=1 at 1735060216.8909
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=785&y=435&mtm=-1&msm=1 at 1735060216.9976885
# [Controller] debug sending action=mouseRelease&button=left at 1735060217.301324
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735060217.3033247
# {'sz': [745, 783, 809, 847], 'id': 13, 'name': 'Savannah', 'name_raw': 'MapSavanna_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentRitual.dds']}
# roi borders [397, 597, 149, 449]
# borders [25, 969, 80, 618]
# map_obj.screen_pos [764, 828]
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=917&y=668&mtm=-1&msm=1 at 1735060217.6719353
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=917&y=668&mtm=-1&msm=1 at 1735060217.776937
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735060217.9639382
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735060217.9689395
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=785&y=435&mtm=-1&msm=1 at 1735060218.3085241
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=785&y=435&mtm=-1&msm=1 at 1735060218.401528
# [Controller] debug sending action=mouseRelease&button=left at 1735060218.7521427
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735060218.754144
# {'sz': [555, 594, 579, 617], 'id': 13, 'name': 'Savannah', 'name_raw': 'MapSavanna_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentRitual.dds']}
# roi borders [397, 597, 149, 449]
# borders [25, 969, 80, 618]
# map_obj.screen_pos [574, 598]
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=847&y=649&mtm=-1&msm=1 at 1735060219.2197585
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=847&y=649&mtm=-1&msm=1 at 1735060219.305766
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735060219.5924451
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735060219.6054275
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=785&y=435&mtm=-1&msm=1 at 1735060219.9094346
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=785&y=435&mtm=-1&msm=1 at 1735060219.982432
# [Controller] debug sending action=mouseRelease&button=left at 1735060220.1654882
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735060220.1670346
# {'sz': [544, 583, 538, 576], 'id': 13, 'name': 'Savannah', 'name_raw': 'MapSavanna_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentRitual.dds']}
# roi borders [185, 385, 149, 449]
# borders [25, 545, 80, 618]
# map_obj.screen_pos [563, 557]
# inventory is opened, different borders and roi
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=817&y=546&mtm=-1&msm=1 at 1735060220.5922492
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=817&y=546&mtm=-1&msm=1 at 1735060220.649256
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735060221.0172803
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735060221.0302827
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=529&y=435&mtm=-1&msm=1 at 1735060221.4295857
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=529&y=435&mtm=-1&msm=1 at 1735060221.5342226
# [Controller] debug sending action=mouseRelease&button=left at 1735060221.6983182
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735060221.699319
# {'sz': [172, 211, 439, 477], 'id': 13, 'name': 'Savannah', 'name_raw': 'MapSavanna_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentRitual.dds']}
# roi borders [185, 385, 149, 449]
# borders [25, 545, 80, 618]
# map_obj.screen_pos [191, 458]
# inventory is opened, different borders and roi
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=464&y=509&mtm=-1&msm=1 at 1735060222.1046202
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=464&y=509&mtm=-1&msm=1 at 1735060222.1666222
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735060222.5688572
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735060222.596861
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=529&y=435&mtm=-1&msm=1 at 1735060222.9497175
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=529&y=435&mtm=-1&msm=1 at 1735060223.0187137
# [Controller] debug sending action=mouseRelease&button=left at 1735060223.4073236
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735060223.4083247
# {'sz': [179, 217, 408, 446], 'id': 13, 'name': 'Savannah', 'name_raw': 'MapSavanna_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentRitual.dds']}
# roi borders [185, 385, 149, 449]
# borders [25, 545, 80, 618]
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=471&y=478&mtm=-1&msm=1 at 1735060224.1864963
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=471&y=478&mtm=-1&msm=1 at 1735060224.2284865
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735060224.4731245
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735060224.507126
# [Controller] debug sending action=mouseRelease&button=left at 1735060224.507126
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735060224.5081244

# %%
poe_bot.ui.inventory.update()
maps_in_inventory = list(filter(lambda i: i.map_tier, poe_bot.ui.inventory.items))
maps_in_inventory.sort(key=lambda i: i.map_tier, reverse=prefer_high_tier)
map_to_run = maps_in_inventory[0]
print(f'placing map {map_to_run.raw}')

if alch_map_if_possible == True:
  ARTS_TO_PICK.append("Art/2DItems/Currency/CurrencyUpgradeToRare.dds")
  for _i in range(1):
    if map_to_run.rarity != "Normal":
      break
    alchemy_orbs = list(filter(lambda i: i.name == "Orb of Alchemy", poe_bot.ui.inventory.items))
    if len(alchemy_orbs) == 0:
      break
    alchemy_orb = alchemy_orbs[0]
    alchemy_orb.click(button="right")
    time.sleep(random.uniform(0.4, 1.2))
    map_to_run.click()
    time.sleep(random.uniform(0.8, 1.2))

map_to_run.click(hold_ctrl=True)
poe_bot.ui.map_device.update()
#TODO sometimes activate button is outside roi
poe_bot.ui.map_device.checkIfActivateButtonIsActive()
# Out:
# placing map {'l': None, 'tt': None, 'Name': 'Waystone (Tier 3)', 'a': 'Art/2DItems/Maps/EndgameMaps/EndgameMap3.dds', 'unique_name': '', 'rarity': 'Normal', 'Class': None, 'ItemType': None, 'm_t': 3, 'c': 0, 'i': 0, 'RenderArt': 'Metadata/Items/Maps/MapKeyTier3', 'items_in_stack': 0, 'item_mods': [], 'imr': [], 'g': [1, 2, 2, 3], 's': [600, 637, 494, 532], 'ti': 0, 'LocationTopLeft': None, 'LocationBottomRight': None, 'TopLeft': None, 'BottomRight': None}
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=859&y=558&mtm=-1&msm=1 at 1735060224.8611217
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=859&y=558&mtm=-1&msm=1 at 1735060224.9921267
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=right at 1735060225.127124
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=right at 1735060225.143148
# [Controller] debug sending action=mouseRelease&button=right at 1735060225.143148
# [Controller] debug recieved response for action=mouseRelease&button=right at 1735060225.143148
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=901&y=576&mtm=-1&msm=1 at 1735060226.2855005
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=901&y=576&mtm=-1&msm=1 at 1735060226.3304899
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735060226.586091
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735060226.6160908
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=897&y=574&mtm=-1&msm=1 at 1735060226.6160908
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=897&y=574&mtm=-1&msm=1 at 1735060226.6530921
# [Controller] debug sending action=mouseRelease&button=left at 1735060226.6530921
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735060226.6540911
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_LCONTROL at 1735060227.5702784
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_LCONTROL at 1735060227.5712798
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=887&y=556&mtm=-1&msm=1 at 1735060227.5712798
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=887&y=556&mtm=-1&msm=1 at 1735060227.602282
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735060227.7762847
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735060227.80828
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=885&y=565&mtm=-1&msm=1 at 1735060227.80828
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=885&y=565&mtm=-1&msm=1 at 1735060227.842285
# [Controller] debug sending action=mouseRelease&button=left at 1735060227.842285
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735060227.8442833
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_LCONTROL at 1735060227.9042811
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_LCONTROL at 1735060227.905283
# [Controller] debug sending action=getPartialScreen&x1=273&y1=51&x2=1297&y2=819& at 1735060228.1839523
# [Controller] data_size_raw b'\x00$\x15\xa8'
# [Controller] data_size 2364840
# activate_button_is_active False
# False

# %%
poe_bot.ui.map_device.activate()

time.sleep(random.uniform(0.8, 1.6))
poe_bot.helper_functions.waitForNewPortals()

poe_bot.refreshInstanceData()
try:
  poe_bot.helper_functions.getToPortal(check_for_map_device=False)
except Exception as e:
  if e.__str__() == 'Portal is too far away':
    print(f'portal became too far away')
    original_area_name = poe_bot.game_data.area_raw_name
    _i = 0
    while True:
      _i += 1
      if _i == 100:
        poe_bot.raiseLongSleepException('coudlnt get to portal')
      poe_bot.refreshAll()
      
      if poe_bot.game_data.area_raw_name != original_area_name:
        break

  else:
    print(e.__str__())
    raise Exception('smth happened on getToPortal')
# Out:
# [Controller] debug sending action=getPartialScreen&x1=273&y1=51&x2=1297&y2=819& at 1735060228.3279505
# [Controller] data_size_raw b'\x00$\x15\xa8'
# [Controller] data_size 2364840
# activate_button_is_active False
# self.checkIfActivateButtonIsActive() is False
# self.checkIfActivateButtonIsActive() is False , raiseLongSleepException
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 poe_bot.ui.map_device.activate()
#       3 time.sleep(random.uniform(0.8, 1.6))
#       4 poe_bot.helper_functions.waitForNewPortals()
#
# File c:\p2\1_host\utils\ui.py:1149, in MapDevice.activate(self)
#    1147 def activate(self):
#    1148   if self.checkIfActivateButtonIsActive() is False:
# -> 1149     self.poe_bot.raiseLongSleepException("self.checkIfActivateButtonIsActive() is False")
#    1150   activate_button_pos = self.activate_button_pos.getCenter()
#    1151   pos_x,pos_y = self.poe_bot.convertPosXY(activate_button_pos[0], activate_button_pos[1], safe=False)
#
# File c:\p2\1_host\utils\gamehelper.py:253, in PoeBot.raiseLongSleepException(self, text, *args, **kwargs)
#     251   self.logger.writeLine(text)
#     252 self.coordinator.sendErrorMessage(text)
# --> 253 raiseLongSleepException(text)
#
# File c:\p2\1_host\utils\utils.py:43, in raiseLongSleepException(text)
#      41 print(f'{text} , raiseLongSleepException')
#      42 run_debug = input("y if run pdb")
# ---> 43 raise Exception(f'{text} , sleep 3600*24')
#
# Exception: self.checkIfActivateButtonIsActive() is False , sleep 3600*24

# %%
# raise 404

# %%
from utils.pathing import TSP


tsp = TSP(poe_bot=poe_bot)
# tsp.generatePointsForDiscovery()
mover = poe_bot.mover
map_complete = False
while map_complete is False:
  poe_bot.refreshInstanceData()
  print(f'generating pathing points')
  tsp.generatePointsForDiscovery()
  #TODO astar sorting
  discovery_points = tsp.sortedPointsForDiscovery()
  print(f'len(discovery_points) {len(discovery_points)}')
  discovery_points = list(filter(lambda p: poe_bot.game_data.terrain.checkIfPointPassable(p[0], p[1]), discovery_points))
  print(f'len(discovery_points) {len(discovery_points)} after sorting')
  print(f'discovery_points {discovery_points}')
  if len(discovery_points) == 0:
    print(f'len(discovery_points) == 0 after points generation')
    map_complete = True
    break
  point_to_go = discovery_points.pop(0)
  while point_to_go is not None:
    need_to_explore = poe_bot.helper_functions.needToExplore(point_to_go=point_to_go)
    if need_to_explore is True:
      print(f'exploring point {point_to_go}')
    else:
      print(f'surrounding around {point_to_go} discovered, skipping')
      try:
        point_to_go = discovery_points.pop(0)
      except:
        point_to_go = None
      continue

    # go to point to make it explored
    result = mover.goToPoint(
      point=point_to_go,
      min_distance=50,
      release_mouse_on_end=False,
      custom_break_function=runnerBreakFunction,
      step_size=random.randint(30,35)
    )
    # then, it result is True, False or None
    print(f"mover.goToPoint result {result}")


    # if we arrived to discovery point and nothing happened
    if result is None:
      while True:
        if len(discovery_points) == 0:
          point_to_go = None
          map_complete = True
          print(f'len(discovery_points) == 0, breaking')
          break

        point_to_go = discovery_points.pop(0)
        print(f'willing to explore next point {point_to_go}')
        need_to_explore = poe_bot.helper_functions.needToExplore(point_to_go=point_to_go)

        if need_to_explore is True:
          print(f'exploring point {point_to_go}')
          break
        else:
          print(f'surrounding around {point_to_go} discovered, skipping')
          continue
    
    # if explorer_break_function() is True:
    #   map_complete = True
    #   break

    poe_bot.refreshInstanceData()
    poe_bot.last_action_time = 0
  # if possible_transition to explore, go to it, run discovery again
# Out:
# generating pathing points
# 1735060259.0961373
# len(discovery_points) 29
# len(discovery_points) 29 after sorting
# discovery_points [(1590, 1155), (1437, 1243), (1446, 1050), (1260, 946), (1104, 994), (1078, 1154), (1254, 1172), (1175, 1324), (905, 1033), (748, 966), (873, 860), (1034, 841), (980, 644), (1119, 543), (1285, 497), (1443, 562), (1520, 734), (1353, 761), (1192, 706), (1595, 888), (720, 799), (563, 692), (388, 757), (270, 883), (201, 692), (290, 555), (457, 533), (568, 941), (486, 1103)]
# exploring point (1590, 1155)
# #goToPoint point: (1590, 1155), min_distance: 50, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: True, random_val: 1
# custom_break_function:<function runnerBreakFunction at 0x000001DFB6BAAA60>, custom_continue_function:None
# heist_transition: False, step_size: 32possible_transition: False
# #goToPoint point: [1488, 1168], min_distance: 50, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: False, random_val: 1
# custom_break_function:<function alwaysFalseFunction at 0x000001DFB5E9F790>, custom_continue_function:<bound method InfernalistZoomancer.usualRoutine of <utils.combat.InfernalistZoomancer object at 0x000001DFB6C2AAF0>>
# heist_transition: False, step_size: 32possible_transition: False
# end pos to go 1488 1168
# [Mover] distance_to_target: 200.47194317410106 at 1735060260.4681141
# [Mover] making step to (849, 668)
# [Mover] making first step, placing a mouse on (849, 668) and going
# [Controller] establishing connection with ('172.22.159.221', 50007)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=849&y=668&mtm=-1&msm=1&wtr=1& at 1735060260.5591137
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=849&y=668&mtm=-1&msm=1&wtr=1& at 1735060260.5611136
# [Controller] debug sending action=mousePress&x=849&y=668&button=left at 1735060260.5641124
# [Controller] debug recieved response for action=mousePress&x=849&y=668&button=left at 1735060260.68011
# [Mover] distance_to_target: 200.47194317410106 at 1735060260.7781203
# [Mover] making step to (849, 668)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=849&y=668&mtm=-1&msm=1&wtr=1& at 1735060260.783114
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=849&y=668&mtm=-1&msm=1&wtr=1& at 1735060260.784114
# [Mover] distance_to_target: 196.98730923589977 at 1735060260.9891138
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (865, 668)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=865&y=668&mtm=-1&msm=1&wtr=1& at 1735060261.014948
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=865&y=668&mtm=-1&msm=1&wtr=1& at 1735060261.0179474
# [Mover] distance_to_target: 190.79046097748179 at 1735060261.1885574
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (896, 668)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=896&y=668&mtm=-1&msm=1&wtr=1& at 1735060261.202552
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=896&y=668&mtm=-1&msm=1&wtr=1& at 1735060261.2045517
# [Mover] distance_to_target: 186.03763060198332 at 1735060261.368552
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (859, 668)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=859&y=668&mtm=-1&msm=1&wtr=1& at 1735060261.3905504
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=859&y=668&mtm=-1&msm=1&wtr=1& at 1735060261.3935509
# [Mover] distance_to_target: 178.5077029150283 at 1735060261.5281546
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (793, 668)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=793&y=668&mtm=-1&msm=1&wtr=1& at 1735060261.569151
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=793&y=668&mtm=-1&msm=1&wtr=1& at 1735060261.5701513
# [Mover] distance_to_target: 175.07141400011596 at 1735060261.684151
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (773, 668)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=773&y=668&mtm=-1&msm=1&wtr=1& at 1735060261.6951506
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=773&y=668&mtm=-1&msm=1&wtr=1& at 1735060261.6951506
# [Mover] distance_to_target: 169.62311163281967 at 1735060261.8321488
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (735, 668)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=735&y=668&mtm=-1&msm=1&wtr=1& at 1735060261.8421438
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=735&y=668&mtm=-1&msm=1&wtr=1& at 1735060261.8421438
# [Mover] distance_to_target: 164.01219466856725 at 1735060261.9871478
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (712, 668)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=712&y=668&mtm=-1&msm=1&wtr=1& at 1735060261.9981465
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000001DFB8ACB310>, <utils.gamehelper.Entity object at 0x000001DFB6F33D00>, <utils.gamehelper.Entity object at 0x000001DFB6F3EEB0>, <utils.gamehelper.Entity object at 0x000001DFB6F3E6A0>, <utils.gamehelper.Entity object at 0x000001DFB6F3E5E0>, <utils.gamehelper.Entity object at 0x000001DFB6F3D820>]
# angle 90, 1, 56, [1.615e+03 1.102e+03 1.000e+00], 56.0, 56.0
# angle 135, 0.75, 40, [1.599e+03 1.142e+03 1.000e+00], 56.568542494923804, 42.42640687119285
# angle 45, 0.75, 26, [1.585e+03 1.076e+03 1.000e+00], 36.76955262170048, 27.577164466275356
# angle 180, 0.5625, 56, [1.559e+03 1.158e+03 1.000e+00], 56.0, 31.5
# angle 0, 0.5625, 26, [1.559e+03 1.076e+03 1.000e+00], 26.0, 14.625
# angle 225, 0.421875, 40, [1.519e+03 1.142e+03 1.000e+00], 56.568542494923804, 23.86485386504598
# angle 315, 0.421875, 26, [1.533e+03 1.076e+03 1.000e+00], 36.76955262170048, 15.512155012279889
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=1042&y=229&mtm=-1&msm=1&wtr=1& at 1735060264.7661598
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=1042&y=229&mtm=-1&msm=1&wtr=1& at 1735060264.7671607
# [Mover] distance_to_target: 99.15644204992432 at 1735060264.9116192
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000001DFB8B4FFD0>, <utils.gamehelper.Entity object at 0x000001DFB8B54040>, <utils.gamehelper.Entity object at 0x000001DFB8B54640>, <utils.gamehelper.Entity object at 0x000001DFB8B4A340>, <utils.gamehelper.Entity object at 0x000001DFB8B4ABB0>]
# angle 90, 1, 54, [1.616e+03 1.102e+03 1.000e+00], 54.0, 54.0
# angle 135, 0.75, 39, [1.601e+03 1.141e+03 1.000e+00], 55.15432893255071, 41.36574669941304
# angle 45, 0.75, 26, [1.588e+03 1.076e+03 1.000e+00], 36.76955262170048, 27.577164466275356
# angle 180, 0.5625, 55, [1.562e+03 1.157e+03 1.000e+00], 55.0, 30.9375
# angle 0, 0.5625, 26, [1.562e+03 1.076e+03 1.000e+00], 26.0, 14.625
# angle 225, 0.421875, 39, [1.523e+03 1.141e+03 1.000e+00], 55.15432893255071, 23.268232518419833
# angle 315, 0.421875, 26, [1.536e+03 1.076e+03 1.000e+00], 36.76955262170048, 15.512155012279889
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=1032&y=235&mtm=-1&msm=1&wtr=1& at 1735060264.9176154
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=1032&y=235&mtm=-1&msm=1&wtr=1& at 1735060264.9196188
# [Mover] distance_to_target: 102.9417310909429 at 1735060265.0666203
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000001DFB8AF0370>, <utils.gamehelper.Entity object at 0x000001DFB8AE7F70>, <utils.gamehelper.Entity object at 0x000001DFB8AE76A0>, <utils.gamehelper.Entity object at 0x000001DFB8AE7AF0>, <utils.gamehelper.Entity object at 0x000001DFB8AE2250>, <utils.gamehelper.Entity object at 0x000001DFB8AE2F10>]
# angle 90, 1, 49, [1.616e+03 1.102e+03 1.000e+00], 49.0, 49.0
# angle 135, 0.75, 40, [1.607e+03 1.142e+03 1.000e+00], 56.568542494923804, 42.42640687119285
# angle 45, 0.75, 26, [1.593e+03 1.076e+03 1.000e+00], 36.76955262170048, 27.577164466275356
# angle 180, 0.5625, 57, [1.567e+03 1.159e+03 1.000e+00], 57.0, 32.0625
# angle 0, 0.5625, 26, [1.567e+03 1.076e+03 1.000e+00], 26.0, 14.625
# angle 225, 0.421875, 40, [1.527e+03 1.142e+03 1.000e+00], 56.568542494923804, 23.86485386504598
# angle 315, 0.421875, 26, [1.541e+03 1.076e+03 1.000e+00], 36.76955262170048, 15.512155012279889
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=1009&y=251&mtm=-1&msm=1&wtr=1& at 1735060265.0766196
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=1009&y=251&mtm=-1&msm=1&wtr=1& at 1735060265.0766196
# [Mover] distance_to_target: 107.61505470890214 at 1735060265.2287588
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000001DFB8A01CA0>, <utils.gamehelper.Entity object at 0x000001DFB8A05730>, <utils.gamehelper.Entity object at 0x000001DFB8A05CD0>, <utils.gamehelper.Entity object at 0x000001DFB8A09250>, <utils.gamehelper.Entity object at 0x000001DFB8A09100>]
# angle 90, 1, 43, [1.616e+03 1.102e+03 1.000e+00], 43.0, 43.0
# angle 135, 0.75, 35, [1.608e+03 1.137e+03 1.000e+00], 49.49747468305833, 37.123106012293746
# angle 45, 0.75, 26, [1.599e+03 1.076e+03 1.000e+00], 36.76955262170048, 27.577164466275356
# angle 180, 0.5625, 57, [1.573e+03 1.159e+03 1.000e+00], 57.0, 32.0625
# angle 0, 0.5625, 26, [1.573e+03 1.076e+03 1.000e+00], 26.0, 14.625
# angle 225, 0.421875, 40, [1.533e+03 1.142e+03 1.000e+00], 56.568542494923804, 23.86485386504598
# angle 315, 0.421875, 27, [1.546e+03 1.075e+03 1.000e+00], 38.18376618407357, 16.108776358906038
# [Controller] debug sending action=mouseSetCursorPosSmooth&x
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (875, 668)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=875&y=668&mtm=-1&msm=1&wtr=1& at 1735060270.1968555
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=875&y=668&mtm=-1&msm=1&wtr=1& at 1735060270.1968555
# [Mover] distance_to_target: 57.27128425310541 at 1735060270.3588583
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000001DFB8B4D3A0>]
# [Mover] making step to (913, 668)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=913&y=668&mtm=-1&msm=1&wtr=1& at 1735060270.3768606
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=913&y=668&mtm=-1&msm=1&wtr=1& at 1735060270.3778594
# [Mover] distance_to_target: 52.39274758971894 at 1735060270.5454652
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000001DFB8AF08E0>]
# [Generic summoner] need to raise srs, current count 9
# [Mover] making step to (923, 668)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=923&y=668&mtm=-1&msm=1&wtr=1& at 1735060270.554472
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=923&y=668&mtm=-1&msm=1&wtr=1& at 1735060270.5584705
# [Mover] distance_to_target: 44.77722635447623 at 1735060270.7214696
# 50 points to target, almost arrived player_pos: x:1506 y: 1127
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=916&y=647&mtm=-1&msm=1&wtr=1& at 1735060270.7254682
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=916&y=647&mtm=-1&msm=1&wtr=1& at 1735060270.726469
# #killUsualEntity {'ls': [228, 3369], 'p': 'Metadata/Monsters/BoneCultists/BoneCultist_Zealots/BoneCultistZealot02@67', 'r': 'Rare', 'i': 402, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1488, 1168], 'wp': [16197, 4598, -51], 'l': [67184, 67184, 0, 200, 200, 0, 2962, 2962, 0], 'rn': 'Lost-men Zealot', 'et': 'm', 'distance_to_player': 200.47194317410106}
# #build.killUsual {'ls': [228, 3369], 'p': 'Metadata/Monsters/BoneCultists/BoneCultist_Zealots/BoneCultistZealot02@67', 'r': 'Rare', 'i': 402, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1488, 1168], 'wp': [16197, 4598, -51], 'l': [67184, 67184, 0, 200, 200, 0, 2962, 2962, 0], 'rn': 'Lost-men Zealot', 'et': 'm', 'distance_to_player': 200.47194317410106}
# cannot find desired entity to kill
# mover.goToPoint result True
# exploring point (1590, 1155)
# #goToPoint point: (1590, 1155), min_distance: 50, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: True, random_val: 1
# custom_break_function:<function runnerBreakFunction at 0x000001DFB6BAAA60>, custom_continue_function:None
# heist_transition: False, step_size: 32possible_transition: False
# [LootPicker.collectLoot] call at 1735060270.8334744
# {'id': 722, 'a': 'Art/2DItems/Currency/Ruthless/CoinPileTier1.dds', 'l': None, 'r': None, 'gp': [1550, 1150], 'sz': [793, 840, 236, 255]}
# {'id': 744, 'a': 'Art/2DItems/Flasks/Basetypes/FlaskMana08.dds', 'l': None, 'r': 'Normal', 'gp': [1539, 1159], 'sz': [749, 893, 299, 318]}
# {'id': 745, 'a': 'Art/2DItems/Maps/EndgameMaps/EndgameMap2.dds', 'l': None, 'r': 'Magic', 'gp': [1575, 1134], 'sz': [782, 880, 111, 130]}
# {'id': 767, 'a': 'Art/2DItems/Gems/UncutSupportGem.dds', 'l': None, 'r': None, 'gp': [1524, 1126], 'sz': [530, 639, 240, 259]}
# {'id': 769, 'a': 'Art/2DItems/Weapons/TwoHandWeapons/Bows/Basetypes/Bow07.dds', 'l': None, 'r': 'Magic', 'gp': [1524, 1126], 'sz': [523, 646, 259, 278]}
# {'id': 770, 'a': 'Art/2DItems/Flasks/Basetypes/FlaskMana08.dds', 'l': None, 'r': 'Magic', 'gp': [1524, 1126], 'sz': [513, 657, 203, 222]}
# item label added to ignored {'id': 722, 'a': 'Art/2DItems/Currency/Ruthless/CoinPileTier1.dds', 'l': None, 'r': None, 'gp': [1550, 1150], 'sz': [793, 840, 236, 255]}
# item label added to ignored {'id': 744, 'a': 'Art/2DItems/Flasks/Basetypes/FlaskMana08.dds', 'l': None, 'r': 'Normal', 'gp': [1539, 1159], 'sz': [749, 893, 299, 318]}
# item label added to ignored {'id': 767, 'a': 'Art/2DItems/Gems/UncutSupportGem.dds', 'l': None, 'r': None, 'gp': [1524, 1126], 'sz': [530, 639, 240, 259]}
# item label added to ignored {'id': 769, 'a': 'Art/2DItems/Weapons/TwoHandWeapons/Bows/Basetypes/Bow07.dds', 'l': None, 'r': 'Magic', 'gp': [1524, 1126], 'sz': [523, 646, 259, 278]}
# item label added to ignored {'id': 770, 'a': 'Art/2DItems/Flasks/Basetypes/FlaskMana08.dds', 'l': None, 'r': 'Magic', 'gp': [1524, 1126], 'sz': [513, 657, 203, 222]}
# [LootPicker.collectLoot] start at 1735060270.8334744
# [LootPicker.collectLoot] pickable_items [<utils.loot_filter.PickableItemLabel object at 0x000001DFB951BA90>]
# [LootPicker.collectLoot] collectLootAt near {'id': 745, 'a': 'Art/2DItems/Maps/EndgameMaps/EndgameMap2.dds', 'l': None, 'r': 'Magic', 'gp': [1575, 1134], 'sz': [782, 880, 111, 130]} at 1735060270.8334744
# [LootPicker.collectLoot] going to clear nearby {'id': 745, 'a': 'Art/2DItems/Maps/EndgameMaps/EndgameMap2.dds', 'l': None, 'r': 'Magic', 'gp': [1575, 1134], 'sz': [782, 880, 111, 130]}
# #clearLocationAroundPoint around point {'X': 1575, 'Y': 1134} ignore_keys: []
# going to {'X': 1575, 'Y': 1134}
# #goToPoint point: [1575, 1134], min_distance: 40, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: True, random_val: 1
# custom_break_function:<function alwaysFalseFunction at 0x000001DFB5E9F790>, custom_continue_function:<bound method InfernalistZoomancer.usualRoutine of <utils.combat.InfernalistZoomancer object at 0x000001DFB6C2AAF0>>
# heist_transition: False, step_size: 27possible_transition: False
# end pos to go 1575 1134
# [Mover] distance_to_target: 71.02816342831905 at 1735060270.983469
# [Mover] making step to (973, 210)
# [Mover] making first step, placing a mouse on (973, 210) and going
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=973&y=210&mtm=-1&msm=1&wtr=1& at 1735060270.9894688
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=973&y=210&mtm=-1&msm=1&wtr=1& at 1735060270.9894688
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=973&y=210&mtm=-1&msm=1&wtr=1& at 1735060271.017468
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=973&y=210&mtm=-1&msm=1&wtr=1& at 1735060271.1424665
# [Mover] distance_to_target: 76.4198926981712 at 1735060271.2250562
# [Mover] making step to (925, 201)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=925&y=201&mtm=-1&msm=1&wtr=1& at 1735060271.2360585
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=925&y=201&mtm=-1&msm=1&wtr=1& at 1735060271.2360585
# [Mover] distance_to_target: 75.8023746329889 at 1735060271.4896502
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000001DFB8AE7610>]
# [Generic summoner] need to raise srs, current count 5
# [Skill flame_wall] using  at 1735060271.4916544
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=536&y=609&mtm=-1&msm=1&wtr=1& at 1735060271.4916544
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=536&y=609&mtm=-1&msm=1&wtr=1& at 1735060271.4916544
# [SkillWithDelay flame_wall]  can be used after 1735060273.7926512 1735060271.4926512 2.3
# [Skill flame_wall] successfully used  at 1735060271.4926512
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_Q&wtr=1& at 1735060271.4926512
# [Mover] distance_to_target: 65.49045732013177 at 1735060271.6856515
# calling usual routine
# nearby_enemies: []
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_Q&wtr=1& at 1735060271.6876538
# [Mover] making step to (933, 224)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=933&y=224&mtm=-1&msm=1&wtr=1& at 1735060271.6926513
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=933&y=224&mtm=-1&msm=1&wtr=1& at 1735060271.6926513
# ...
# [LootPicker.pickupDropV6] return at 1735060685.8472755
# calling usual routine
# [LootPicker.collectLoot] return at 1735060685.9012733
# mover.goToPoint result True
# exploring point (486, 1103)
# #goToPoint point: (486, 1103), min_distance: 50, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: True, random_val: 1
# custom_break_function:<function runnerBreakFunction at 0x000001DFB6BAAA60>, custom_continue_function:None
# heist_transition: False, step_size: 35possible_transition: False
# [LootPicker.collectLoot] call at 1735060685.9592686
# end pos to go 485 1102
# [Mover] distance_to_target: 641.1754829997791 at 1735060686.0342748
# [LootPicker.collectLoot] call at 1735060686.035274
# [Mover] making step to (1168, 641)
# [Mover] making first step, placing a mouse on (1168, 641) and going
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=1123&y=638&mtm=-1&msm=1&wtr=1& at 1735060692.5174701
# [Mover] distance_to_target: 411.0985283359696 at 1735060692.7296467
# [LootPicker.collectLoot] call at 1735060692.730645
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (1122, 641)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=1122&y=641&mtm=-1&msm=1&wtr=1& at 1735060692.7475896
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=1122&y=641&mtm=-1&msm=1&wtr=1& at 1735060692.7503629
# [Mover] distance_to_target: 404.10023509025575 at 1735060693.048504
# [LootPicker.collectLoot] call at 1735060693.0495045
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (1096, 625)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=1096&y=625&mtm=-1&msm=1&wtr=1& at 1735060693.0592186
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=1096&y=625&mtm=-1&msm=1&wtr=1& at 1735060693.0592186

# %%
# open portal and enter it
def openPortal():
  poe_bot.bot_controls.releaseAll()

  time.sleep(random.randint(40,80)/100)
  pos_x, pos_y = random.randint(709,711), random.randint(694,696)
  pos_x, pos_y = poe_bot.convertPosXY(pos_x, pos_y, safe=False)
  poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
  time.sleep(random.randint(40,80)/100)
  poe_bot.bot_controls.mouse.click()
  time.sleep(random.randint(30,60)/100)

while True:
  try:
    poe_bot.refreshInstanceData()
    killed_smth = poe_bot.combat_module.clearAreaAroundPoint(poe_bot.game_data.player.grid_pos.toList())
    if killed_smth == False:
      openPortal()
      poe_bot.helper_functions.waitForPortalNearby()
      poe_bot.helper_functions.getToPortal(check_for_map_device=False, refresh_area=False)
      poe_bot.refreshInstanceData()
      killed_smth = poe_bot.combat_module.clearAreaAroundPoint(poe_bot.game_data.player.grid_pos.toList())
      if killed_smth:
        continue
  except Exception as e:
    if e.__str__() == 'Area changed but refreshInstanceData was called before refreshAll':
      time.sleep(5)
      break
# Out:
# #clearLocationAroundPoint around point {'X': 821, 'Y': 557} ignore_keys: []
# going to {'X': 821, 'Y': 557}
# #goToPoint point: [821, 557], min_distance: 40, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: True, random_val: 1
# custom_break_function:<function alwaysFalseFunction at 0x0000028777DF0790>, custom_continue_function:<bound method InfernalistZoomancer.usualRoutine of <utils.combat.InfernalistZoomancer object at 0x0000028778B7DCD0>>
# heist_transition: False, step_size: 26possible_transition: False
# end pos to go 822 556
# useless call of gotopoint arrived = True
# [Controller] debug sending action=releaseAll at 1735059792.7405238
# [Controller] debug recieved response for action=releaseAll at 1735059792.7425241
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=982&y=745&mtm=-1&msm=1 at 1735059793.2747102
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=982&y=745&mtm=-1&msm=1 at 1735059793.406816
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735059793.9484432
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735059793.9694562
# [Controller] debug sending action=mouseRelease&button=left at 1735059794.0744615
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735059794.0754645
# #waitForNewPortals 1735059794.7037072
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# there is a portal nearby
# original_area_raw_name MapSeepage_NoBoss
# portal_to_enter {'ls': [512, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 121, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [769, 565], 'wp': [8384, 10634, -95], 'l': None, 'rn': 'Felled Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# getting into portal {'ls': [512, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 121, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [769, 565], 'wp': [8384, 10634, -95], 'l': None, 'rn': 'Felled Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# 785 349
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=785&y=349&mtm=-1&msm=1 at 1735059796.1019118
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=785&y=349&mtm=-1&msm=1 at 1735059796.2422607
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735059796.645911
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735059796.6619
# [Controller] debug sending action=mouseRelease&button=left at 1735059796.7738962
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735059796.7749126
# clicked on a portal {'ls': [512, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 121, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [769, 565], 'wp': [8384, 10634, -95], 'l': None, 'rn': 'Felled Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# portal_to_enter {'ls': [512, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 121, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [769, 565], 'wp': [8384, 10634, -95], 'l': None, 'rn': 'Felled Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# getting into portal {'ls': [512, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 121, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [769, 565], 'wp': [8384, 10634, -95], 'l': None, 'rn': 'Felled Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# 785 349
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=785&y=349&mtm=-1&msm=1 at 1735059798.531587
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=785&y=349&mtm=-1&msm=1 at 1735059798.5595865
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735059798.9595876
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735059798.974588
# [Controller] debug sending action=mouseRelease&button=left at 1735059799.084598
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735059799.0856018
# clicked on a portal {'ls': [512, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 121, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [769, 565], 'wp': [8384, 10634, -95], 'l': None, 'rn': 'Felled Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# portal_to_enter {'ls': [512, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 121, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [769, 565], 'wp': [8384, 10634, -95], 'l': None, 'rn': 'Felled Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# getting into portal {'ls': [512, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 121, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [769, 565], 'wp': [8384, 10634, -95], 'l': None, 'rn': 'Felled Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# 785 349
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=785&y=349&mtm=-1&msm=1 at 1735059801.1320472
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=785&y=349&mtm=-1&msm=1 at 1735059801.1600502
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735059801.5636032
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735059801.5806088
# [Controller] debug sending action=mouseRelease&button=left at 1735059801.7226233
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735059801.7236211
# clicked on a portal {'ls': [512, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 121, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [769, 565], 'wp': [8384, 10634, -95], 'l': None, 'rn': 'Felled Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# [Controller] debug sending action=releaseAll at 1735059802.4586146
# [Controller] debug recieved response for action=releaseAll at 1735059802.4606154
# Area changed but refreshInstanceData was called before refreshAll
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=349&y=111&mtm=-1&msm=1 at 1735059802.4606154
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=349&y=111&mtm=-1&msm=1 at 1735059802.5996013
# [Controller] debug sending action=releaseAll at 1735059802.608616
# [Controller] debug recieved response for action=releaseAll at 1735059802.608616

# %%
raise 404
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 raise 404
#
# TypeError: exceptions must derive from BaseException

# %%
prefer_high_tier = True

# %%
poe_bot.refreshAll()
# Out:
# [poebot] #refreshAll call at 1735060254.2004125

# %%
# pos_x, pos_y = random.randint(580,640), random.randint(408,409)
# pos_x, pos_y = poe_bot.convertPosXY(pos_x, pos_y)
# time.sleep(random.randint(20,80)/100)
# poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
# time.sleep(random.randint(20,80)/100)
# poe_bot.bot_controls.mouse.click()
# time.sleep(random.randint(30,60)/100)

# %%
start_time = time.time()

def destroyCorpse(corpse_entity:Entity):
  print(f'destroying corpse {corpse_entity.raw}')
  while True:
    poe_bot.refreshInstanceData()
    updated_corpse_entity = next( (e for e in poe_bot.game_data.entities.all_entities if e.id == corpse_entity.id), None)
    if updated_corpse_entity:
      if updated_corpse_entity.distance_to_player > 25:
        poe_bot.mover.goToEntitysPoint(updated_corpse_entity)
      else:
        if poe_bot.combat_module.build.detonate_dead:
          if poe_bot.combat_module.build.detonate_dead.use(updated_entity=updated_corpse_entity, force=True) != False:
            continue
        if poe_bot.combat_module.build.unearth and poe_bot.combat_module.build.unearth.canUse():
          if poe_bot.combat_module.build.unearth.use(updated_entity=updated_corpse_entity) != False:
            continue
    else:
      break
beetle_corpse = next( (e for e in poe_bot.game_data.entities.all_entities if e.render_name == "The Ninth Treasure of Keth"), None)
if beetle_corpse:
  destroyCorpse(beetle_corpse)

# %%
entity_to_run_around = None
if beetle_corpse:
  print(f'running around corpse {beetle_corpse}')
  entity_to_run_around = beetle_corpse
elif beetle_entity:
  print(f'running around entity {beetle_entity}')

  entity_to_run_around = beetle_entity

if entity_to_run_around:
  start_time = time.time()
  run_duration_seconds = 5
  end_at = start_time + run_duration_seconds
  kite_distance = 10
  reversed_run = random.choice([True, False])
  while time.time() < end_at:
    poe_bot.refreshInstanceData()
    poe_bot.combat_module.build.auto_flasks.useFlasks()  
    print('kiting')
    point = poe_bot.game_data.terrain.pointToRunAround(entity_to_run_around.grid_position.x, entity_to_run_around.grid_position.y, kite_distance+random.randint(-1,1), check_if_passable=True, reversed=reversed_run)
    poe_bot.mover.move(grid_pos_x = point[0], grid_pos_y = point[1])
else:
  poe_bot.refreshInstanceData()

# %%
poe_bot.loot_picker.collectLootWhilePresented()

# %%
def respawnAtCheckPoint():
  poe_bot.bot_controls.keyboard.tap('DIK_ESCAPE')
  time.sleep(random.randint(40,80)/100)
  pos_x, pos_y = random.randint(450,550), random.randint(289,290)
  pos_x, pos_y = poe_bot.convertPosXY(pos_x, pos_y)
  poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
  time.sleep(random.randint(40,80)/100)
  poe_bot.bot_controls.mouse.click()
  time.sleep(random.randint(30,60)/100)

  pos_x, pos_y = random.randint(580,640), random.randint(408,409)
  pos_x, pos_y = poe_bot.convertPosXY(pos_x, pos_y)
  time.sleep(random.randint(20,80)/100)
  poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
  time.sleep(random.randint(20,80)/100)
  poe_bot.bot_controls.mouse.click()
  time.sleep(random.randint(30,60)/100)
  return True
poe_bot.bot_controls.releaseAll()
respawnAtCheckPoint()
while True:
  poe_bot.refreshInstanceData()
  beetle_entity = next( (e for e in poe_bot.game_data.entities.all_entities if e.render_name == "The Ninth Treasure of Keth"), None)
  if beetle_entity:
    break

# %%
raise 404

# %%
poe_bot.refreshInstanceData()
poe_bot.loot_picker.collectLoot()

# %%
from utils.utils import getAngle

# %%
poe_bot.refreshAll()

# %%
poe_bot.refreshInstanceData()
map_device_entity = next( (e for e in poe_bot.game_data.entities.all_entities if e.path == "Metadata/Terrain/Missions/Hideouts/Objects/MapDeviceVariants/ZigguratMapDevice"), None)
map_device_entity.hover()
poe_bot.refreshInstanceData()
map_device_entity = next( (e for e in poe_bot.game_data.entities.all_entities if e.path == "Metadata/Terrain/Missions/Hideouts/Objects/MapDeviceVariants/ZigguratMapDevice"), None)
if map_device_entity.is_targeted == True:
  print('targeted')
  map_device_entity.click()

# %%
import time
while True:
  time.sleep(0.2)
  poe_bot.refreshInstanceData()
  player_pos = poe_bot.game_data.player.grid_pos.toList()
  p1 = player_pos
  p0 = (player_pos[0], player_pos[1]+50)

  for e in poe_bot.game_data.entities.all_entities:
    if e.id != 11:
      continue
    print(e.raw)
    print(getAngle(p0, p1, (e.grid_position.x, e.grid_position.y), abs_180=True))

# %%
poe_bot.refreshAll()
poe_bot.bot_controls.releaseAll()

our_pos = [poe_bot.game_data.player.grid_pos.x, poe_bot.game_data.player.grid_pos.y]
# entity pos
pos_x, pos_y = poe_bot.game_data.player.grid_pos.x, poe_bot.game_data.player.grid_pos.y

distance_to_point = 45

reversed = True
check_if_passable = True

# %%
import time
from math import dist

while True:
  time.sleep(0.2)
  poe_bot.refreshInstanceData()

  our_pos = [poe_bot.game_data.player.grid_pos.x, poe_bot.game_data.player.grid_pos.y]
  points_around = [
    [pos_x+distance_to_point,pos_y], # 90
    [int(pos_x+distance_to_point*0.7),int(pos_y-distance_to_point*0.7)], # 45
    [pos_x,pos_y-distance_to_point], # 0
    [int(pos_x-distance_to_point*0.7),int(pos_y-distance_to_point*0.7)], # 315
    [pos_x-distance_to_point,pos_y], # 270
    [int(pos_x-distance_to_point*0.7),int(pos_y+distance_to_point*0.7)], # 215
    [pos_x,pos_y+distance_to_point], # 180
    [int(pos_x+distance_to_point*0.7),int(pos_y+distance_to_point*0.7)], # 135
  ]
  if reversed is True:
    points_around.reverse()
  distances = list(map(lambda p: dist(our_pos, p),points_around))
  nearset_pos_index = distances.index(min(distances))
  distances = list(map(lambda p: dist(our_pos, p),points_around))
  nearset_pos_index = distances.index(min(distances))
  # TODO check if next point is passable
  current_pos_index = nearset_pos_index+1
  if current_pos_index > len(points_around)-1: current_pos_index -= len(points_around)
  point = points_around[current_pos_index]
  if check_if_passable is True:
    if poe_bot.game_data.terrain.checkIfPointPassable(point[0], point[1], radius=1) is False:
      start_index = current_pos_index+1
      point_found = False
      for i in range(len(points_around)-2):
        current_index = start_index + i
        if current_index > len(points_around)-1: current_index -= len(points_around)
        point = points_around[current_index]
        if poe_bot.game_data.terrain.checkIfPointPassable(point[0], point[1], radius=1) is True:
          point_found = True
          break
      if point_found is True:
        pass
  print(point)
  poe_bot.mover.move(point[0], point[1])

# %%
# move back or move to safe grid if enemies on a way
# map device
poe_bot.ui.map_device.update()

# %%
from utils.ui import MapDevice_Poe2
poe_bot.ui.map_device = MapDevice_Poe2(poe_bot)
poe_bot.ui.map_device.update()

# %%
raise 404

# %%
from utils.utils import sortByHSV
x1 = poe_bot.ui.map_device.activate_button_pos.x1 +5
x2 = poe_bot.ui.map_device.activate_button_pos.x2 -5
y1 = poe_bot.ui.map_device.activate_button_pos.y1 +5
y2 = poe_bot.ui.map_device.activate_button_pos.y2 -5
game_img = poe_bot.getImage()
activate_button_img = game_img[y1:y2, x1:x2]
# print('activate_button_img')
# plt.imshow(activate_button_img);plt.show()
# plt.imshow(third_skill);plt.show()
sorted_img = sortByHSV(activate_button_img, 0, 0, 0, 255, 30, 180)
# plt.imshow(sorted_img);plt.show()
activate_button_is_active = not len(sorted_img[sorted_img != 0]) > 30
# print(sorted_img[sorted_img != 0])
print(f"activate_button_is_active {activate_button_is_active}")

# %%
x1 = poe_bot.ui.map_device.activate_button_pos.x1 +5
x2 = poe_bot.ui.map_device.activate_button_pos.x2 -5
y1 = poe_bot.ui.map_device.activate_button_pos.y1 +5
y2 = poe_bot.ui.map_device.activate_button_pos.y2 -5
game_img = poe_bot.getImage()
active_button = game_img[y1:y2, x1:x2]

# %%
x1 = poe_bot.ui.map_device.activate_button_pos.x1 +5
x2 = poe_bot.ui.map_device.activate_button_pos.x2 -5
y1 = poe_bot.ui.map_device.activate_button_pos.y1 +5
y2 = poe_bot.ui.map_device.activate_button_pos.y2 -5
game_img = poe_bot.getImage()
inactive_button = game_img[y1:y2, x1:x2]

# %%
active_sorted_img = sortByHSV(active_button, 0,0,0, 255, 30, 180)
plt.imshow(active_sorted_img);plt.show()
inactive_sorted_img = sortByHSV(inactive_button, 0,0,0, 255, 30, 180)
plt.imshow(inactive_sorted_img);plt.show()

# %%
raise 404

# %%
from utils.ui import MapDevice_Poe2
poe_bot.ui.map_device = MapDevice_Poe2(poe_bot)
poe_bot.ui.map_device.update()
map_obj = random.choice(poe_bot.ui.map_device.avaliable_maps)
print(map_obj.raw)
poe_bot.ui.map_device.moveScreenTo(map_obj)
time.sleep(random.uniform(0.15, 0.35))
poe_bot.ui.map_device.update()
updated_map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == map_obj.id))
time.sleep(random.uniform(0.15, 0.35))
updated_map_obj.hover()
time.sleep(random.uniform(0.15, 0.35))
updated_map_obj.click()

# %%
poe_bot.ui.map_device.update()
updated_map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == map_obj.id))
time.sleep(random.uniform(0.15, 0.35))
updated_map_obj.hover()
time.sleep(random.uniform(0.15, 0.35))
updated_map_obj.click()

# %%
poe_bot.ui.map_device.update()
# find a map to go
# for map_obj in poe_bot.ui.map_device.avaliable_maps[0:1]:
map_obj = random.choice(poe_bot.ui.map_device.avaliable_maps)
print(f'going to drag to {map_obj.id}')
orig_id = map_obj.id
while True:
  poe_bot.ui.map_device.update()
  if poe_bot.ui.map_device.is_opened == False:
    raise poe_bot.raiseLongSleepException('map device closed during dragging to map object')
  map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == orig_id))

  poe_bot.ui.inventory.update()
  x_center = poe_bot.game_window.center_point[0]
  borders = poe_bot.game_window.borders[:]
  borders[2] = 80
  if poe_bot.ui.inventory.is_opened:
    borders[1] = 545
    x_center = int(x_center)/2
  roi_borders = [
    int((borders[0] + borders[1])/2 - 100),
    int((borders[0] + borders[1])/2 + 100),
    int((borders[2] + borders[3])/2 - 150),
    int((borders[2] + borders[3])/2 + 50),
  ]

  if poe_bot.game_window.isInRoi(map_obj.screen_pos.x, map_obj.screen_pos.y, custom_borders=roi_borders):
    break
  print(f"map_obj.screen_pos {map_obj.screen_pos.toList()}")
  drag_from = poe_bot.game_window.convertPosXY(map_obj.screen_pos.x, map_obj.screen_pos.y, custom_borders=borders)
  # ignore the inventory panel if it's opened
  if poe_bot.ui.inventory.is_opened == True:
    print('inventory is opened, different borders and roi')
  drag_to = poe_bot.game_window.convertPosXY(x_center, poe_bot.game_window.center_point[1], custom_borders=borders)
  poe_bot.bot_controls.mouse.drag(drag_from, drag_to)
  time.sleep(random.uniform(0.15, 0.35))
# map_obj.click()
# time.sleep(random.uniform(0.15, 0.35))

# %%
poe_bot.refreshAll()

# %%
player_pos = poe_bot.game_data.player.grid_pos.toList()
pos_to_go = [player_pos[0]+3, player_pos[1]-50]
print(player_pos, pos_to_go)

# %%
from utils.utils import angleOfLine, pointOnCircleByAngleAndLength, createLineIteratorWithValues

def findBackwardsPoint(current_point, point_to_go):
  next_angle = angleOfLine(current_point, point_to_go)
  distance = math.dist(current_point, point_to_go)
  backwards_angle_raw = next_angle - 180
  if backwards_angle_raw < 0:
    backwards_angle_raw += 360
  if backwards_angle_raw == 360:
    backwards_angle_raw = 0
  angle_mult = backwards_angle_raw // 45
  angle_leftover = backwards_angle_raw % 45
  if angle_leftover > 22.5:
    angle_mult += 1

  backwards_angle = int(angle_mult * 45)
  if backwards_angle == 360:
    backwards_angle = 0
  backwards_angle
  backwards_angles = [backwards_angle]
  for _i in [-1,1]:
    branch = backwards_angle + 45 * _i
    if branch < 0:
      branch += 360
    if branch > 360:
      branch -= 360
    if branch == 360:
      branch = 0
    backwards_angles.append(branch)

  furthest_point = current_point
  furthest_point_distance = 0
  for angle in backwards_angles:
    line_end = pointOnCircleByAngleAndLength(angle, distance, current_point)
    line_points_vals = createLineIteratorWithValues(current_point, line_end, poe_bot.game_data.terrain.passable)
    length = 0
    last_point = line_points_vals[0]
    for point in line_points_vals:
      if point[2] != 1:
        break
      last_point = point 
      length += 1
    dist_to_last_point = math.dist(current_point, (last_point[0], last_point[1]))
    if furthest_point_distance < dist_to_last_point:
      furthest_point_distance = dist_to_last_point
      furthest_point = [int(last_point[0]), int(last_point[1])]
    print(f"angle {angle} {length}, {last_point}, {dist_to_last_point}")
  return furthest_point
findBackwardsPoint(player_pos, pos_to_go)
