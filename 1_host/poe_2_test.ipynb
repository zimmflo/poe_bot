# %%
import time
import random
import sys
from ast import literal_eval

from utils.gamehelper import Poe2Bot

# %%
from typing import List

# %%
notebook_dev = False
# readability
poe_bot_class = Poe2Bot
poe_bot: poe_bot_class

# %%
default_config = {
  "REMOTE_IP": '172.23.107.65', # z2
  "unique_id": "poe_2_test",
  "build": "EaBallistasEle",
  "password": None,
  "max_lvl": 101,
  "chromatics_recipe": True,
  "force_reset_temp": False,
}



try:
  i = sys.argv[1]
  print(i)
  parsed_config = literal_eval(i)
  print(f'successfully parsed cli config')
  print(f'parsed_config: {parsed_config}')
except:
  print(f'cannot parse config from cli, using default\dev one')
  notebook_dev = True
  parsed_config = default_config
  parsed_config['unique_id'] = poe_bot_class.getDevKey()

config = {

}

for key in default_config.keys():
  config[key] = parsed_config.get(key, default_config[key])

print(f'config to run {config}')
# Out:
# --f=c:\Users\1\AppData\Roaming\jupyter\runtime\kernel-v2-19196AKK57lODy4kJ.json
# cannot parse config from cli, using default\dev one
# config to run {'REMOTE_IP': '172.23.107.65', 'unique_id': '7d1165934e24534a1ba5', 'build': 'EaBallistasEle', 'password': None, 'max_lvl': 101, 'chromatics_recipe': True, 'force_reset_temp': False}

# %%
REMOTE_IP = config['REMOTE_IP'] # REMOTE_IP
UNIQUE_ID = config['unique_id'] # unique id
MAX_LVL = config.get('max_lvl')
CHROMATICS_RECIPE = config['chromatics_recipe']
BUILD_NAME = config['build'] # build_name
password = config['password']
force_reset_temp = config['force_reset_temp']
print(f'running aqueduct using: REMOTE_IP: {REMOTE_IP} unique_id: {UNIQUE_ID} max_lvl: {MAX_LVL} chromatics_recipe: {CHROMATICS_RECIPE} force_reset_temp: {force_reset_temp}')
# Out:
# running aqueduct using: REMOTE_IP: 172.23.107.65 unique_id: 7d1165934e24534a1ba5 max_lvl: 101 chromatics_recipe: True force_reset_temp: False

# %%
poe_bot = Poe2Bot(unique_id = UNIQUE_ID, remote_ip = REMOTE_IP, password=password)
poe_bot.refreshAll()
# poe_bot.game_data.terrain.getCurrentlyPassableArea()
# Out:
# [Controller] establishing connection with ('172.23.107.65', 50007)
# [temp] loaded from file AfkTempData
# [temp] loaded from file StashTempData
# build is not assigned, using any functions may throw errors
# poe bot, v: 3.25.15 init at 1736595026.1332445
# [temp] loaded from file StashTempData
# [poebot] #refreshAll call at 1736595026.1362448

# %%
from utils.loot_filter import PickableItemLabel

ARTS_TO_PICK = [
  "Art/2DItems/Currency/CurrencyModValues.dds", # divine
  "Art/2DItems/Currency/CurrencyGemQuality.dds", # gemcutter
  "Art/2DItems/Currency/CurrencyRerollRare.dds", # chaos
  "Art/2DItems/Currency/CurrencyAddModToRare.dds", # exalt
  "Art/2DItems/Currency/CurrencyUpgradeToUnique.dds", # chance
]

# big piles of gold
for tier in range(2,17):
  ARTS_TO_PICK.append(f"Art/2DItems/Currency/Ruthless/CoinPileTier{tier}.dds")
# waystones
for tier in range(1,17):
  ARTS_TO_PICK.append(f"Art/2DItems/Maps/EndgameMaps/EndgameMap{tier}.dds")

# "Art/2DItems/Currency/Essence/GreaterFireEssence.dds"

def isItemHasPickableKey(item_label:PickableItemLabel):
  if item_label.icon_render in ARTS_TO_PICK:
    return True
  elif "Art/2DItems/Currency/Essence/" in item_label.icon_render:
    return True
  return False
poe_bot.loot_picker.loot_filter.special_rules = [isItemHasPickableKey]

# %%
poe_bot.mover.setMoveType('wasd')

# %%
from utils.combat import PathfinderPoisonConc2
from utils.combat import InfernalistZoomancer
from utils.combat import GenericBuild2
from utils.combat import GenericBuild2Cautious

# poe_bot.combat_module.build = InfernalistZoomancer(poe_bot=poe_bot)
# poe_bot.combat_module.build = PathfinderPoisonConc2(poe_bot=poe_bot)
poe_bot.combat_module.build = GenericBuild2(poe_bot=poe_bot)
# poe_bot.combat_module.build = GenericBuild2Cautious(poe_bot=poe_bot)
poe_bot.combat_module.build.auto_flasks.life_flask_recovers_es = True
poe_bot.combat_module.build.auto_flasks.hp_thresh = 0.70

def activateSwitchesNearby():
  switch_nearby = next( (e for e in poe_bot.game_data.entities.all_entities if e.is_targetable and e.path == "Metadata/Terrain/Maps/Crypt/Objects/CryptSecretDoorSwitch" and e.distance_to_player < 30), None)
  if switch_nearby:
    poe_bot.mover.goToEntitysPoint(switch_nearby)
    poe_bot.combat_module.clearAreaAroundPoint(switch_nearby.grid_position.toList())
    switch_nearby.clickTillNotTargetable()
    return True
  return False

def custom_default_continue_function(*args, **kwargs):
  pass

poe_bot.mover.default_continue_function = poe_bot.combat_module.build.usualRoutine
# Out:
# [GenericBuild2] main attacking skill spark

# %%
# raise 404

# %%
# Ы

# %%
# poe_bot.backend.getVisibleLabels()

# %%
# raise 404

# %%
from utils.encounters import EssenceEncounter, BreachEncounter, RitualEncounter
from utils.constants import ESSENCES_KEYWORD

class MapArea:
  boss_render_names:List[str] = []

class MapBackwash(MapArea):
  boss_render_names = ["Yaota, the Loathsome"]

# settings
rares_detection_radius = 999
prefer_high_tier = True
alch_map_if_possible = True

maps_to_ignore = [
  "MapCrypt_NoBoss", # activators
  "MapAugury_NoBoss", # activators
  "MapLostTowers"
]


# cache
ritual_ignore_ids = []


def isMapCompleted():
  poe_bot.game_data.map_info.update()
  if poe_bot.game_data.map_info.map_completed == True:
    print(f'poe_bot.game_data.map_info.map_completed == True')
    return True
  return False

def seekForEssences(search_loc = None):
  '''
  search_loc: [gridx,gridy]
  '''
  essences = list(filter(lambda e: e.is_targetable is True and ESSENCES_KEYWORD in e.path and poe_bot.game_data.terrain.checkIfPointPassable(e.grid_position.x, e.grid_position.y), poe_bot.game_data.entities.all_entities))
  return essences

def seekForBreaches():
  return next( (e for e in poe_bot.game_data.entities.all_entities if e.path == "Metadata/MiscellaneousObjects/Breach/BreachObject"), None)

def seekForRituals():
  return next( (e for e in poe_bot.game_data.entities.all_entities if e.path == "Metadata/Terrain/Leagues/Ritual/RitualRuneInteractable" and not e.id in ritual_ignore_ids), None)


def runnerBreakFunction(*args, **kwargs):

  '''crypt map'''
  if activateSwitchesNearby() == True:
    return True
  '''crypt map'''

  if rares_detection_radius != 0:
    rares_nearby = list(filter(lambda e: e.distance_to_player < rares_detection_radius, poe_bot.game_data.entities.attackable_entities_rares))
    print(f'found rares {list(map(lambda e: e.raw, rares_nearby))}')
    for rare_mob in rares_nearby:
      updated_entity = list(filter(lambda e: e.id == rare_mob.id, poe_bot.game_data.entities.attackable_entities_rares))
      if len(updated_entity) != 0:
        updated_entity = updated_entity[0]
        print(f'going to kill rare {updated_entity.raw}')
        def custom_continue_func(*args, **kwargs):
          if activateSwitchesNearby() == True:
            return True
          if poe_bot.loot_picker.collectLoot() == True:
            return True
          return False
        # while True:
        #   res = poe_bot.mover.goToEntitysPoint(updated_entity,custom_break_function=custom_continue_func, min_distance=50)
        #   if res is None:
        #     break
        poe_bot.combat_module.killUsualEntity(updated_entity)
        return True
  essences = seekForEssences()
  if len(essences) != 0:
    essence_encounter = EssenceEncounter(poe_bot, essences[0])
    essence_encounter.doEncounter()
    poe_bot.loot_picker.collectLoot()
    return True

  breach_entity = seekForBreaches()
  if breach_entity:
    BreachEncounter(poe_bot, breach_entity).doEncounter()
    return True

  ritual_entity = seekForRituals()
  if ritual_entity:
    poe_bot.mover.goToEntitysPoint(ritual_entity, min_distance=100)
    poe_bot.game_data.minimap_icons.update()
    corresponding_icon = next( (i for i in poe_bot.game_data.minimap_icons.icons if i.id == ritual_entity.id), None)
    if not corresponding_icon:
      poe_bot.mover.goToEntitysPoint(ritual_entity, min_distance=50)
    poe_bot.game_data.minimap_icons.update()
    corresponding_icon = next( (i for i in poe_bot.game_data.minimap_icons.icons if i.id == ritual_entity.id), None)
    if not corresponding_icon:
      print('ritual minimap icon is not in hud, ignoring')
      ritual_ignore_ids.append(ritual_entity.id)
      return True
    if corresponding_icon.name == "RitualRuneFinished":
      print('according to minimap icon data, ritual is finished')
      ritual_ignore_ids.append(ritual_entity.id)
      return True
    RitualEncounter(poe_bot, ritual_entity).doEncounter()
    # check if we did 3 of 3 or 4of4 rituals, if true, defer\whatever items
    ritual_ignore_ids.append(ritual_entity.id)
    return True

    

  loot_collected = poe_bot.loot_picker.collectLoot()
  if loot_collected is True:
    return loot_collected
  return False

# %%
# raise 404
poe_bot.refreshAll()
# Out:
# [poebot] #refreshAll call at 1736595027.2773392

# %%
# free inventory if neededS
poe_bot.ui.inventory.update()
empty_slots = poe_bot.ui.inventory.getEmptySlots()
if len(empty_slots) < 40:
  poe_bot.ui.stash.open()
  items_to_keep = []
  poe_bot.ui.inventory.update()
  waystones_to_keep = list(filter(lambda i: i.map_tier, poe_bot.ui.inventory.items))
  waystones_to_keep.sort(key=lambda i: i.map_tier, reverse=prefer_high_tier)
  items_to_keep.extend(waystones_to_keep[:4])
  alchemy_orbs = list(filter(lambda i: i.name == "Orb of Alchemy", poe_bot.ui.inventory.items))
  items_to_keep.extend(alchemy_orbs[:1])
  items_can_stash = list(filter(lambda i: i not in items_to_keep, poe_bot.ui.inventory.items))
  poe_bot.ui.clickMultipleItems(items_can_stash)
  poe_bot.ui.closeAll()
  time.sleep(random.uniform(0.3, 1.4))
# Out:
# [ui.Stash.open] call 1736595028.2062156
# no items getOpenedStashInfo
# [ui.Stash.open] no stash_box nearby
# looking to town portals nearby
# relogging through char select screen
# [Controller] debug sending action=releaseAll at 1736595028.259213
# [Controller] debug recieved response for action=releaseAll at 1736595028.2622151
# getting to char selection screen from game
# [Controller] debug sending action=releaseAll at 1736595028.2622151
# [Controller] debug recieved response for action=releaseAll at 1736595028.263217
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_SPACE&wtr=1& at 1736595028.263217
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_SPACE&wtr=1& at 1736595028.264213
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_SPACE&wtr=1& at 1736595028.3482158
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_SPACE&wtr=1& at 1736595028.3482158
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_SPACE&wtr=1& at 1736595028.519645
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_SPACE&wtr=1& at 1736595028.525644
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_SPACE&wtr=1& at 1736595028.674573
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_SPACE&wtr=1& at 1736595028.674573
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_SPACE&wtr=1& at 1736595028.8295674
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_SPACE&wtr=1& at 1736595028.83457
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_SPACE&wtr=1& at 1736595028.9085739
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_SPACE&wtr=1& at 1736595028.9085739
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_SPACE&wtr=1& at 1736595028.9855642
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_SPACE&wtr=1& at 1736595028.9865646
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_SPACE&wtr=1& at 1736595029.1395643
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_SPACE&wtr=1& at 1736595029.1425676
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 5
#       3 empty_slots = poe_bot.ui.inventory.getEmptySlots()
#       4 if len(empty_slots) < 40:
# ----> 5   poe_bot.ui.stash.open()
#       6   items_to_keep = []
#       7   poe_bot.ui.inventory.update()
#
# File c:\p2\1_host\utils\ui.py:1643, in Stash.open(self)
#    1641 if stash_box is None:
#    1642   print(f'[ui.Stash.open] no stash_box nearby')
# -> 1643   self.poe_bot.helper_functions.enterNearestPortal()
#    1644 if self.is_opened is not True:
#    1645   print(f'[ui.Stash.open] opening stash_box: {stash_box.raw}')
#
# File c:\p2\1_host\utils\helper_functions.py:576, in HelperFunctions.enterNearestPortal(self)
#     574     raise Exception('got into map area by accident')
#     575 else:
# --> 576   self.poe_bot.helper_functions.relog()
#     577   self.poe_bot.helper_functions.getToHideout()
#     578   raise Exception("was not not nearby map device on mapdevice.open, relogged")
#
# File c:\p2\1_host\utils\helper_functions.py:269, in HelperFunctions.relog(self)
#     268 def relog(self):
# --> 269   self.relogThroughCharSelectionScreen()
#
# File c:\p2\1_host\utils\helper_functions.py:274, in HelperFunctions.relogThroughCharSelectionScreen(self)
#     272 bot_controls = self.poe_bot.bot_controls
#     273 bot_controls.releaseAll()
# --> 274 self.getToCharSelectionFromGame()
#     275 self.getIntoWorldFromCharSelection()
#     276 raise Exception('logged in, success')
#
# File c:\p2\1_host\utils\helper_functions.py:200, in HelperFunctions.getToCharSelectionFromGame(self, close_all_ui)
#     198 if close_all_ui:
#     199   for _i in range(random.randint(2,4)):
# --> 200     self.poe_bot.ui.closeAll()
#     201 bot_controls.keyboard.tap('DIK_ESCAPE')
#     202 time.sleep(random.randint(20,40)/100)
#
# File c:\p2\1_host\utils\ui.py:177, in Ui.closeAll(self)
#     175 self.incursion_ui.visible = False
#     176 bot_controls.keyboard.tap('DIK_SPACE')
# --> 177 time.sleep(random.randint(5,20)/100)
#
# KeyboardInterrupt:

# %%
# open map device
poe_bot.ui.map_device.open()
# move to map, open dropdown
poe_bot.ui.map_device.update()
possible_to_run_maps = list(filter(lambda m: 
  m.is_boss == False and # some bosses have unique logic?
  m.is_tower == False and# cant run tower maps yet
  m.is_hideout == False and# hideouts ignored
  m.is_trader == False and# manual trade
  m.is_ritual == False and# save rituals for tests
  (m.name_raw in maps_to_ignore) == False
, poe_bot.ui.map_device.avaliable_maps))
map_obj = random.choice(possible_to_run_maps)
print(map_obj.raw)
poe_bot.ui.map_device.moveScreenTo(map_obj)
time.sleep(random.uniform(0.15, 0.35))


poe_bot.ui.map_device.update()


updated_map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == map_obj.id))
updated_map_obj.click()
time.sleep(random.uniform(0.15, 0.35))
poe_bot.ui.map_device.update()
if poe_bot.ui.map_device.place_map_window_opened == False:
  print(f'dropdown didnt open')
  pos_x, pos_y = poe_bot.game_window.convertPosXY(100, 100)
  poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
  time.sleep(random.uniform(0.15, 0.35))
  poe_bot.ui.map_device.update()
  updated_map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == map_obj.id))
  updated_map_obj.click()
  time.sleep(random.uniform(0.15, 0.35))
  poe_bot.ui.map_device.update()
  if poe_bot.ui.map_device.place_map_window_opened == False:
    print(f'seems like map device bug')
    poe_bot.raiseLongSleepException("cant open dropdown for map device")

# %%
poe_bot.ui.map_device.update()
for m in poe_bot.ui.map_device.avaliable_maps:
  print(m.raw)

# %%
if poe_bot.ui.map_device.place_map_window_opened != True:
  poe_bot.raiseLongSleepException("cant open dropdown for map device")

# %%
# screen_pos_x, screen_pos_y = poe_bot.game_window.center_point
# pos_x, pos_y = poe_bot.game_window.convertPosXY(screen_pos_x, screen_pos_y)
# poe_bot.bot_controls.mouse.setPos(pos_x, pos_y)


# poe_bot.ui.map_device.update()
# updated_map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == map_obj.id))

# screen_pos_x, screen_pos_y = updated_map_obj.screen_pos.toList()
# pos_x, pos_y = poe_bot.game_window.convertPosXY(screen_pos_x, screen_pos_y)
# # poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
# poe_bot.bot_controls.mouse.setPos(pos_x, pos_y)

# %%
if len(poe_bot.ui.map_device.place_map_window_items) > 1:
  poe_bot.raiseLongSleepException('placed more than 1 map already')
elif len(poe_bot.ui.map_device.place_map_window_items) == 0:
  poe_bot.ui.inventory.update()
  maps_in_inventory = list(filter(lambda i: i.map_tier, poe_bot.ui.inventory.items))
  maps_in_inventory.sort(key=lambda i: i.map_tier, reverse=prefer_high_tier)
  map_to_run = maps_in_inventory[0]
  print(f'placing map {map_to_run.raw}')

  if alch_map_if_possible == True:
    ARTS_TO_PICK.append("Art/2DItems/Currency/CurrencyUpgradeToRare.dds")
    for _i in range(1):
      if map_to_run.rarity != "Normal":
        break
      alchemy_orbs = list(filter(lambda i: i.name == "Orb of Alchemy", poe_bot.ui.inventory.items))
      if len(alchemy_orbs) == 0:
        break
      alchemy_orb = alchemy_orbs[0]
      alchemy_orb.click(button="right")
      time.sleep(random.uniform(0.4, 1.2))
      map_to_run.click()
      time.sleep(random.uniform(0.8, 1.2))

  map_to_run.click(hold_ctrl=True)

# %%
poe_bot.ui.map_device.update()
#TODO sometimes activate button is outside roi
poe_bot.ui.map_device.checkIfActivateButtonIsActive()

# %%
poe_bot.ui.map_device.activate()

time.sleep(random.uniform(0.8, 1.6))
poe_bot.helper_functions.waitForNewPortals()

# %%
poe_bot.refreshInstanceData()
original_area_raw_name = poe_bot.game_data.area_raw_name
poe_bot.helper_functions.getToPortal(check_for_map_device=False, refresh_area=True)
area_changed = False
while area_changed != True:
  poe_bot.refreshAll()
  area_changed = poe_bot.game_data.area_raw_name != original_area_raw_name

# %%
# raise 404

# %%
from utils.pathing import TSP


tsp = TSP(poe_bot=poe_bot)
# tsp.generatePointsForDiscovery()
mover = poe_bot.mover
map_complete = False
while map_complete is False:
  poe_bot.refreshInstanceData()
  print(f'generating pathing points')
  tsp.generatePointsForDiscovery()
  #TODO astar sorting
  discovery_points = tsp.sortedPointsForDiscovery(add_start_point_weight=True)
  print(f'len(discovery_points) {len(discovery_points)}')
  discovery_points = list(filter(lambda p: poe_bot.game_data.terrain.checkIfPointPassable(p[0], p[1]), discovery_points))
  print(f'len(discovery_points) {len(discovery_points)} after sorting')
  print(f'discovery_points {discovery_points}')
  if len(discovery_points) == 0:
    print(f'len(discovery_points) == 0 after points generation')
    map_complete = True
    break
  point_to_go = discovery_points.pop(0)
  while point_to_go is not None:
    need_to_explore = poe_bot.helper_functions.needToExplore(point_to_go=point_to_go)
    if need_to_explore is True:
      print(f'exploring point {point_to_go}')
    else:
      print(f'surrounding around {point_to_go} discovered, skipping')
      try:
        point_to_go = discovery_points.pop(0)
      except:
        point_to_go = None
      continue

    # go to point to make it explored
    result = mover.goToPoint(
      point=point_to_go,
      min_distance=50,
      release_mouse_on_end=False,
      custom_break_function=runnerBreakFunction,
      step_size=random.randint(30,35)
    )
    # then, it result is True, False or None
    print(f"mover.goToPoint result {result}")


    # if we arrived to discovery point and nothing happened
    if isMapCompleted() == True:
      map_complete = True
      break
    if result is None:
      while True:
        if len(discovery_points) == 0:
          point_to_go = None
          map_complete = True
          print(f'len(discovery_points) == 0, breaking')
          break

        point_to_go = discovery_points.pop(0)
        print(f'willing to explore next point {point_to_go}')
        need_to_explore = poe_bot.helper_functions.needToExplore(point_to_go=point_to_go)

        if need_to_explore is True:
          print(f'exploring point {point_to_go}')
          break
        else:
          print(f'surrounding around {point_to_go} discovered, skipping')
          continue
    
    # if explorer_break_function() is True:
    #   map_complete = True
    #   break

    poe_bot.refreshInstanceData()
    poe_bot.last_action_time = 0
  # if possible_transition to explore, go to it, run discovery again
# Out:
# generating pathing points
# 1736595038.7034967
# len(discovery_points) 42
# len(discovery_points) 42 after sorting
# discovery_points [(1443, 562), (1232, 685), (1440, 791), (1585, 698), (1666, 556), (1731, 788), (1581, 889), (1385, 952), (1153, 901), (1095, 1095), (1263, 1119), (1555, 1058), (1503, 1220), (1699, 1152), (1865, 1023), (1941, 876), (1228, 1285), (1387, 1380), (1172, 1503), (981, 1297), (822, 1359), (964, 1470), (1013, 1651), (1238, 1714), (1396, 1677), (1610, 1581), (1722, 1712), (1515, 1797), (1351, 1844), (1170, 1902), (1003, 1917), (891, 1786), (758, 1511), (651, 1380), (470, 1308), (488, 1584), (755, 1674), (569, 1735), (401, 1734), (1185, 2110), (1637, 1941), (1868, 1802)]
# exploring point (1443, 562)
# #goToPoint point: (1443, 562), min_distance: 50, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: True, random_val: 1
# custom_break_function:<function runnerBreakFunction at 0x00000203F6AA3A60>, custom_continue_function:None
# heist_transition: False, step_size: 31possible_transition: False
# found rares [{'ls': [-502, 4995], 'p': 'Metadata/Monsters/GoreCharger/GoreCharger@35', 'r': 'Rare', 'i': 2256, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1169, 759], 'wp': [12757, 18051, -49], 'l': [16229, 16229, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Diretusk Boar', 'et': 'm', 'distance_to_player': 231.8145810772049}]
# going to kill rare {'ls': [-502, 4995], 'p': 'Metadata/Monsters/GoreCharger/GoreCharger@35', 'r': 'Rare', 'i': 2256, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1169, 759], 'wp': [12757, 18051, -49], 'l': [16229, 16229, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Diretusk Boar', 'et': 'm', 'distance_to_player': 231.8145810772049}
# #killUsualEntity {'ls': [-502, 4995], 'p': 'Metadata/Monsters/GoreCharger/GoreCharger@35', 'r': 'Rare', 'i': 2256, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1169, 759], 'wp': [12757, 18051, -49], 'l': [16229, 16229, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Diretusk Boar', 'et': 'm', 'distance_to_player': 231.8145810772049}
# [build.killUsual] getting closer in killUsual
# getting closer to entity
# #goToPoint point: [1169, 759], min_distance: 100, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: False, random_val: 1
# custom_break_function:<function alwaysFalseFunction at 0x00000203F5052AF0>, custom_continue_function:<bound method GenericBuild2Chicken.usualRoutine of <utils.combat.GenericBuild2Chicken object at 0x00000203F8D7B3D0>>
# heist_transition: False, step_size: 31possible_transition: False
# end pos to go 1169 759
# [Mover.goToPoint] len(path): 325
# [Mover] distance_to_target: 231.8145810772049 at 1736595041.5765097
# [pather.cropPath] point [ 625 1305] 54 is reachable in 325
# [Mover] making step to (400, 662)
# [Mover] making first step, placing a mouse on (400, 662) and going
# [Controller] debug sending action=mouseSetCursorPosSmooth&x
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_F&wtr=1& at 1736595044.6487994
# [Mover] making step to (715, 668)
# [Mover.moveWASD] gonna move by angle 225
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_F&wtr=1& at 1736595044.7418287
# [Mover] distance_to_target: 132.23085872821065 at 1736595044.8338165
# [pather.cropPath] point [ 705 1229] 210 is reachable in 325
# probably casting smth atm
# [Mover] making step to (697, 668)
# [Mover.moveWASD] gonna move by angle 225
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_F&wtr=1& at 1736595044.9248168
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_F&wtr=1& at 1736595044.9278154
# [Mover] distance_to_target: 127.98828071350908 at 1736595045.0218158
# [pather.cropPath] point [ 705 1223] 216 is reachable in 325
# [Skill spark] using  at 1736595045.0228167
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=718&y=205&mtm=-1&msm=1&wtr=1& at 1736595045.0228167
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=718&y=205&mtm=-1&msm=1&wtr=1& at 1736595045.0228167
# [SkillWithDelay spark]  can be used after 1736595045.0438151 1736595045.0238152 0.02
# [Skill spark] successfully used  at 1736595045.0238152
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_F&wtr=1& at 1736595045.0248168
# [Mover] making step to (689, 668)
# [Mover.moveWASD] gonna move by angle 225
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_F&wtr=1& at 1736595045.138816
# [Mover] distance_to_target: 122.3315167894194 at 1736595045.2268112
# [pather.cropPath] point [ 711 1221] 224 is reachable in 325
# probably casting smth atm
# [Mover] making step to (716, 668)
# [Mover.moveWASD] gonna move by angle 225
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_F&wtr=1& at 1736595045.3268285
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_F&wtr=1& at 1736595045.3268285
# [Mover] distance_to_target: 118.0889495253472 at 1736595045.4118314
# [pather.cropPath] point [ 716 1220] 230 is reachable in 325
# [Mover] making step to (742, 668)
# [Mover.moveWASD] gonna move by angle 225
# [Mover] distance_to_target: 113.84638773364748 at 1736595045.7310045
# [pather.cropPath] point [ 721 1220] 235 is reachable in 325
# [Mover] making step to (770, 668)
# [Mover.moveWASD] gonna move by angle 225
# [Mover] distance_to_target: 108.18964830333816 at 1736595045.9069974
# [pather.cropPath] point [ 726 1218] 242 is reachable in 325
# [Mover] making step to (770, 668)
# [Mover.moveWASD] gonna move by angle 225
# [Mover] distance_to_target: 105.36128321162381 at 1736595046.0750184
# [pather.cropPath] point [ 729 1217] 246 is reachable in 325
# [Mover] making step to (781, 668)
# [Mover.moveWASD] gonna move by angle 180
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_D&wtr=1& at 1736595046.0830007
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_D&wtr=1& at 1736595046.0880158
# [Mover] distance_to_target: 101.11874208078343 at 1736595046.2669976
# [pather.cropPath] point [ 733 1215] 252 is reachable in 325
# [Mover] making step to (770, 668)
# [Mover.moveWASD] gonna move by angle 180
# [Mover] distance_to_target: 97.67292357659824 at 1736595046.4635859
# 100 points to target, almost arrived player_pos: x:1241 y: 693
# [Mover.moveWASD] gonna move by angle 270
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_D&wtr=1& at 1736595046.4655852
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_D&wtr=1& at 1736595046.4655852
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_A&wtr=1& at 1736595046.4655852
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_A&wtr=1& at 1736595046.466581
# killing it
# #goToPoint point: [1169, 759], min_distance: -1, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: False, random_val: 1
# custom_break_function:<function Mover.goToEntity.<locals>.custom_break_function_nested at 0x00000203F5D67EE0>, custom_continue_function:<function Mover.goToEntity.<locals>.custom_continue_fucntion_nested at 0x00000203F5D67E50>
# heist_transition: False, step_size: 31possible_transition: False
# seems like entity_to_go moved far away from a target distance_from_end_path 50.48762224545735, rebuilding path
# #goToPoint point: [1119, 766], min_distance: -1, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: False, random_val: 1
# custom_break_function:<function Mover.goToEntity.<locals>.custom_break_function_nested at 0x00000203F5D67EE0>, custom_continue_function:<function Mover.goToEntity.<locals>.custom_continue_fucntion_nested at 0x00000203F5D67E50>
# heist_transition: False, step_size: 31possible_transition: False
# check first_attack_time None
# end pos to go 1119 766
# [Mover.goToPoint] len(path): 196
# [Mover] distance_to_target: 139.18692467326088 at 1736595046.5405858
# [pather.cropPath] point [ 737 1206] 79 is reachable in 196
# check first_attack_time None
# [Mover] making step to (692, 668)
# [Mover] making first step, placing a mouse on (692, 668) and going
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=692&y=668&mtm=-1&msm=1&wtr=1& at 1736595046.5445793
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=692&y=668&mtm=-1&msm=1&wtr=1& at 1736595046.5455837
# [Mover.moveWASD] gonna move by angle 180
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_D&wtr=1& at 1736595046.5455837
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_D&wtr=1& at 1736595046.6861808
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_A&wtr=1& at 1736595046.6861808
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_A&wtr=1& at 1736595046.68918
# [Mover] distance_to_target: 134.6142637315972 at 1736595047.0221806
# [pather.cropPath] point [ 737 1206] 79 is reachable in 196
# check first_attack_time None
# [Mover] making step to (665, 647)
# [Mover.moveWASD] gonna move by angle 225
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_D&wtr=1& at 1736595047.0331855
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_D&wtr=1& at 1736595047.0331855
# [Mover] distance_to_target: 123.30855606972293 at 1736595047.2291882
# [pather.cropPath] point [ 738 1202] 84 is reachable in 196
# check first_attack_time None
# first_attack_time None
# [build.killUsual] getting closer in killUsual
# [Mover] making step to (602, 616)
# [Mover.moveWASD] gonna move by angle 225
# [Mover] distance_to_target: 115.52056094046635 at 1736595047.4081845
# [pather.cropPath] point [ 738 1200] 86 is reachable in 196
# check first_attack_time None
# first_attack_time None
# [build.killUsual] getting closer in killUsual
# [Mover] making step to (592, 579)
# [Mover.moveWASD] gonna move by angle 225
# [Mover] distance_to_target: 110.3856874780422 at 1736595047.5787783
# [pather.cropPath] point [ 738 1195] 91 is reachable in 196
# seems like entity_to_go moved far away from a target distance_from_end_path 15.03329637837291, rebuilding path
# #goToPoint point: [1134, 767], min_distance: -1, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: False, random_val: 1
# custom_break_function:<function Mover.goToEntity.<locals>.custom_break_function_nested at 0x00000203F5D67EE0>, custom_continue_function:<function Mover.goToEntity.<locals>.custom_continue_fucntion_nested at 0x00000203F5D67E50>
# heist_transition: False, step_size: 31possible_transition: False
# check first_attack_time None
# end pos to go 1134 767
# [Mover.goToPoint] len(path): 128
# [Mover] distance_to_target: 94.15412895885129 at 1736595047.6487947
# [pather.cropPath] point [ 748 1175] 67 is reachable in 128
# check first_attack_time None
# [Mover] making step to (552, 668)
# [Mover] making first step, placing a mouse on (552, 668) and going
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=552&y=668&mtm=-1&msm=1&wtr=1& at 1736595047.659389
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=552&y=668&mtm=-1&msm=1&wtr=1& at 1736595047.6604068
# [Mover.moveWASD] gonna move by angle 225
# [Mover] distance_to_target: 91.54780172128659 at 1736595047.7304058
# [pather.cropPath] point [ 748 1175] 67 is reachable in 128
# check first_attack_time None
# [Mover] making step to (547, 659)
# [Mover.moveWASD] gonna move by angle 225
# [Mover] distance_to_target: 83.81527307120105 at 1736595048.108497
# [pather.cropPath] point [ 746 1175] 65 is reachable in 128
# check first_attack_time None
# first_attack_time None
# [build.killUsual] getting closer in killUsual
# [Mover] making step to (521, 556)
# [Mover.moveWASD] gonna move by angle 270
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_A&wtr=1& at 1736595048.1174955
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_A&wtr=1& at 1736595048.1174955
# [Mover] distance_to_target: 74.73285756613353 at 1736595048.2844944
# [Pather] cant find point in los
# [Mover] len(current_path) == 0, generating new path
# [Mover] distance_to_target: 74.21590126111789 at 1736595048.3624954
# [Pather] cant find point in los
# [Mover] len(current_path) == 0, generating new path
# [Mover] distance_to_target: 73.76313442364011 at 1736595048.4371374
# [Pather] cant find point in los
# [Mover] len(current_path) == 0, generating new path
# [Mover] distance_to_target: 71.47027354082255 at 1736595048.5001385
# [Pather] cant find point in los
# [Mover] len(current_path) == 0, generating new path
# [Mover] distance_to_target: 69.89277502002622 at 1736595048.5741498
# [Pather] cant find point in los
# [Mover] len(current_path) == 0, generating new path
# [Mover] distance_to_target: 65.19202405202648 at 1736595048.6647303
# [Pather] cant find point in los
# [Mover] len(current_path) == 0, generating new path
# [Mover] distance_to_target: 62.76941930590086 at 1736595048.744731
# [pather.cropPath] point [ 751 1151] 61 is reachable in 95
# seems like entity_to_go moved far away from a target distance_from_end_path 46.518813398452025, rebuilding path
# #goToPoint point: [1176, 747], min_distance: -1, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: False, random_val: 1
# custom_break_function:<function Mover.goToEntity.<locals>.custom_break_function_nested at 0x00000203F5D67EE0>, custom_continue_function:<function Mover.goToEntity.<locals>.custom_continue_fucntion_nested at 0x00000203F5D67E50>
# heist_transition: False, step_size: 31possible_transition: False
# check first_attack_time None
# end pos to go 1176 747
# [Mover.goToPoint] len(path): 27
# [Mover] distance_to_target: 14.866068747318506 at 1736595048.9067335
# [pather.cropPath] point [ 747 1176] 26 is reachable in 27
# check first_attack_time None
# [Mover] making step to (677, 493)
# [Mover] making first step, placing a mouse on (677, 493) and going
# [Controller] debug sending action=mouseSetCursorPosSmooth&x
is reachable in 222
# found rares []
# [LootPicker.collectLoot] call at 1736595340.9358377
# angle 270, 1, 3, [1.231e+03 1.657e+03 1.000e+00], 3.0, 3.0
# angle 315, 0.75, 4, [1.230e+03 1.653e+03 1.000e+00], 5.656854249492381, 4.242640687119286
# angle 225, 0.75, 3, [1.231e+03 1.660e+03 1.000e+00], 4.242640687119286, 3.1819805153394642
# angle 0, 0.5625, 57, [1.234e+03 1.600e+03 1.000e+00], 57.0, 32.0625
# angle 180, 0.5625, 57, [1.234e+03 1.714e+03 1.000e+00], 57.0, 32.0625
# angle 45, 0.421875, 35, [1.269e+03 1.622e+03 1.000e+00], 49.49747468305833, 20.881747131915233
# angle 135, 0.421875, 26, [1.260e+03 1.683e+03 1.000e+00], 36.76955262170048, 15.512155012279889
# [Mover.moveWASD] gonna move by angle 0
# [Skill spark] using  at 1736595340.9388323
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=725&y=307&mtm=-1&msm=1&wtr=1& at 1736595340.9388323
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=725&y=307&mtm=-1&msm=1&wtr=1& at 1736595340.939832
# [SkillWithDelay spark]  can be used after 1736595340.9578319 1736595340.939832 0.02
# [Skill spark] successfully used  at 1736595340.939832
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_F&wtr=1& at 1736595340.939832
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_F&wtr=1& at 1736595340.9738345
# [Mover] distance_to_target: 163.08586695357758 at 1736595341.1258337
# [pather.cropPath] point [1665 1286] 90 is reachable in 222
# found rares []
# [LootPicker.collectLoot] call at 1736595341.1268318
# {'id': 2740, 'a': 'Art/2DItems/Weapons/OneHandWeapons/Scepters/Basetypes/Sceptre06c.dds', 'l': None, 'r': 'Normal', 'gp': [1250, 1654], 'sz': [560, 642, 277, 296]}
# item label added to ignored {'id': 2740, 'a': 'Art/2DItems/Weapons/OneHandWeapons/Scepters/Basetypes/Sceptre06c.dds', 'l': None, 'r': 'Normal', 'gp': [1250, 1654], 'sz': [560, 642, 277, 296]}
# probably casting smth atm
# [Mover] making step to (1018, 276)
# [Mover.moveWASD] gonna move by angle 90
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_A&wtr=1& at 1736595341.1308339
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_A&wtr=1& at 1736595341.1308339
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_D&wtr=1& at 1736595341.1308339
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_D&wtr=1& at 1736595341.1318338
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_F&wtr=1& at 1736595341.1618345
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_F&wtr=1& at 1736595341.1658354
# [Mover] distance_to_target: 163.77118183612157 at 1736595341.3168337
# [pather.cropPath] point [1665 1284] 88 is reachable in 222
# found rares []
# [LootPicker.collectLoot] call at 1736595341.318833
# [Skill spark] using  at 1736595341.3198369
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=633&y=272&mtm=-1&msm=1&wtr=1& at 1736595341.3198369
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=633&y=272&mtm=-1&msm=1&wtr=1& at 1736595341.3198369
# [SkillWithDelay spark]  can be used after 1736595341.341837 1736595341.3198369 0.02
# [Skill spark] successfully used  at 1736595341.3198369
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_F&wtr=1& at 1736595341.3218365
# [Mover] making step to (1028, 293)
# [Mover.moveWASD] gonna move by angle 90
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_F&wtr=1& at 1736595341.3728356
# [Mover] distance_to_target: 161.99382704288456 at 1736595341.513526
# [pather.cropPath] point [1665 1286] 90 is reachable in 222
# found rares []
# [LootPicker.collectLoot] call at 1736595341.515528
# probably casting smth atm
# [Mover] making step to (1025, 295)
# [Mover.moveWASD] gonna move by angle 90
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_F&wtr=1& at 1736595341.5585284
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_F&wtr=1& at 1736595341.5585284
# [Mover] distance_to_target: 159.0503065070923 at 1736595341.795091
# [pather.cropPath] point [1665 1289] 93 is reachable in 222
# found rares []
# [LootPicker.collectLoot] call at 1736595341.7960918
# [Skill spark] using  at 1736595341.7960918
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=609&y=290&mtm=-1&msm=1&wtr=1& at 1736595341.7960918
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=609&y=290&mtm=-1&msm=1&wtr=1& at 1736595341.7970934
# [SkillWithDelay spark]  can be used after 1736595341.8170934 1736595341.7970934 0.02
# [Skill spark] successfully used  at 1736595341.7970934
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_F&wtr=1& at 1736
is reachable in 222
# found rares []
# [LootPicker.collectLoot] call at 1736595343.971036
# [Skill spark] using  at 1736595343.971036
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=977&y=177&mtm=-1&msm=1&wtr=1& at 1736595343.971036
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=977&y=177&mtm=-1&msm=1&wtr=1& at 1736595343.972039
# [SkillWithDelay spark]  can be used after 1736595343.994039 1736595343.972039 0.02
# [Skill spark] successfully used  at 1736595343.972039
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_F&wtr=1& at 1736595343.9730365
# [Mover] making step to (947, 242)
# [Mover.moveWASD] gonna move by angle 90
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_F&wtr=1& at 1736595344.016036
# [Mover] distance_to_target: 86.12200647918044 at 1736595344.158039
# [pather.cropPath] point [1661 1364] 174 is reachable in 222
# found rares []
# [LootPicker.collectLoot] call at 1736595344.1590457
# probably casting smth atm
# [Mover] making step to (954, 237)
# [Mover.moveWASD] gonna move by angle 90

# %%
# open portal and enter it
def openPortal():
  poe_bot.bot_controls.releaseAll()

  time.sleep(random.randint(40,80)/100)
  pos_x, pos_y = random.randint(709,711), random.randint(694,696)
  pos_x, pos_y = poe_bot.convertPosXY(pos_x, pos_y, safe=False)
  poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
  time.sleep(random.randint(40,80)/100)
  poe_bot.bot_controls.mouse.click()
  time.sleep(random.randint(30,60)/100)


map_finish_time = time.time() 
time_now = time.time()
rev = bool(random.randint(0,1))
while time_now < map_finish_time + 1 :
  poe_bot.refreshInstanceData()
  killed_someone = poe_bot.combat_module.clearLocationAroundPoint({"X":poe_bot.game_data.player.grid_pos.x, "Y":poe_bot.game_data.player.grid_pos.y},detection_radius=50)
  res = poe_bot.loot_picker.collectLoot()
  if killed_someone is False and res is False:
    point = poe_bot.game_data.terrain.pointToRunAround(
      point_to_run_around_x=poe_bot.game_data.player.grid_pos.x,
      point_to_run_around_y=poe_bot.game_data.player.grid_pos.y,
      distance_to_point=15,
      reversed=rev
    )
    poe_bot.mover.move(grid_pos_x = point[0], grid_pos_y = point[1])
    poe_bot.refreshInstanceData()
  time_now = time.time()

i = 0
random_click_iter = 0
can_click_portal_after = time.time()
while True:
  while True:
    poe_bot.refreshInstanceData()
    res = poe_bot.loot_picker.collectLoot()
    if res is False:
      break
  
  if poe_bot.game_data.invites_panel_visible != False:
    print(f'[onmapfinishfunction] already loading')
  else:
    i+= 1
    random_click_iter += 1
    if random_click_iter > 15:
      print('[Mapper] cannot get to portal, clicking random point around the player')
      poe_bot.ui.closeAll()
      # point = poe_bot.game_data.terrain.pointToRunAround(poe_bot.game_data.player.grid_pos.x, poe_bot.game_data.player.grid_pos.y, distance_to_point=random.randint(15,25), check_if_passable=True)
      random_click_iter = random.randint(0,3)
    if i > 200:
      poe_bot.raiseLongSleepException('portal bug')
    nearby_portals = list(filter(lambda e: e.distance_to_player < 50, poe_bot.game_data.entities.town_portals))
    if len(nearby_portals) == 0:
      openPortal()
    nearby_portals = list(filter(lambda e: e.distance_to_player < 50, poe_bot.game_data.entities.town_portals))
    if len(nearby_portals) != 0:
      poe_bot.helper_functions.getToPortal(check_for_map_device=False, refresh_area=False)
  poe_bot.combat_module.clearLocationAroundPoint({"X": poe_bot.game_data.player.grid_pos.x, "Y": poe_bot.game_data.player.grid_pos.y},detection_radius=50)
  poe_bot.loot_picker.collectLoot()

# %%
# while True:
#   poe_bot.refreshInstanceData()
#   loot_collected = poe_bot.loot_picker.collectLoot()
#   if loot_collected == True:
#     continue
#   killed_smth = poe_bot.combat_module.clearAreaAroundPoint(poe_bot.game_data.player.grid_pos.toList())
  
#   if poe_bot.game_data.invites_panel_visible == False and killed_smth == False:
#     openPortal()
#     poe_bot.helper_functions.waitForPortalNearby()
#     poe_bot.helper_functions.getToPortal(check_for_map_device=False, refresh_area=False)
#     poe_bot.refreshInstanceData()
#     killed_smth = poe_bot.combat_module.clearAreaAroundPoint(poe_bot.game_data.player.grid_pos.toList())

# %%
raise 404

# %%
prefer_high_tier = True

# %%
poe_bot.refreshAll()
poe_bot.game_data.terrain.getCurrentlyPassableArea()

# %%
tsp = TSP(poe_bot)

tsp.generatePointsForDiscovery()
#TODO astar sorting
discovery_points = tsp.sortedPointsForDiscovery()

# %%
poe_bot.game_data.player.grid_pos.toList()

# %%
discovery_points

# %%
poe_bot.backend.getMapInfo()

# %%
poe_bot.backend.getMapInfo()

# %%
poe_bot.game_data.map_info.update()

# %%
poe_bot.game_data.map_info.map_completed

# %%
poe_bot.refreshAll()

# %%
poe_bot.game_data.player.grid_pos.toList()

# %%
poe_bot.mover.move(*poe_bot.game_data.player.grid_pos.toList())

# %%
# poe_bot.mo

# %%
import matplotlib.pyplot as plt

plt.imshow(poe_bot.game_data.terrain.passable)

# %%
poe_bot.refreshAll()
for e in poe_bot.game_data.labels_on_ground_entities:
  print(e.raw)

# %%
poe_bot.refreshAll()

# %%
poe_bot.ui.stash.update()

# %%
max_tier_to_recycle = 11

stash = poe_bot.ui.stash
stash.update()
waystone_items = list(filter(lambda i: i.map_tier != 0, stash.current_tab_items))
waystones_by_tier = {

}
for item in waystone_items:
  waystone_tier = item.map_tier
  if waystone_tier > max_tier_to_recycle:
    continue
  if waystones_by_tier.get(waystone_tier, 0) == 0:
    waystones_by_tier[waystone_tier] = []
  waystones_by_tier[waystone_tier].append(item)

waystone_tiers_sorted = list(waystones_by_tier.keys())
waystone_tiers_sorted.sort()

collected_items_count = 0
max_items_can_get = 60
for k in waystone_tiers_sorted:
  waystones_amount = len(waystones_by_tier[k])
  if waystones_amount // 3 == 0:
    continue

  collected_items_count += waystones_amount
  if collected_items_count > max_items_can_get:
    break
  poe_bot.ui.clickMultipleItems(waystones_by_tier[k])

# %%
# on map completion if some ritual was completed

# open ritual via ritual button
# TODO open ritual button is visible, screen position

 
poe_bot.ui.ritual_ui.update()
poe_bot.ui.ritual_ui.visible == True
poe_bot.ui.ritual_ui.tribute # current tribute
poe_bot.ui.ritual_ui.reroll_cost # 750 or 1000, depends on raw text
poe_bot.ui.ritual_ui.items # items actually

interesting_items_names = [
  "An Audience with the King",
  "Divine orb"
]

interesting_items = list(filter(lambda i: i.name == interesting_items_names,poe_bot.ui.ritual_ui.items))

for item in interesting_items:
  print(item.raw)
  item.hover()
  item_info = poe_bot.backend.getHoveredItemInfo()
  cost = int(item_info['tt'][-2][:-1])
  # do something with them, defer, reroll, buyout, whatever
