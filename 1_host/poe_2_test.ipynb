# %%
import time
import random
import sys
from ast import literal_eval

from utils.gamehelper import Poe2Bot

# %%
notebook_dev = False
# readability
poe_bot_class = Poe2Bot
poe_bot: poe_bot_class

# %%
default_config = {
  "REMOTE_IP": '172.23.107.65', # z2
  "unique_id": "poe_2_test",
  "build": "EaBallistasEle",
  "password": None,
  "max_lvl": 101,
  "chromatics_recipe": True,
  "force_reset_temp": False,
}



try:
  i = sys.argv[1]
  print(i)
  parsed_config = literal_eval(i)
  print(f'successfully parsed cli config')
  print(f'parsed_config: {parsed_config}')
except:
  print(f'cannot parse config from cli, using default\dev one')
  notebook_dev = True
  parsed_config = default_config
  parsed_config['unique_id'] = poe_bot_class.getDevKey()

config = {

}

for key in default_config.keys():
  config[key] = parsed_config.get(key, default_config[key])

print(f'config to run {config}')
# Out:
# --f=c:\Users\1\AppData\Roaming\jupyter\runtime\kernel-v2-4320vRJbdIIwRlve.json
# cannot parse config from cli, using default\dev one
# config to run {'REMOTE_IP': '172.23.107.65', 'unique_id': '7d1165934e24534a1ba5', 'build': 'EaBallistasEle', 'password': None, 'max_lvl': 101, 'chromatics_recipe': True, 'force_reset_temp': False}

# %%
REMOTE_IP = config['REMOTE_IP'] # REMOTE_IP
UNIQUE_ID = config['unique_id'] # unique id
MAX_LVL = config.get('max_lvl')
CHROMATICS_RECIPE = config['chromatics_recipe']
BUILD_NAME = config['build'] # build_name
password = config['password']
force_reset_temp = config['force_reset_temp']
print(f'running aqueduct using: REMOTE_IP: {REMOTE_IP} unique_id: {UNIQUE_ID} max_lvl: {MAX_LVL} chromatics_recipe: {CHROMATICS_RECIPE} force_reset_temp: {force_reset_temp}')
# Out:
# running aqueduct using: REMOTE_IP: 172.23.107.65 unique_id: 7d1165934e24534a1ba5 max_lvl: 101 chromatics_recipe: True force_reset_temp: False

# %%
poe_bot = Poe2Bot(unique_id = UNIQUE_ID, remote_ip = REMOTE_IP, password=password)
poe_bot.refreshAll()
# poe_bot.game_data.terrain.getCurrentlyPassableArea()
# Out:
# [Controller] establishing connection with ('172.23.107.65', 50007)
# [temp] loaded from file AfkTempData
# [temp] loaded from file StashTempData
# build is not assigned, using any functions may throw errors
# poe bot, v: 3.25.15 init at 1735708576.8160417
# [temp] loaded from file StashTempData
# [poebot] #refreshAll call at 1735708576.8200397

# %%
from utils.loot_filter import PickableItemLabel

ARTS_TO_PICK = [
  "Art/2DItems/Currency/CurrencyModValues.dds", # divine
  "Art/2DItems/Currency/CurrencyGemQuality.dds", # gemcutter
  "Art/2DItems/Currency/CurrencyRerollRare.dds", # chaos
  "Art/2DItems/Currency/CurrencyAddModToRare.dds", # exalt
  "Art/2DItems/Currency/CurrencyUpgradeToUnique.dds", # chance
]

# big piles of gold
for tier in range(2,17):
  ARTS_TO_PICK.append(f"Art/2DItems/Currency/Ruthless/CoinPileTier{tier}.dds")
# waystones
for tier in range(1,17):
  ARTS_TO_PICK.append(f"Art/2DItems/Maps/EndgameMaps/EndgameMap{tier}.dds")

# "Art/2DItems/Currency/Essence/GreaterFireEssence.dds"

def isItemHasPickableKey(item_label:PickableItemLabel):
  if item_label.icon_render in ARTS_TO_PICK:
    return True
  elif "Art/2DItems/Currency/Essence/" in item_label.icon_render:
    return True
  return False
poe_bot.loot_picker.loot_filter.special_rules = [isItemHasPickableKey]

# %%
poe_bot.mover.setMoveType('wasd')

# %%
from utils.combat import PathfinderPoisonConc2
from utils.combat import InfernalistZoomancer

# poe_bot.combat_module.build = InfernalistZoomancer(poe_bot=poe_bot)
poe_bot.combat_module.build = PathfinderPoisonConc2(poe_bot=poe_bot)
poe_bot.combat_module.build.auto_flasks.life_flask_recovers_es = True
poe_bot.combat_module.build.auto_flasks.hp_thresh = 0.25

def activateSwitchesNearby():
  switch_nearby = next( (e for e in poe_bot.game_data.entities.all_entities if e.is_targetable and e.path == "Metadata/Terrain/Maps/Crypt/Objects/CryptSecretDoorSwitch" and e.distance_to_player < 30), None)
  if switch_nearby:
    poe_bot.mover.goToEntitysPoint(switch_nearby)
    poe_bot.combat_module.clearAreaAroundPoint(switch_nearby.grid_position.toList())
    switch_nearby.clickTillNotTargetable()
    return True
  return False

def custom_default_continue_function(*args, **kwargs):
  pass

poe_bot.mover.default_continue_function = poe_bot.combat_module.build.usualRoutine
# Out:
# throw_flask_poison

# %%
# raise 404

# %%
# Ы

# %%
# poe_bot.backend.getVisibleLabels()

# %%
# raise 404

# %%
from utils.encounters import EssenceEncounter
from utils.constants import ESSENCES_KEYWORD

rares_detection_radius = 999



def seekForEssences(search_loc = None):
  '''
  search_loc: [gridx,gridy]
  '''
  essences = list(filter(lambda e: e.is_targetable is True and ESSENCES_KEYWORD in e.path and poe_bot.game_data.terrain.checkIfPointPassable(e.grid_position.x, e.grid_position.y), poe_bot.game_data.entities.all_entities))
  return essences

def runnerBreakFunction(*args, **kwargs):

  '''crypt map'''
  if activateSwitchesNearby() == True:
    return True
  '''crypt map'''

  if rares_detection_radius != 0:
    rares_nearby = list(filter(lambda e: e.distance_to_player < rares_detection_radius, poe_bot.game_data.entities.attackable_entities_rares))
    print(f'found rares {list(map(lambda e: e.raw, rares_nearby))}')
    for rare_mob in rares_nearby:
      updated_entity = list(filter(lambda e: e.id == rare_mob.id, poe_bot.game_data.entities.attackable_entities_rares))
      if len(updated_entity) != 0:
        updated_entity = updated_entity[0]
        print(f'going to kill rare {updated_entity.raw}')
        def custom_continue_func(*args, **kwargs):
          if activateSwitchesNearby() == True:
            return True
          if poe_bot.loot_picker.collectLoot() == True:
            return True
          return False
        # while True:
        #   res = poe_bot.mover.goToEntitysPoint(updated_entity,custom_break_function=custom_continue_func, min_distance=50)
        #   if res is None:
        #     break
        poe_bot.combat_module.killUsualEntity(updated_entity)
        return True
  essences = seekForEssences()
  if len(essences) != 0:
    essence_encounter = EssenceEncounter(poe_bot, essences[0])
    essence_encounter.doEncounter()
    poe_bot.loot_picker.collectLoot()
    return True

  loot_collected = poe_bot.loot_picker.collectLoot()
  if loot_collected is True:
    return loot_collected
  return False

# %%
# raise 404
poe_bot.refreshAll()
# Out:
# [poebot] #refreshAll call at 1735708577.2356043

# %%
prefer_high_tier = True
alch_map_if_possible = True

maps_to_ignore = [
  "MapCrypt_NoBoss", # activators
  "MapAugury_NoBoss", # activators
  "MapLostTowers"
]

# %%
# free inventory if neededS
poe_bot.ui.inventory.update()
empty_slots = poe_bot.ui.inventory.getEmptySlots()
if len(empty_slots) < 40:
  poe_bot.ui.stash.open()
  items_to_keep = []
  poe_bot.ui.inventory.update()
  waystones_to_keep = list(filter(lambda i: i.map_tier, poe_bot.ui.inventory.items))
  waystones_to_keep.sort(key=lambda i: i.map_tier, reverse=prefer_high_tier)
  items_to_keep.extend(waystones_to_keep[:4])
  alchemy_orbs = list(filter(lambda i: i.name == "Orb of Alchemy", poe_bot.ui.inventory.items))
  items_to_keep.extend(alchemy_orbs[:1])
  items_can_stash = list(filter(lambda i: i not in items_to_keep, poe_bot.ui.inventory.items))
  poe_bot.ui.clickMultipleItems(items_can_stash)
  poe_bot.ui.closeAll()
  time.sleep(random.uniform(0.3, 1.4))

# %%
# open map device
poe_bot.ui.map_device.open()
# move to map, open dropdown
poe_bot.ui.map_device.update()
possible_to_run_maps = list(filter(lambda m: 
  m.is_boss == False and # some bosses have unique logic?
  m.is_tower == False and# cant run tower maps yet
  m.is_hideout == False and# hideouts ignored
  m.is_trader == False and# manual trade
  m.is_ritual == False and# save rituals for tests
  (m.name_raw in maps_to_ignore) == False
, poe_bot.ui.map_device.avaliable_maps))
map_obj = random.choice(possible_to_run_maps)
print(map_obj.raw)
poe_bot.ui.map_device.moveScreenTo(map_obj)
time.sleep(random.uniform(0.15, 0.35))


poe_bot.ui.map_device.update()


updated_map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == map_obj.id))
updated_map_obj.click()
time.sleep(random.uniform(0.15, 0.35))
poe_bot.ui.map_device.update()
if poe_bot.ui.map_device.place_map_window_opened == False:
  print(f'dropdown didnt open')
  pos_x, pos_y = poe_bot.game_window.convertPosXY(100, 100)
  poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
  time.sleep(random.uniform(0.15, 0.35))
  poe_bot.ui.map_device.update()
  updated_map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == map_obj.id))
  updated_map_obj.click()
  time.sleep(random.uniform(0.15, 0.35))
  poe_bot.ui.map_device.update()
  if poe_bot.ui.map_device.place_map_window_opened == False:
    print(f'seems like map device bug')
    poe_bot.raiseLongSleepException("cant open dropdown for map device")
# Out:
# [ui.MapDevice_Poe2.open] call 1735708577.4706054
# [ui.MapDevice_Poe2.open] opening mapping_device: {'ls': [512, 274], 'p': 'Metadata/Terrain/Missions/Hideouts/Objects/MapDeviceVariants/ZigguratMapDevice', 'r': 'White', 'i': 20, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [390, 507], 'wp': [4276, 4276, -23], 'l': None, 'rn': 'Map Device', 'et': 'IngameIcon', 'distance_to_player': 9.899494936611665}
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=726&y=314&mtm=-1&msm=1 at 1735708577.4966004
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=726&y=314&mtm=-1&msm=1 at 1735708577.629234
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735708578.1872344
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735708578.195234
# [Controller] debug sending action=mouseRelease&button=left at 1735708578.3518193
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735708578.3548164
# {'sz': [1311, 1339, -292, -263], 'id': 343, 'name': 'Vaal Factory', 'name_raw': 'MapVaalFactory_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}
# going to drag to 343
# {'sz': [1311, 1339, -292, -263], 'id': 343, 'name': 'Vaal Factory', 'name_raw': 'MapVaalFactory_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}
# roi borders [397, 597, 149, 449]
# borders [25, 969, 80, 618]
# map_obj.screen_pos [1325, -277]
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=1101&y=120&mtm=-1&msm=1 at 1735708579.821121
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=1101&y=120&mtm=-1&msm=1 at 1735708579.9411104
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735708580.2491152
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735708580.2781045
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=726&y=424&mtm=-1&msm=1 at 1735708580.5001016
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=726&y=424&mtm=-1&msm=1 at 1735708580.6417642
# [Controller] debug sending action=mouseRelease&button=left at 1735708581.0397644
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735708581.040781
# {'sz': [980, 1009, -130, -101], 'id': 343, 'name': 'Vaal Factory', 'name_raw': 'MapVaalFactory_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}
# roi borders [397, 597, 149, 449]
# borders [25, 969, 80, 618]
# map_obj.screen_pos [994, -115]
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=1019&y=120&mtm=-1&msm=1 at 1735708581.2477648
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=1019&y=120&mtm=-1&msm=1 at 1735708581.367766
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735708581.5763576
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735708581.5973608
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=726&y=424&mtm=-1&msm=1 at 1735708581.9733615
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=726&y=424&mtm=-1&msm=1 at 1735708582.1013634
# [Controller] debug sending action=mouseRelease&button=left at 1735708582.3723736
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735708582.3743641
# {'sz': [690, 719, 56, 85], 'id': 343, 'name': 'Vaal Factory', 'name_raw': 'MapVaalFactory_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}
# roi borders [397, 597, 149, 449]
# borders [25, 969, 80, 618]
# map_obj.screen_pos [704, 70]
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=911&y=120&mtm=-1&msm=1 at 1735708582.652975
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=911&y=120&mtm=-1&msm=1 at 1735708582.7809706
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735708582.98997
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735708583.0069716
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=726&y=424&mtm=-1&msm=1 at 1735708583.2729752
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=726&y=424&mtm=-1&msm=1 at 1735708583.3809838
# [Controller] debug sending action=mouseRelease&button=left at 1735708583.7015934
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735708583.7025933
# {'sz': [506, 534, 235, 263], 'id': 343, 'name': 'Vaal Factory', 'name_raw': 'MapVaalFactory_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}
# roi borders [185, 385, 149, 449]
# borders [25, 545, 80, 618]
# map_obj.screen_pos [520, 249]
# inventory is opened, different borders and roi
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=734&y=289&mtm=-1&msm=1 at 1735708583.97559
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=734&y=289&mtm=-1&msm=1 at 1735708584.0315914
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735708584.2525988
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735708584.262593
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=470&y=424&mtm=-1&msm=1 at 1735708584.5857487
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=470&y=424&mtm=-1&msm=1 at 1735708584.6857357
# [Controller] debug sending action=mouseRelease&button=left at 1735708584.9325306
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735708584.933515
# {'sz': [301, 330, 277, 306], 'id': 343, 'name': 'Vaal Factory', 'name_raw': 'MapVaalFactory_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}
# roi borders [185, 385, 149, 449]
# borders [25, 545, 80, 618]
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=529&y=331&mtm=-1&msm=1 at 1735708585.6768513
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=529&y=331&mtm=-1&msm=1 at 1735708585.7298346
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735708585.9580736
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735708585.9670918
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=529&y=331&mtm=-1&msm=1 at 1735708585.9670918
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=529&y=331&mtm=-1&msm=1 at 1735708585.9970932
# [Controller] debug sending action=mouseRelease&button=left at 1735708585.9970932
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735708585.9970932

# %%
for m in possible_to_run_maps:
  print(m.raw)
# Out:
# {'sz': [2252, 2280, 3662, 3691], 'id': 232, 'name': 'Blooming Field', 'name_raw': 'MapBloomingField_NoBoss', 'icons': []}
# {'sz': [682, 711, 737, 766], 'id': 232, 'name': 'Blooming Field', 'name_raw': 'MapBloomingField_NoBoss', 'icons': []}
# {'sz': [424, 453, 411, 440], 'id': 224, 'name': 'Backwash', 'name_raw': 'MapBackwash_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentExpedition.dds']}
# {'sz': [1379, 1408, 552, 581], 'id': 278, 'name': 'Hidden Grotto', 'name_raw': 'MapHiddenGrotto_NoBoss', 'icons': []}
# {'sz': [1291, 1319, 462, 490], 'id': 305, 'name': 'Steppe', 'name_raw': 'MapSteppe_NoBoss', 'icons': []}
# {'sz': [796, 825, 115, 144], 'id': 263, 'name': 'Sump', 'name_raw': 'MapSump_NoBoss', 'icons': []}
# {'sz': [1312, 1341, 353, 382], 'id': 239, 'name': 'Savannah', 'name_raw': 'MapSavanna_NoBoss', 'icons': []}
# {'sz': [1119, 1148, 95, 124], 'id': 282, 'name': 'Seepage', 'name_raw': 'MapSeepage_NoBoss', 'icons': []}
# {'sz': [997, 1026, -85, -56], 'id': 253, 'name': 'Sulphuric Caverns', 'name_raw': 'MapSulphuricCaverns_NoBoss', 'icons': []}
# {'sz': [985, 1013, -190, -162], 'id': 325, 'name': 'Deserted', 'name_raw': 'MapDeserted_NoBoss', 'icons': []}
# {'sz': [2249, 2278, 321, 350], 'id': 267, 'name': 'Hive', 'name_raw': 'MapHive_NoBoss', 'icons': []}
# {'sz': [817, 846, -466, -437], 'id': 284, 'name': 'Riverside', 'name_raw': 'MapRiverside_NoBoss', 'icons': []}
# {'sz': [1445, 1474, -232, -203], 'id': 282, 'name': 'Seepage', 'name_raw': 'MapSeepage_NoBoss', 'icons': []}
# {'sz': [1311, 1339, -292, -263], 'id': 343, 'name': 'Vaal Factory', 'name_raw': 'MapVaalFactory_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}
# {'sz': [947, 976, -565, -536], 'id': 327, 'name': 'Oasis', 'name_raw': 'MapOasis_NoBoss', 'icons': []}
# {'sz': [903, 931, -612, -583], 'id': 321, 'name': 'Decay', 'name_raw': 'MapDecay_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}
# {'sz': [914, 943, -813, -784], 'id': 239, 'name': 'Savannah', 'name_raw': 'MapSavanna_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentDelirium.dds']}

# %%
if poe_bot.ui.map_device.place_map_window_opened != True:
  poe_bot.raiseLongSleepException("cant open dropdown for map device")

# %%
# screen_pos_x, screen_pos_y = poe_bot.game_window.center_point
# pos_x, pos_y = poe_bot.game_window.convertPosXY(screen_pos_x, screen_pos_y)
# poe_bot.bot_controls.mouse.setPos(pos_x, pos_y)


# poe_bot.ui.map_device.update()
# updated_map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == map_obj.id))

# screen_pos_x, screen_pos_y = updated_map_obj.screen_pos.toList()
# pos_x, pos_y = poe_bot.game_window.convertPosXY(screen_pos_x, screen_pos_y)
# # poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
# poe_bot.bot_controls.mouse.setPos(pos_x, pos_y)

# %%
poe_bot.ui.inventory.update()
maps_in_inventory = list(filter(lambda i: i.map_tier, poe_bot.ui.inventory.items))
maps_in_inventory.sort(key=lambda i: i.map_tier, reverse=prefer_high_tier)
map_to_run = maps_in_inventory[0]
print(f'placing map {map_to_run.raw}')

if alch_map_if_possible == True:
  ARTS_TO_PICK.append("Art/2DItems/Currency/CurrencyUpgradeToRare.dds")
  for _i in range(1):
    if map_to_run.rarity != "Normal":
      break
    alchemy_orbs = list(filter(lambda i: i.name == "Orb of Alchemy", poe_bot.ui.inventory.items))
    if len(alchemy_orbs) == 0:
      break
    alchemy_orb = alchemy_orbs[0]
    alchemy_orb.click(button="right")
    time.sleep(random.uniform(0.4, 1.2))
    map_to_run.click()
    time.sleep(random.uniform(0.8, 1.2))

map_to_run.click(hold_ctrl=True)
poe_bot.ui.map_device.update()
#TODO sometimes activate button is outside roi
poe_bot.ui.map_device.checkIfActivateButtonIsActive()


poe_bot.ui.map_device.activate()

time.sleep(random.uniform(0.8, 1.6))
poe_bot.helper_functions.waitForNewPortals()
# Out:
# placing map {'l': None, 'tt': None, 'Name': 'Waystone (Tier 12)', 'a': 'Art/2DItems/Maps/EndgameMaps/EndgameMap12.dds', 'unique_name': '', 'rarity': 'Normal', 'Class': None, 'ItemType': None, 'm_t': 12, 'c': 0, 'i': 0, 'RenderArt': 'Metadata/Items/Maps/MapKeyTier12', 'items_in_stack': 0, 'item_mods': [], 'imr': [], 'g': [0, 1, 0, 1], 's': [563, 600, 420, 457], 'ti': 0, 'LocationTopLeft': None, 'LocationBottomRight': None, 'TopLeft': None, 'BottomRight': None}
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=829&y=506&mtm=-1&msm=1 at 1735708586.3429785
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=829&y=506&mtm=-1&msm=1 at 1735708586.4509745
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=right at 1735708586.6825678
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=right at 1735708586.7105653
# [Controller] debug sending action=mouseRelease&button=right at 1735708586.7105653
# [Controller] debug recieved response for action=mouseRelease&button=right at 1735708586.711565
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=785&y=490&mtm=-1&msm=1 at 1735708587.153579
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=785&y=490&mtm=-1&msm=1 at 1735708587.1955688
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735708587.4565628
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735708587.47157
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=811&y=479&mtm=-1&msm=1 at 1735708587.47157
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=811&y=479&mtm=-1&msm=1 at 1735708587.5115662
# [Controller] debug sending action=mouseRelease&button=left at 1735708587.5115662
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735708587.512567
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_LCONTROL at 1735708588.537186
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_LCONTROL at 1735708588.538172
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=809&y=490&mtm=-1&msm=1 at 1735708588.538172
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=809&y=490&mtm=-1&msm=1 at 1735708588.5778131
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735708588.760815
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735708588.7928166
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=795&y=484&mtm=-1&msm=1 at 1735708588.7928166
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=795&y=484&mtm=-1&msm=1 at 1735708588.8248029
# [Controller] debug sending action=mouseRelease&button=left at 1735708588.8248029
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735708588.8258035
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_LCONTROL at 1735708588.8877997
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_LCONTROL at 1735708588.8877997
# [Controller] debug sending action=getPartialScreen&x1=214&y1=40&x2=1238&y2=808& at 1735708588.916803
# [Controller] data_size_raw b'\x00$\x15\xa8'
# [Controller] data_size 2364840
# activate_button_is_active False
# [Controller] debug sending action=getPartialScreen&x1=214&y1=40&x2=1238&y2=808& at 1735708589.0078003
# [Controller] data_size_raw b'\x00$\x15\xa8'
# [Controller] data_size 2364840
# activate_button_is_active True
# activate button pos (530, 579)
# activate button pos <utils.components.Posx1x2y1y2 object at 0x000002A595F57F70>
# activate button pos {'ap_o': True, 'wm_o': True, 'av_m': [{'sz': [-3649, -3620, 21577, 21606], 'id': 381, 'name': 'Limestone Hideout', 'name_raw': 'MapHideoutLimestone_Claimable', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentHideout.dds']}, {'sz': [-1440, -1404, 15140, 15219], 'id': 245, 'name': 'Lost Towers', 'name_raw': 'MapLostTowers', 'icons': []}, {'sz': [-1667, -1638, 11740, 11769], 'id': 232, 'name': 'Blooming Field', 'name_raw': 'MapBloomingField_NoBoss', 'icons': []}, {'sz': [-1527, -1498, 7517, 7545], 'id': 276, 'name': 'Crypt', 'name_raw': 'MapCrypt_NoBoss', 'icons': []}, {'sz': [-344, -315, 10786, 10814], 'id': 258, 'name': 'Augury', 'name_raw': 'MapAugury_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentRitual.dds']}, {'sz': [557, 586, 11586, 11614], 'id': 381, 'name': 'Limestone Hideout', 'name_raw': 'MapHideoutLimestone_Claimable', 'icons': []}, {'sz': [-585, -556, 5348, 5377], 'id': 284, 'name': 'Riverside', 'name_raw': 'MapRiverside_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentRitual.dds']}, {'sz': [2190, 2219, 10305, 10334], 'id': 223, 'name': 'Backwash', 'name_raw': 'MapBackwash', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentMapBoss.dds']}, {'sz': [-1260, -1231, 2122, 2151], 'id': 232, 'name': 'Blooming Field', 'name_raw': 'MapBloomingField_NoBoss', 'icons': []}, {'sz': [-1196, -1167, 1828, 1856], 'id': 258, 'name': 'Augury', 'name_raw': 'MapAugury_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}, {'sz': [-1342, -1306, 1585, 1665], 'id': 245, 'name': 'Lost Towers', 'name_raw': 'MapLostTowers', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}, {'sz': [-1347, -1318, 1486, 1515], 'id': 224, 'name': 'Backwash', 'name_raw': 'MapBackwash_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentExpedition.dds']}, {'sz': [1861, 1890, 8375, 8403], 'id': 321, 'name': 'Decay', 'name_raw': 'MapDecay_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentRitual.dds']}, {'sz': [1581, 1610, 7612, 7641], 'id': 258, 'name': 'Augury', 'name_raw': 'MapAugury_NoBoss', 'icons': []}, {'sz': [-417, -381, 2927, 3007], 'id': 245, 'name': 'Lost Towers', 'name_raw': 'MapLostTowers', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}, {'sz': [-815, -779, 2120, 2199], 'id': 245, 'name': 'Lost Towers', 'name_raw': 'MapLostTowers', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}, {'sz': [3116, 3144, 8421, 8450], 'id': 276, 'name': 'Crypt', 'name_raw': 'MapCrypt_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentExpedition.dds', 'Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentDelirium.dds']}, {'sz': [-11, 24, 2758, 2837], 'id': 245, 'name': 'Lost Towers', 'name_raw': 'MapLostTowers', 'icons': []}, {'sz': [-1106, -1070, 966, 1046], 'id': 245, 'name': 'Lost Towers', 'name_raw': 'MapLostTowers', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}, {'sz': [-1321, -1292, 625, 654], 'id': 381, 'name': 'Limestone Hideout', 'name_raw': 'MapHideoutLimestone_Claimable', 'icons': []}, {'sz': [-1130, -1094, 685, 765], 'id': 245, 'name': 'Lost Towers', 'name_raw': 'MapLostTowers', 'icons': []}, {'sz': [2717, 2753, 6724, 6803], 'id': 245, 'name': 'Lost Towers', 'name_raw': 'MapLostTowers', 'icons': []}, {'sz': [-105, -69, 2035, ...
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=530&y=579&mtm=-1&msm=3 at 1735708589.0578005
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=530&y=579&mtm=-1&msm=3 at 1735708589.2698014
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735708589.3788462
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735708589.4083772
# [Controller] debug sending action=mouseRelease&button=left at 1735708589.4903772
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735708589.4943771
# #waitForNewPortals 1735708590.789707
# checking if portals changed
# portals changed
# True

# %%
poe_bot.refreshInstanceData()
original_area_raw_name = poe_bot.game_data.area_raw_name
poe_bot.helper_functions.getToPortal(check_for_map_device=False, refresh_area=True)
area_changed = False
while area_changed != True:
  poe_bot.refreshAll()
  area_changed = poe_bot.game_data.area_raw_name != original_area_raw_name
# Out:
# original_area_raw_name HideoutShrine
# portal_to_enter {'ls': [474, 347], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 50, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [373, 517], 'wp': [4080, 4156, -95], 'l': None, 'rn': 'Vaal Factory', 'et': 'TownPortal', 'distance_to_player': 10.44030650891055}
# getting into portal {'ls': [474, 347], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 50, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [373, 517], 'wp': [4080, 4156, -95], 'l': None, 'rn': 'Vaal Factory', 'et': 'TownPortal', 'distance_to_player': 10.44030650891055}
# 688 387
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=688&y=387&mtm=-1&msm=1 at 1735708593.867493
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=688&y=387&mtm=-1&msm=1 at 1735708593.9684951
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735708594.383494
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735708594.3944974
# [Controller] debug sending action=mouseRelease&button=left at 1735708594.5585628
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735708594.5590794
# clicked on a portal {'ls': [474, 347], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 50, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [373, 517], 'wp': [4080, 4156, -95], 'l': None, 'rn': 'Vaal Factory', 'et': 'TownPortal', 'distance_to_player': 10.44030650891055}
# [Controller] debug sending action=releaseAll at 1735708596.6543272
# [Controller] debug recieved response for action=releaseAll at 1735708596.6563268
# area is loading on partial request
# [poebot] #refreshAll call at 1735708596.6563268
# area is loading 1
# area is loading 2
# area is loading 3
# area is loading 4
# area is loading 5
# area is loading 6
# area is loading 7
# area is loading 8
# area is loading 9
# area is loading 10
# area is loading 11
# area is loading 12
# area is loading 13
# area is loading 14
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=290&y=100&mtm=-1&msm=1 at 1735708603.3959477
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=290&y=100&mtm=-1&msm=1 at 1735708603.535949
# [poebot] #refreshAll call at 1735708603.535949

# %%
# raise 404

# %%
from utils.pathing import TSP


tsp = TSP(poe_bot=poe_bot)
# tsp.generatePointsForDiscovery()
mover = poe_bot.mover
map_complete = False
while map_complete is False:
  poe_bot.refreshInstanceData()
  print(f'generating pathing points')
  tsp.generatePointsForDiscovery()
  #TODO astar sorting
  discovery_points = tsp.sortedPointsForDiscovery(add_start_point_weight=True)
  print(f'len(discovery_points) {len(discovery_points)}')
  discovery_points = list(filter(lambda p: poe_bot.game_data.terrain.checkIfPointPassable(p[0], p[1]), discovery_points))
  print(f'len(discovery_points) {len(discovery_points)} after sorting')
  print(f'discovery_points {discovery_points}')
  if len(discovery_points) == 0:
    print(f'len(discovery_points) == 0 after points generation')
    map_complete = True
    break
  point_to_go = discovery_points.pop(0)
  while point_to_go is not None:
    need_to_explore = poe_bot.helper_functions.needToExplore(point_to_go=point_to_go)
    if need_to_explore is True:
      print(f'exploring point {point_to_go}')
    else:
      print(f'surrounding around {point_to_go} discovered, skipping')
      try:
        point_to_go = discovery_points.pop(0)
      except:
        point_to_go = None
      continue

    # go to point to make it explored
    result = mover.goToPoint(
      point=point_to_go,
      min_distance=50,
      release_mouse_on_end=False,
      custom_break_function=runnerBreakFunction,
      step_size=random.randint(30,35)
    )
    # then, it result is True, False or None
    print(f"mover.goToPoint result {result}")


    # if we arrived to discovery point and nothing happened
    poe_bot.game_data.map_info.update()
    if poe_bot.game_data.map_info.map_completed == True:
      print(f'poe_bot.game_data.map_info.map_completed == True')
      map_complete = True
      break
    if result is None:
      while True:
        if len(discovery_points) == 0:
          point_to_go = None
          map_complete = True
          print(f'len(discovery_points) == 0, breaking')
          break

        point_to_go = discovery_points.pop(0)
        print(f'willing to explore next point {point_to_go}')
        need_to_explore = poe_bot.helper_functions.needToExplore(point_to_go=point_to_go)

        if need_to_explore is True:
          print(f'exploring point {point_to_go}')
          break
        else:
          print(f'surrounding around {point_to_go} discovered, skipping')
          continue
    
    # if explorer_break_function() is True:
    #   map_complete = True
    #   break

    poe_bot.refreshInstanceData()
    poe_bot.last_action_time = 0
  # if possible_transition to explore, go to it, run discovery again
# Out:
# generating pathing points
# 1735708604.2355595
# len(discovery_points) 41
# len(discovery_points) 41 after sorting
# discovery_points [(623, 1706), (776, 1512), (595, 1512), (590, 1330), (767, 1263), (925, 1365), (971, 1605), (1136, 1472), (1324, 1511), (1318, 1343), (1093, 1233), (938, 1161), (690, 1106), (448, 1168), (398, 1323), (230, 1323), (265, 1157), (343, 1007), (505, 1001), (677, 939), (862, 960), (1139, 1069), (1277, 966), (1393, 1189), (1167, 804), (865, 748), (1008, 615), (1182, 627), (1329, 738), (1334, 568), (1136, 456), (965, 449), (767, 583), (582, 675), (395, 729), (245, 812), (155, 1001), (312, 579), (570, 489), (776, 402), (1321, 401)]
# exploring point (623, 1706)
# #goToPoint point: (623, 1706), min_distance: 50, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: True, random_val: 1
# custom_break_function:<function runnerBreakFunction at 0x000002A594A749D0>, custom_continue_function:None
# heist_transition: False, step_size: 30possible_transition: False
# found rares []
# [LootPicker.collectLoot] call at 1735708605.6534643
# end pos to go 622 1705
# [Mover] distance_to_target: 147.27525250360293 at 1735708605.8524618
# found rares []
# [LootPicker.collectLoot] call at 1735708605.8534608
# [Mover] making step to (426, 354)
# [Mover] making first step, placing a mouse on (426, 354) and going
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=426&y=354&mtm=-1&msm=1&wtr=1& at 1735708605.8974621
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=426&y=354&mtm=-1&msm=1&wtr=1& at 1735708605.8974621
# [Mover.moveWASD] (753, 1644), (None, None)
# grid pos pp [769, 1696]
# [Mover.moveWASD] exact angle to move 342.89727103094765
# angle 315, 1, 23, [7.460e+02 1.673e+03 1.000e+00], 32.526911934581186, 32.526911934581186
# angle 360, 1.25, 54, [7.690e+02 1.642e+03 1.000e+00], 54.0, 67.5
# [Mover.moveWASD] gonna move by angle 0
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_A&wtr=1& at 1735708605.8994598
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_A&wtr=1& at 1735708606.0174592
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_W&wtr=1& at 1735708606.0174592
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_W&wtr=1& at 1735708606.0174592
# [Mover] distance_to_target: 147.27525250360293 at 1735708606.06546
# found rares []
# [LootPicker.collectLoot] call at 1735708606.0664592
# [Mover] making step to (426, 354)
# [Mover.moveWASD] (753, 1644), (None, None)
# grid pos pp [769, 1696]
# [Mover.moveWASD] exact angle to move 342.89727103094765
# angle 315, 1, 23, [7.460e+02 1.673e+03 1.000e+00], 32.526911934581186, 32.526911934581186
# angle 360, 1.25, 54, [7.690e+02 1.642e+03 1.000e+00], 54.0, 67.5
# [Mover.moveWASD] gonna move by angle 0
# [Mover] distance_to_target: 147.41099009232659 at 1735708606.2020555
# found rares []
# [LootPicker.collectLoot] call at 1735708606.204053
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594AAA100>, <utils.gamehelper.Entity object at 0x000002A594F4C2E0>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (437, 371)
# [Mover.moveWASD] (753, 1642), (None, None)
# grid pos pp [769, 1694]
# [Mover.moveWASD] exact angle to move 342.89727103094765
# angle 315, 1, 23, [7.460e+02 1.671e+03 1.000e+00], 32.526911934581186, 32.526911934581186
# angle 360, 1.25, 54, [7.69e+02 1.64e+03 1.00e+00], 54.0, 67.5
# [Mover.moveWASD] gonna move by angle 0
# [Mover] distance_to_target: 147.97972834141845 at 1735708606.3500516
# found rares []
# [LootPicker.collectLoot] call at 1735708606.3510516
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594AA7040>, <utils.gamehelper.Entity object at 0x000002A594F53610>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (435, 389)
# [Mover.moveWASD] (751, 1638), (None, None)
# grid pos pp [769, 1688]
# [Mover.moveWASD] exact angle to move 340.20112364547504
# angle 315, 1, 22, [7.470e+02 1.666e+03 1.000e+00], 31.112698372208094, 31.112698372208094
# angle 360, 1.25, 53, [7.690e+02 1.635e+03 1.000e+00], 53.0, 66.25
# [Mover.moveWASD] gonna move by angle 0
# [Mover] distance_to_target: 148.63714206079177 at 1735708606.555897
# found rares []
# [LootPicker.collectLoot] call at 1735708606.5569732
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594BD9D30>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (435, 420)
# [Mover.moveWASD] (748, 1634), (None, None)
# grid pos pp [769, 1683]
# [Mover.moveWASD] exact angle to move 336.8014094863518
# angle 315, 1.25, 21, [7.480e+02 1.662e+03 1.000e+00], 29.698484809834998, 37.123106012293746
# angle 360, 1, 53, [7.69e+02 1.63e+03 1.00e+00], 53.0, 53.0
# [Mover.moveWASD] gonna move by angle 0
# [Mover] distance_to_target: 150.23315213360863 at 1735708606.8266356
# found rares []
# [LootPicker.collectLoot] call at 1735708606.827635
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (441, 464)
# [Mover.moveWASD] (741, 1633), (None, None)
# grid pos pp [769, 1674]
# [Mover.moveWASD] exact angle to move 325.66978280449666
# angle 315, 1.25, 20, [7.490e+02 1.654e+03 1.000e+00], 28.284271247461902, 35.35533905932738
# angle 360, 1, 49, [7.690e+02 1.625e+03 1.000e+00], 49.0, 49.0
# [Mover.moveWASD] gonna move by angle 0
# [Mover] distance_to_target: 153.16004700965587 at 1735708607.1116333
# found rares []
# [LootPicker.collectLoot] call at 1735708607.1146333
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (467, 492)
# [Mover.moveWASD] (738, 1633), (None, None)
# grid pos pp [769, 1662]
# [Mover.moveWASD] exact angle to move 313.0908475670036
# angle 270, 1, 21, [7.480e+02 1.662e+03 1.000e+00], 21.0, 21.0
# angle 315, 1.25, 19, [7.500e+02 1.643e+03 1.000e+00], 26.870057685088806, 33.58757210636101
# [Mover.moveWASD] gonna move by angle 315
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_W&wtr=1& at 1735708607.135634
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_W&wtr=1& at 1735708607.1456325
# [Mover] distance_to_target: 157.3054353797096 at 1735708607.3746412
# found rares []
# [LootPicker.collectLoot] call at 1735708607.3786411
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (512, 504)
# [Mover.moveWASD] (736, 1633), (None, None)
# grid pos pp [769, 1649]
# [Mover.moveWASD] exact angle to move 295.8663567940945
# angle 270, 1, 19, [7.500e+02 1.649e+03 1.000e+00], 19.0, 19.0
# angle 315, 1.25, 25, [7.440e+02 1.624e+03 1.000e+00], 35.35533905932738, 44.19417382415922
# [Mover.moveWASD] gonna move by angle 315
# [Mover] distance_to_target: 153.93505123915085 at 1735708607.6672332
# found rares []
# [LootPicker.collectLoot] call at 1735708607.669235
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (393, 525)
# [Mover.moveWASD] (712, 1620), (None, None)
# grid pos pp [762, 1641]
# [Mover.moveWASD] exact angle to move 292.7824057304817
# angle 270, 1, 12, [7.500e+02 1.641e+03 1.000e+00], 12.0, 12.0
# angle 315, 1.25, 38, [7.240e+02 1.603e+03 1.000e+00], 53.74011537017761, 67.17514421272202
# [Mover.moveWASD] gonna move by angle 315
# [Mover] distance_to_target: 149.96666296213968 at 1735708608.0432372
# found rares []
# [LootPicker.collectLoot] call at 1735708608.0452356
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (432, 565)
# [Mover.moveWASD] (700, 1620), (None, None)
# grid pos pp [753, 1632]
# [Mover.moveWASD] exact angle to move 282.7575321608767
# angle 270, 1.25, 31, [7.220e+02 1.632e+03 1.000e+00], 31.0, 38.75
# angle 315, 1, 38, [7.150e+02 1.594e+03 1.000e+00], 53.74011537017761, 53.74011537017761
# [Mover.moveWASD] gonna move by angle 315
# [Mover] distance_to_target: 146.23952953972466 at 1735708608.255233
# found rares []
# [LootPicker.collectLoot] call at 1735708608.2562323
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594BFFFA0>]
# going to clear
# didnt use pconc for long, throw somewhere even if theres 1 attack val
# enemy_to_attack.attack_value 2 {'ls': [29, 511], 'p': 'Metadata/Monsters/VaalHumanoids/VaalHumanoidSwordShield/VaalHumanoidSwordShield_@77', 'r': 'White', 'i': 2413, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [675, 1603], 'wp': [7363, 3364, -53], 'l': [16807, 16807, 0, 200, 200, 0, 884, 884, 0], 'rn': 'Fused Swordsman', 'et': 'm', 'distance_to_player': 68.15423684555495}
# pconc throw reduced to [691.5, 1607.25]
# [Skill throw_flask_poison] using  at 1735708608.2572324
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=409&y=551&mtm=-1&msm=1&wtr=1& at 1735708608.2692344
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=409&y=551&mtm=-1&msm=1&wtr=1& at 1735708608.2892344
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=right at 1735708608.2892344
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=right at 1735708608.4652324
# [Controller] debug sending action=mouseRelease&button=right at 1735708608.6198347
# [Controller] debug recieved response for action=mouseRelease&button=right at 1735708608.627834
# [SkillWithDelay throw_flask_poison]  can be used after 1735708608.660834 1735708608.627834 0.03
# [Skill throw_flask_poison] successfully used  at 1735708608.627834
# adding explosion zone 1735708608.2562323 with [671.5, 711.5, 1587.25, 1627.25]
# [Mover] making step to (557, 626)
# [Mover.moveWASD] (687, 1620), (None, None)
# grid pos pp [741, 1620]
# [Mover.moveWASD] exact angle to move 270.0
# angle 270, 1.25, 54, [6.87e+02 1.62e+03 1.00e+00], 54.0, 67.5
# angle 315, 1, 38, [7.030e+02 1.582e+03 1.000e+00], 53.74011537017761, 53.74011537017761
# [Mover.moveWASD] gonna move by angle 270
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_S&wtr=1& at 1735708608.6488445
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_S&wtr=1& at 1735708608.6498344
# [Mover] distance_to_target: 144.3606594609487 at 1735708608.7148347
# found rares []
# [LootPicker.collectLoot] call at 1735708608.7158353
# calling usual routine
# probably casting smth atm
# [Mover] making step to (511, 657)
# [Mover.moveWASD] (675, 1620), (None, None)
# grid pos pp [728, 1607]
# [Mover.moveWASD] exact angle to move 256.21840276434637
# angle 225, 1, 16, [7.120e+02 1.623e+03 1.000e+00], 22.627416997969522, 22.627416997969522
# angle 270, 1.25, 54, [6.740e+02 1.607e+03 1.000e+00], 54.0, 67.5
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 144.3121616496683 at 1735708608.9528332
# found rares []
# [LootPicker.collectLoot] call at 1735708608.9538343
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594A91730>, <utils.gamehelper.Entity object at 0x000002A594B47160>, <utils.gamehelper.Entity object at 0x000002A594B47F70>, <utils.gamehelper.Entity object at 0x000002A594B473D0>, <utils.gamehelper.Entity object at 0x000002A594B47220>]
# going to clear
# didnt use pconc for long, throw somewhere even if theres 1 attack val
# enemy_to_attack.attack_value 2 {'ls': [168, 367], 'p': 'Metadata/Monsters/VaalHumanoids/VaalHumanoidSwordShield/VaalHumanoidSwordShield_@77', 'r': 'White', 'i': 2412, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [686, 1582], 'wp': [7488, 3586, -57], 'l': [16807, 16807, 0, 200, 200, 0, 884, 884, 0], 'rn': 'Fused Swordsman', 'et': 'm', 'distance_to_player': 47.50789408087881}
# pconc throw reduced to [696.25, 1588.0]
# [Skill throw_flask_poison] using  at 1735708608.954835
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=478&y=437&mtm=-1&msm=1&wtr=1& at 1735708608.9658368
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=478&y=437&mtm=-1&msm=1&wtr=1& at 1735708608.9668348
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=right at 1735708608.9668348
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=right at 1735708609.1078315
# [Controller] debug sending action=mouseRelease&button=right at 1735708609.2531343
# [Controller] debug recieved response for action=mouseRelease&button=right at 1735708609.2578344
# [SkillWithDelay throw_flask_poison]  can be used after 1735708609.2848344 1735708609.2578344 0.03
# [Skill throw_flask_poison] successfully used  at 1735708609.2578344
# adding explosion zone 1735708608.9538343 with [676.25, 716.25, 1568.0, 1608.0]
# [Mover] making step to (523, 635)
# [Mover.moveWASD] (674, 1620), (None, None)
# grid pos pp [727, 1606]
# [Mover.moveWASD] exact angle to move 255.20323775494268
# angle 225, 1, 17, [7.100e+02 1.623e+03 1.000e+00], 24.041630560342618, 24.041630560342618
# angle 270, 1.25, 54, [6.730e+02 1.606e+03 1.000e+00], 54.0, 67.5
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 135.77186748365804 at 1735708609.687444
# found rares []
# [LootPicker.collectLoot] call at 1735708609.6894453
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594F3FC10>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (484, 655)
# [Mover.moveWASD] (665, 1620), (None, None)
# grid pos pp [719, 1610]
# [Mover.moveWASD] exact angle to move 259.5085229876684
# angle 225, 1, 33, [6.860e+02 1.643e+03 1.000e+00], 46.66904755831214, 46.66904755831214
# angle 270, 1.25, 54, [6.65e+02 1.61e+03 1.00e+00], 54.0, 67.5
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 130.11533345459327 at 1735708609.8724449
# found rares []
# [LootPicker.collectLoot] call at 1735708609.8734448
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A595F35DC0>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (478, 657)
# [Mover.moveWASD] (659, 1620), (None, None)
# grid pos pp [713, 1612]
# [Mover.moveWASD] exact angle to move 261.57303097851934
# angle 225, 1, 27, [6.860e+02 1.639e+03 1.000e+00], 38.18376618407357, 38.18376618407357
# angle 270, 1.25, 54, [6.590e+02 1.612e+03 1.000e+00], 54.0, 67.5
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 125.31959144523253 at 1735708610.063445
# found rares []
# [LootPicker.collectLoot] call at 1735708610.0654433
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (456, 651)
# [Mover.moveWASD] (652, 1620), (None, None)
# grid pos pp [706, 1612]
# [Mover.moveWASD] exact angle to move 261.57303097851934
# angle 225, 1, 23, [6.830e+02 1.635e+03 1.000e+00], 32.526911934581186, 32.526911934581186
# angle 270, 1.25, 54, [6.520e+02 1.612e+03 1.000e+00], 54.0, 67.5
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 119.85407794480753 at 1735708610.2184417
# found rares []
# [LootPicker.collectLoot] call at 1735708610.2204442
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (464, 645)
# [Mover.moveWASD] (646, 1620), (None, None)
# grid pos pp [700, 1614]
# [Mover.moveWASD] exact angle to move 263.6598082540901
# angle 225, 1, 20, [6.800e+02 1.634e+03 1.000e+00], 28.284271247461902, 28.284271247461902
# angle 270, 1.25, 54, [6.460e+02 1.614e+03 1.000e+00], 54.0, 67.5
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 115.42096863222038 at 1735708610.3934398
# found rares []
# [LootPicker.collectLoot] call at 1735708610.394439
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (462, 629)
# [Mover.moveWASD] (640, 1618), (None, None)
# grid pos pp [693, 1614]
# [Mover.moveWASD] exact angle to move 265.6839724801344
# angle 225, 1, 20, [6.730e+02 1.634e+03 1.000e+00], 28.284271247461902, 28.284271247461902
# angle 270, 1.25, 53, [6.400e+02 1.614e+03 1.000e+00], 53.0, 66.25
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 110.67971810589327 at 1735708610.6430566
# found rares []
# [LootPicker.collectLoot] call at 1735708610.6440504
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (458, 623)
# [Mover.moveWASD] (631, 1617), (None, None)
# grid pos pp [685, 1614]
# [Mover.moveWASD] exact angle to move 266.8201698801358
# angle 225, 1, 20, [6.650e+02 1.634e+03 1.000e+00], 28.284271247461902, 28.284271247461902
# angle 270, 1.25, 54, [6.310e+02 1.614e+03 1.000e+00], 54.0, 67.5
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 106.3296760081587 at 1735708610.8190506
# found rares []
# [LootPicker.collectLoot] call at 1735708610.8190506
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594F47C40>, <utils.gamehelper.Entity object at 0x000002A594F3E490>, <utils.gamehelper.Entity object at 0x000002A595F54EB0>]
# going to clear
# didnt use pconc for long, throw somewhere even if theres 1 attack val
# enemy_to_attack.attack_value 3 {'ls': [88, 544], 'p': 'Metadata/Monsters/VaalHumanoids/VaalHumanoidCannon/VaalHumanoidCannonFire@77', 'r': 'Magic', 'i': 2173, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [610, 1604], 'wp': [6672, 3335, -50], 'l': [45501, 45501, 0, 200, 200, 0, 0, 0, 0], 'rn': "Doryani's Elite", 'et': 'm', 'distance_to_player': 67.7421582177598}
# pconc throw reduced to [626.75, 1606.5]
# [Skill throw_flask_poison] using  at 1735708610.8200521
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=422&y=566&mtm=-1&msm=1&wtr=1& at 1735708610.8230517
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=422&y=566&mtm=-1&msm=1&wtr=1& at 1735708610.8230517
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=right at 1735708610.8240483
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=right at 1735708610.9790504
# [Controller] debug sending action=mouseRelease&button=right at 1735708611.1200502
# [Controller] debug recieved response for action=mouseRelease&button=right at 1735708611.12105
# [SkillWithDelay throw_flask_poison]  can be used after 1735708611.1510499 1735708611.12105 0.03
# [Skill throw_flask_poison] successfully used  at 1735708611.12105
# adding explosion zone 1735708610.8200521 with [606.75, 646.75, 1586.5, 1626.5]
# [Mover] making step to (538, 563)
# [Mover.moveWASD] (623, 1617), (None, None)
# grid pos pp [677, 1614]
# [Mover.moveWASD] exact angle to move 266.8201698801358
# angle 225, 1, 17, [6.600e+02 1.631e+03 1.000e+00], 24.041630560342618, 24.041630560342618
# angle 270, 1.25, 54, [6.230e+02 1.614e+03 1.000e+00], 54.0, 67.5
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 98.6154146165801 at 1735708611.1950483
# found rares []
# [LootPicker.collectLoot] call at 1735708611.1960495
# calling usual routine
# probably casting smth atm
# [Mover] making step to (453, 644)
# [Mover.moveWASD] (607, 1619), (None, None)
# grid pos pp [660, 1614]
# [Mover.moveWASD] exact angle to move 264.6106882400266
# angle 225, 1, 14, [6.460e+02 1.628e+03 1.000e+00], 19.79898987322333, 19.79898987322333
# angle 270, 1.25, 53, [6.070e+02 1.614e+03 1.000e+00], 53.0, 66.25
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 96.79876032264049 at 1735708611.4800491
# found rares []
# [LootPicker.collectLoot] call at 1735708611.4820497
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594BFE400>, <utils.gamehelper.Entity object at 0x000002A594F43220>, <utils.gamehelper.Entity object at 0x000002A594F43E20>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (469, 632)
# [Mover.moveWASD] (601, 1619), (None, None)
# grid pos pp [655, 1614]
# [Mover.moveWASD] exact angle to move 264.7099187946287
# angle 225, 1, 10, [6.450e+02 1.624e+03 1.000e+00], 14.142135623730951, 14.142135623730951
# angle 270, 1.25, 54, [6.010e+02 1.614e+03 1.000e+00], 54.0, 67.5
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 94.92101980067429 at 1735708611.6292558
# found rares []
# [LootPicker.collectLoot] call at 1735708611.6302562
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594A915E0>, <utils.gamehelper.Entity object at 0x000002A594BFE730>, <utils.gamehelper.Entity object at 0x000002A594BFE2E0>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (482, 649)
# [Mover.moveWASD] (597, 1622), (None, None)
# grid pos pp [649, 1614]
# [Mover.moveWASD] exact angle to move 261.25383773744477
# angle 225, 1, 8, [6.410e+02 1.622e+03 1.000e+00], 11.313708498984761, 11.313708498984761
# angle 270, 1.25, 52, [5.970e+02 1.614e+03 1.000e+00], 52.0, 65.0
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 93.62157870918436 at 1735708611.7902546
# found rares []
# [LootPicker.collectLoot] call at 1735708611.7922568
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594BE8CD0>, <utils.gamehelper.Entity object at 0x000002A594BE8B80>, <utils.gamehelper.Entity object at 0x000002A594A91250>, <utils.gamehelper.Entity object at 0x000002A594A91910>]
# going to clear
# didnt use pconc for long, throw somewhere even if theres 1 attack val
# enemy_to_attack.attack_value 1 {'ls': [56, 519], 'p': 'Metadata/Monsters/VaalHumanoids/VaalHumanoidCannon/VaalHumanoidCannonFire@77', 'r': 'Magic', 'i': 2175, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [575, 1598], 'wp': [6313, 3403, -47], 'l': [45501, 45501, 0, 200, 200, 0, 0, 0, 0], 'rn': "Doryani's Elite", 'et': 'm', 'distance_to_player': 70.83078426785913}
# pconc throw reduced to [592.25, 1602.0]
# [Skill throw_flask_poison] using  at 1735708611.7922568
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=389&y=550&mtm=-1&msm=1&wtr=1& at 1735708611.8162553
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=389&y=550&mtm=-1&msm=1&wtr=1& at 1735708611.8212578
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=right at 1735708611.8212578
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=right at 1735708611.9352572
# [Controller] debug sending action=mouseRelease&button=right at 1735708612.0532587
# [Controller] debug recieved response for action=mouseRelease&button=right at 1735708612.0732572
# [SkillWithDelay throw_flask_poison]  can be used after 1735708612.1062572 1735708612.0732572 0.03
# [Skill throw_flask_poison] successfully used  at 1735708612.0732572
# adding explosion zone 1735708611.7922568 with [572.25, 612.25, 1582.0, 1622.0]
# [Mover] making step to (608, 601)
# [Mover.moveWASD] (595, 1627), (None, None)
# grid pos pp [644, 1614]
# [Mover.moveWASD] exact angle to move 255.14138555207535
# angle 225, 1, 6, [6.38e+02 1.62e+03 1.00e+00], 8.485281374238571, 8.485281374238571
# angle 270, 1.25, 50, [5.940e+02 1.614e+03 1.000e+00], 50.0, 62.5
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 91.13725912051558 at 1735708612.2003863
# found rares []
# [LootPicker.collectLoot] call at 1735708612.2101908
# calling usual routine
# probably casting smth atm
# [Mover] making step to (646, 586)
# [Mover.moveWASD] (595, 1628), (None, None)
# grid pos pp [627, 1614]
# [Mover.moveWASD] exact angle to move 246.3706222693432
# angle 225, 1.25, 7, [6.200e+02 1.621e+03 1.000e+00], 9.899494936611665, 12.374368670764582
# angle 270, 1, 34, [5.930e+02 1.614e+03 1.000e+00], 34.0, 34.0
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 91.00549433962766 at 1735708612.3612528
# found rares []
# [LootPicker.collectLoot] call at 1735708612.3692546
# {'id': 2459, 'a': 'Art/2DItems/Armours/Gloves/Basetypes/GlovesStrDex02.dds', 'l': None, 'r': 'Normal', 'gp': [615, 1595], 'sz': [316, 472, 285, 303]}
# {'id': 2460, 'a': 'Art/2DItems/Armours/BodyArmours/Basetypes/BodyInt02.dds', 'l': None, 'r': 'Normal', 'gp': [610, 1605], 'sz': [345, 486, 316, 335]}
# item label added to ignored {'id': 2459, 'a': 'Art/2DItems/Armours/Gloves/Basetypes/GlovesStrDex02.dds', 'l': None, 'r': 'Normal', 'gp': [615, 1595], 'sz': [316, 472, 285, 303]}
# item label added to ignored {'id': 2460, 'a': 'Art/2DItems/Armours/BodyArmours/Basetypes/BodyInt02.dds', 'l': None, 'r': 'Normal', 'gp': [610, 1605], 'sz': [345, 486, 316, 335]}
# calling usual routine
# probably casting smth atm
# [Mover] making step to (666, 573)
# [Mover.moveWASD] (595, 1628), (None, None)
# grid pos pp [623, 1614]
# [Mover.moveWASD] exact angle to move 243.43494882292202
# angle 225, 1.25, 6, [6.17e+02 1.62e+03 1.00e+00], 8.485281374238571, 10.606601717798213
# angle 270, 1, 31, [5.920e+02 1.614e+03 1.000e+00], 31.0, 31.0
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 92.02173656261874 at 1735708612.5112572
# found rares []
# [LootPicker.collectLoot] call at 1735708612.5152555
# calling usual routine
# removing explosion zone 1735708608.2562323 with [671.5, 711.5, 1587.25, 1627.25] , expired
# removing explosion zone 1735708608.2572322 with [655, 695, 1583, 1623] , expired
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A595FDC0D0>, <utils.gamehelper.Entity object at 0x000002A595F54910>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (679, 568)
# [Mover.moveWASD] (594, 1628), (None, None)
# grid pos pp [620, 1613]
# [Mover.moveWASD] exact angle to move 240.01836063115067
# angle 225, 1.25, 8, [6.120e+02 1.621e+03 1.000e+00], 11.313708498984761, 14.142135623730951
# angle 270, 1, 30, [5.900e+02 1.613e+03 1.000e+00], 30.0, 30.0
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 93.13431161500041 at 1735708612.6638553
# found rares []
# [LootPicker.collectLoot] call at 1735708612.6708567
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594B99B50>, <utils.gamehelper.Entity object at 0x000002A594F47550>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (714, 573)
# [Mover.moveWASD] (593, 1631), (None, None)
# grid pos pp [617, 1612]
# [Mover.moveWASD] exact angle to move 231.63251461513846
# angle 225, 1.25, 10, [6.070e+02 1.622e+03 1.000e+00], 14.142135623730951, 17.67766952966369
# angle 270, 1, 30, [5.870e+02 1.612e+03 1.000e+00], 30.0, 30.0
# [Mover.moveWASD] gonna move by angle 270
# [Mover] distance_to_target: 94.64142856064674 at 1735708612.8128653
# found rares []
# [LootPicker.collectLoot] call at 1735708612.819861
# {'id': 2462, 'a': 'Art/2DItems/Weapons/OneHandWeapons/OneHandMaces/Basetypes/1HMace03.dds', 'l': None, 'r': 'Normal', 'gp': [614, 1620], 'sz': [529, 623, 333, 352]}
# item label added to ignored {'id': 2462, 'a': 'Art/2DItems/Weapons/OneHandWeapons/OneHandMaces/Basetypes/1HMace03.dds', 'l': None, 'r': 'Normal', 'gp': [614, 1620], 'sz': [529, 623, 333, 352]}
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594F3EBE0>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (755, 559)
# [Mover.moveWASD] (592, 1633), (None, None)
# grid pos pp [611, 1611]
# [Mover.moveWASD] exact angle to move 220.8150838748816
# angle 180, 1, 10, [6.110e+02 1.621e+03 1.000e+00], 10.0, 10.0
# angle 225, 1.25, 20, [5.910e+02 1.631e+03 1.000e+00], 28.284271247461902, 35.35533905932738
# [Mover.moveWASD] gonna move by angle 225
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_A&wtr=1& at 1735708612.8228562
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_A&wtr=1& at 1735708612.8258588
# [Mover] distance_to_target: 95.70788891204319 at 1735708612.9638581
# found rares []
# [LootPicker.collectLoot] call at 1735708612.9678545
# calling usual routine
# removing explosion zone 1735708608.9538343 with [676.25, 716.25, 1568.0, 1608.0] , expired
# removing explosion zone 1735708608.9548342 with [666, 706, 1562, 1602] , expired
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594F43EE0>, <utils.gamehelper.Entity object at 0x000002A594A914F0>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (832, 598)
# [Mover.moveWASD] (588, 1645), (None, None)
# grid pos pp [604, 1611]
# [Mover.moveWASD] exact angle to move 205.20112364547506
# angle 180, 1, 11, [6.040e+02 1.622e+03 1.000e+00], 11.0, 11.0
# angle 225, 1.25, 25, [5.790e+02 1.636e+03 1.000e+00], 35.35533905932738, 44.19417382415922
# [Mover.moveWASD] gonna move by angle 225
# [Mover] distance_to_target: 92.89241088485109 at 1735708613.1048577
# found rares []
# [LootPicker.collectLoot] call at 1735708613.1108568
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594BE85E0>, <utils.gamehelper.Entity object at 0x000002A594BE8910>, <utils.gamehelper.Entity object at 0x000002A594F42DC0>, <utils.gamehelper.Entity object at 0x000002A594F42070>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (830, 563)
# [Mover.moveWASD] (588, 1645), (None, None)
# grid pos pp [599, 1615]
# [Mover.moveWASD] exact angle to move 200.13630342824814
# angle 180, 1.25, 15, [5.99e+02 1.63e+03 1.00e+00], 15.0, 18.75
# angle 225, 1, 20, [5.790e+02 1.635e+03 1.000e+00], 28.284271247461902, 28.284271247461902
# [Mover.moveWASD] gonna move by angle 225
# [Mover] distance_to_target: 89.49301648732153 at 1735708613.3168535
# found rares []
# [LootPicker.collectLoot] call at 1735708613.320854
# {'id': 2465, 'a': 'Art/2DItems/Armours/BodyArmours/Basetypes/BodyDex08.dds', 'l': None, 'r': 'Rare', 'gp': [579, 1598], 'sz': [254, 410, 277, 296]}
# item label added to ignored {'id': 2465, 'a': 'Art/2DItems/Armours/BodyArmours/Basetypes/BodyDex08.dds', 'l': None, 'r': 'Rare', 'gp': [579, 1598], 'sz': [254, 410, 277, 296]}
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A595F54D90>, <utils.gamehelper.Entity object at 0x000002A594BFFC70>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (828, 509)
# [Mover.moveWASD] (588, 1645), (None, None)
# grid pos pp [594, 1620]
# [Mover.moveWASD] exact angle to move 193.4957332807958
# angle 180, 1.25, 15, [5.940e+02 1.635e+03 1.000e+00], 15.0, 18.75
# angle 225, 1, 15, [5.790e+02 1.635e+03 1.000e+00], 21.213203435596427, 21.213203435596427
# [Mover.moveWASD] gonna move by angle 225
# [Mover] distance_to_target: 86.00581375697807 at 1735708613.5048587
# found rares []
# [LootPicker.collectLoot] call at 1735708613.5098593
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594F474C0>, <utils.gamehelper.Entity object at 0x000002A595FDC130>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (825, 456)
# [Mover.moveWASD] (588, 1645), (None, None)
# grid pos pp [588, 1626]
# [Mover.moveWASD] exact angle to move 180.0
# angle 180, 1.25, 15, [5.880e+02 1.641e+03 1.000e+00], 15.0, 18.75
# angle 225, 1, 9, [5.790e+02 1.635e+03 1.000e+00], 12.727922061357857, 12.727922061357857
# [Mover.moveWASD] gonna move by angle 180
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_D&wtr=1& at 1735708613.5158591
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_D&wtr=1& at 1735708613.51686
# [Mover] distance_to_target: 83.64807230295268 at 1735708613.6459732
# opening door {'ls': [600, 341], 'p': 'Metadata/MiscellaneousObjects/Door', 'r': 'White', 'i': 1816, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [586, 1645], 'wp': [6406, 2906, -67], 'l': None, 'rn': 'Door', 'et': 'Door', 'distance_to_player': 14.317821063276352}
# door {'ls': [600, 341], 'p': 'Metadata/MiscellaneousObjects/Door', 'r': 'White', 'i': 1816, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [586, 1645], 'wp': [6406, 2906, -67], 'l': None, 'rn': 'Door', 'et': 'Door', 'distance_to_player': 14.317821063276352} is not in line of sight
# found rares []
# [LootPicker.collectLoot] call at 1735708613.6509745
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594A919D0>, <utils.gamehelper.Entity object at 0x000002A594BFAD90>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (818, 425)
# [Mover.moveWASD] (588, 1645), (None, None)
# grid pos pp [583, 1631]
# [Mover.moveWASD] exact angle to move 160.34617594194668
# angle 135, 1, 8, [5.910e+02 1.639e+03 1.000e+00], 11.313708498984761, 11.313708498984761
# angle 180, 1.25, 10, [5.830e+02 1.641e+03 1.000e+00], 10.0, 12.5
# [Mover.moveWASD] gonna move by angle 180
# [Mover] distance_to_target: 79.75587752636166 at 1735708613.7849734
# opening door {'ls': [568, 316], 'p': 'Metadata/MiscellaneousObjects/Door', 'r': 'White', 'i': 1816, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [586, 1645], 'wp': [6406, 2906, -67], 'l': None, 'rn': 'Door', 'et': 'Door', 'distance_to_player': 9.848857801796104}
# pos on screen to open DoodadEvent from poe helper (568, 316)
# pos on screen to open DoodadEvent (782, 343)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=782&y=343&mtm=-1&msm=1 at 1735708613.7849734
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=782&y=343&mtm=-1&msm=1 at 1735708613.916972
# {'ls': [542, 296], 'p': 'Metadata/MiscellaneousObjects/Door', 'r': 'White', 'i': 1816, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [586, 1645], 'wp': [6406, 2906, -67], 'l': None, 'rn': 'Door', 'et': 'Door', 'distance_to_player': 4.47213595499958}
# pos on screen to open DoodadEvent from poe helper (542, 296)
# pos on screen to open DoodadEvent (756, 323)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=756&y=323&mtm=-1&msm=1 at 1735708613.9489725
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=756&y=323&mtm=-1&msm=1 at 1735708614.023972
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735708614.0249717
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735708614.049973
# [Controller] debug sending action=mouseRelease&button=left at 1735708614.1739721
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735708614.1779747
# {'ls': [542, 296], 'p': 'Metadata/MiscellaneousObjects/Door', 'r': 'White', 'i': 1816, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [586, 1645], 'wp': [6406, 2906, -67], 'l': None, 'rn': 'Door', 'et': 'Door', 'distance_to_player': 4.47213595499958}
# pos on screen to open DoodadEvent from poe helper (542, 296)
# pos on screen to open DoodadEvent (756, 323)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=756&y=323&mtm=-1&msm=1 at 1735708614.2099702
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=756&y=323&mtm=-1&msm=1 at 1735708614.2529747
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735708614.2529747
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735708614.2539735
# [Controller] debug sending action=mouseRelease&button=left at 1735708614.3339846
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735708614.3349874
# {'ls': [519, 280], 'p': 'Metadata/MiscellaneousObjects/Door', 'r': 'White', 'i': 1816, 'o': 1, 'h': 1, 'ia': 0, 't': 0, 'it': 0, 'em': 0, 'b': 1, 'gp': [586, 1645], 'wp': [6406, 2906, -67], 'l': None, 'rn': 'Door', 'et': 'Door', 'distance_to_player': 4.0}
# door became opened
# [Mover] distance_to_target: 67.20119046564577 at 1735708614.5751128
# found rares []
# [LootPicker.collectLoot] call at 1735708614.5761137
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (1084, 371)
# [Mover.moveWASD] (622, 1686), (None, None)
# grid pos pp [582, 1651]
# [Mover.moveWASD] exact angle to move 131.18592516570965
# angle 90, 1, 10, [5.920e+02 1.651e+03 1.000e+00], 10.0, 10.0
# angle 135, 1.25, 37, [6.190e+02 1.688e+03 1.000e+00], 52.32590180780452, 65.40737725975565
# [Mover.moveWASD] gonna move by angle 135
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_S&wtr=1& at 1735708614.5821126
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_S&wtr=1& at 1735708614.5821126
# [Mover] distance_to_target: 62.481997407253246 at 1735708614.71711
# found rares []
# [LootPicker.collectLoot] call at 1735708614.71711
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (1081, 372)
# [Mover.moveWASD] (622, 1692), (None, None)
# grid pos pp [582, 1657]
# [Mover.moveWASD] exact angle to move 131.18592516570965
# angle 90, 1, 26, [6.080e+02 1.657e+03 1.000e+00], 26.0, 26.0
# angle 135, 1.25, 37, [6.190e+02 1.694e+03 1.000e+00], 52.32590180780452, 65.40737725975565
# [Mover.moveWASD] gonna move by angle 135
# [Mover] distance_to_target: 55.31726674375732 at 1735708614.895112
# found rares []
# [LootPicker.collectLoot] call at 1735708614.8961127
# calling usual routine
# removing explosion zone 1735708610.8200521 with [606.75, 646.75, 1586.5, 1626.5] , expired
# removing explosion zone 1735708610.821052 with [590, 630, 1584, 1624] , expired
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594B47070>]
# going to clear
# didnt use pconc for long, throw somewhere even if theres 1 attack val
# enemy_to_attack.attack_value 1 {'ls': [897, 290], 'p': 'Metadata/Monsters/VaalHumanoids/VaalHumanoidBow/VaalHumanoidBow__@77', 'r': 'White', 'i': 2123, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [631, 1699], 'wp': [6895, 2328, -18], 'l': [16513, 16513, 0, 200, 200, 0, 1834, 1834, 0], 'rn': 'Archer Transcendent', 'et': 'm', 'distance_to_player': 57.628118136895644}
# pconc throw reduced to [619.75, 1690.0]
# [Skill throw_flask_poison] using  at 1735708614.8971126
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=1006&y=375&mtm=-1&msm=1&wtr=1& at 1735708614.9011137
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=1006&y=375&mtm=-1&msm=1&wtr=1& at 1735708614.902112
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=right at 1735708614.902112
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=right at 1735708615.100254
# [Controller] debug sending action=mouseRelease&button=right at 1735708615.246287
# [Controller] debug recieved response for action=mouseRelease&button=right at 1735708615.2522902
# [SkillWithDelay throw_flask_poison]  can be used after 1735708615.2822902 1735708615.2522902 0.03
# [Skill throw_flask_poison] successfully used  at 1735708615.2522902
# adding explosion zone 1735708614.8961127 with [599.75, 639.75, 1670.0, 1710.0]
# [Mover] making step to (994, 426)
# [Mover.moveWASD] (622, 1703), (None, None)
# grid pos pp [586, 1663]
# [Mover.moveWASD] exact angle to move 138.01278750418334
# angle 135, 1.25, 38, [6.240e+02 1.701e+03 1.000e+00], 53.74011537017761, 67.17514421272202
# angle 180, 1, 6, [5.860e+02 1.669e+03 1.000e+00], 6.0, 6.0
# [Mover.moveWASD] gonna move by angle 135
# [Mover] distance_to_target: 37.73592452822641 at 1735708615.4328249
# 50 points to target, almost arrived player_pos: x:602 y: 1673
# [Mover.moveWASD] (623, 1706), (None, None)
# grid pos pp [602, 1673]
# [Mover.moveWASD] exact angle to move 147.52880770915152
# angle 135, 1.25, 27, [6.29e+02 1.70e+03 1.00e+00], 38.18376618407357, 47.72970773009196
# angle 180, 1, 16, [6.020e+02 1.689e+03 1.000e+00], 16.0, 16.0
# [Mover.moveWASD] gonna move by angle 135
# mover.goToPoint result None
# willing to explore next point (776, 1512)
# exploring point (776, 1512)
# exploring point (776, 1512)
# #goToPoint point: (776, 1512), min_distance: 50, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: True, random_val: 1
# custom_break_function:<function runnerBreakFunction at 0x000002A594A749D0>, custom_continue_function:None
# heist_transition: False, step_size: 30possible_transition: False
# found rares []
# [LootPicker.collectLoot] call at 1735708615.606213
# end pos to go 775 1513
# [Mover] distance_to_target: 230.5558500667463 at 1735708615.690212
# found rares []
# [LootPicker.collectLoot] call at 1735708615.6942134
# [Mover] making step to (470, 369)
# [Mover] making first step, placing a mouse on (470, 369) and going
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=470&y=369&mtm=-1&msm=1&wtr=1& at 1735708615.707393
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=470&y=369&mtm=-1&msm=1&wtr=1& at 1735708615.7304964
# [Mover.moveWASD] (588, 1644), (None, None)
# grid pos pp [609, 1673]
# [Mover.moveWASD] exact angle to move 324.09027692082236
# angle 315, 1.25, 25, [5.840e+02 1.648e+03 1.000e+00], 35.35533905932738, 44.19417382415922
# angle 360, 1, 6, [6.090e+02 1.667e+03 1.000e+00], 6.0, 6.0
# [Mover.moveWASD] gonna move by angle 315
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_D&wtr=1& at 1735708615.731495
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_D&wtr=1& at 1735708616.036483
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_A&wtr=1& at 1735708616.036483
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_A&wtr=1& at 1735708616.0384831
# [Mover] distance_to_target: 234.13884769512296 at 1735708616.1004822
# found rares []
# [LootPicker.collectLoot] call at 1735708616.1014838
# {'id': 2527, 'a': 'Art/2DItems/Weapons/TwoHandWeapons/Bows/Basetypes/Bow08.dds', 'l': None, 'r': 'Normal', 'gp': [621, 1681], 'sz': [473, 574, 264, 283]}
# item label added to ignored {'id': 2527, 'a': 'Art/2DItems/Weapons/TwoHandWeapons/Bows/Basetypes/Bow08.dds', 'l': None, 'r': 'Normal', 'gp': [621, 1681], 'sz': [473, 574, 264, 283]}
# [Mover] making step to (379, 350)
# [Mover.moveWASD] (588, 1644), (None, None)
# grid pos pp [614, 1683]
# [Mover.moveWASD] exact angle to move 326.30993247402023
# angle 315, 1.25, 33, [5.81e+02 1.65e+03 1.00e+00], 46.66904755831214, 58.33630944789017
# angle 360, 1, 16, [6.140e+02 1.667e+03 1.000e+00], 16.0, 16.0
# [Mover.moveWASD] gonna move by angle 315
# [Mover] distance_to_target: 234.23279018958897 at 1735708616.2424834
# found rares []
# [LootPicker.collectLoot] call at 1735708616.2444842
# calling usual routine
# removing explosion zone 1735708611.7922568 with [572.25, 612.25, 1582.0, 1622.0] , expired
# removing explosion zone 1735708611.7932568 with [555, 595, 1578, 1618] , expired
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594B99BB0>, <utils.gamehelper.Entity object at 0x000002A594B99C10>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (395, 349)
# [Mover.moveWASD] (588, 1644), (None, None)
# grid pos pp [616, 1685]
# [Mover.moveWASD] exact angle to move 325.66978280449666
# angle 315, 1.25, 35, [5.81e+02 1.65e+03 1.00e+00], 49.49747468305833, 61.87184335382291
# angle 360, 1, 18, [6.160e+02 1.667e+03 1.000e+00], 18.0, 18.0
# [Mover.moveWASD] gonna move by angle 315
# [Mover] distance_to_target: 234.06195760951843 at 1735708616.42848
# found rares []
# [LootPicker.collectLoot] call at 1735708616.4304821
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594B99520>, <utils.gamehelper.Entity object at 0x000002A594F3F8B0>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (454, 349)
# [Mover.moveWASD] (588, 1644), (None, None)
# grid pos pp [611, 1680]
# [Mover.moveWASD] exact angle to move 327.4259428654275
# angle 315, 1.25, 30, [5.81e+02 1.65e+03 1.00e+00], 42.42640687119285, 53.033008588991066
# angle 360, 1, 13, [6.110e+02 1.667e+03 1.000e+00], 13.0, 13.0
# [Mover.moveWASD] gonna move by angle 315
# [Mover] distance_to_target: 234.104677441524 at 1735708616.608075
# found rares []
# [LootPicker.collectLoot] call at 1735708616.6150744
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594B99D30>, <utils.gamehelper.Entity object at 0x000002A594B99760>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (502, 349)
# [Mover.moveWASD] (588, 1644), (None, None)
# grid pos pp [606, 1675]
# [Mover.moveWASD] exact angle to move 329.85861444792465
# angle 315, 1.25, 25, [5.81e+02 1.65e+03 1.00e+00], 35.35533905932738, 44.19417382415922
# angle 360, 1, 21, [6.060e+02 1.654e+03 1.000e+00], 21.0, 21.0
# [Mover.moveWASD] gonna move by angle 315
# [Mover] distance_to_target: 234.29255216502293 at 1735708616.7570808
# found rares []
# [LootPicker.collectLoot] call at 1735708616.7600813
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A595F573A0>, <utils.gamehelper.Entity object at 0x000002A595F57910>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (548, 349)
# [Mover.moveWASD] (588, 1644), (None, None)
# grid pos pp [602, 1671]
# [Mover.moveWASD] exact angle to move 332.5924245621816
# angle 315, 1.25, 21, [5.81e+02 1.65e+03 1.00e+00], 29.698484809834998, 37.123106012293746
# angle 360, 1, 17, [6.020e+02 1.654e+03 1.000e+00], 17.0, 17.0
# [Mover.moveWASD] gonna move by angle 315
# [Mover] distance_to_target: 234.82972554597936 at 1735708616.9080784
# found rares []
# [LootPicker.collectLoot] call at 1735708616.911081
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A595F6DBE0>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (597, 349)
# [Mover.moveWASD] (588, 1644), (None, None)
# grid pos pp [596, 1665]
# [Mover.moveWASD] exact angle to move 339.14554196042167
# angle 315, 1, 15, [5.81e+02 1.65e+03 1.00e+00], 21.213203435596427, 21.213203435596427
# angle 360, 1.25, 11, [5.960e+02 1.654e+03 1.000e+00], 11.0, 13.75
# [Mover.moveWASD] gonna move by angle 315
# [Mover] distance_to_target: 235.51008470976353 at 1735708617.1300805
# found rares []
# [LootPicker.collectLoot] call at 1735708617.1380823
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (659, 350)
# [Mover.moveWASD] (588, 1644), (None, None)
# grid pos pp [591, 1660]
# [Mover.moveWASD] exact angle to move 349.38034472384487
# angle 315, 1, 10, [5.81e+02 1.65e+03 1.00e+00], 14.142135623730951, 14.142135623730951
# angle 360, 1.25, 12, [5.910e+02 1.648e+03 1.000e+00], 12.0, 15.0
# [Mover.moveWASD] gonna move by angle 0
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_W&wtr=1& at 1735708617.1480806
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_W&wtr=1& at 1735708617.1510806
# [Mover] distance_to_target: 235.80076335754302 at 1735708617.3470778
# found rares []
# [LootPicker.collectLoot] call at 1735708617.3560781
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (728, 372)
# [Mover.moveWASD] (588, 1644), (None, None)
# grid pos pp [586, 1654]
# [Mover.moveWASD] exact angle to move 11.30993247402023
# angle 0, 1.25, 6, [5.860e+02 1.648e+03 1.000e+00], 6.0, 7.5
# angle 45, 1, 5, [5.910e+02 1.649e+03 1.000e+00], 7.0710678118654755, 7.0710678118654755
# [Mover.moveWASD] gonna move by angle 0
# [Mover] distance_to_target: 231.04328598771272 at 1735708617.5020828
# [Pather] cant find point in los
# [Mover] len(current_path) == 0, generating new path
# [Mover] distance_to_target: 229.3686988235317 at 1735708617.5546844
# found rares []
# [LootPicker.collectLoot] call at 1735708617.555681
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (707, 162)
# [Mover.moveWASD] (619, 1600), (None, None)
# grid pos pp [584, 1640]
# [Mover.moveWASD] exact angle to move 41.18592516570965
# angle 0, 1, 53, [5.840e+02 1.587e+03 1.000e+00], 53.0, 53.0
# angle 45, 1.25, 15, [5.990e+02 1.625e+03 1.000e+00], 21.213203435596427, 26.516504294495533
# [Mover.moveWASD] gonna move by angle 0
# [Mover] distance_to_target: 226.63847863944025 at 1735708617.7066844
# found rares []
# [LootPicker.collectLoot] call at 1735708617.7066844
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A595FCFDF0>, <utils.gamehelper.Entity object at 0x000002A595FCF8B0>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (764, 165)
# [Mover.moveWASD] (625, 1600), (None, None)
# grid pos pp [584, 1635]
# [Mover.moveWASD] exact angle to move 49.51398845800128
# angle 45, 1.25, 38, [6.220e+02 1.597e+03 1.000e+00], 53.74011537017761, 67.17514421272202
# angle 90, 1, 10, [5.940e+02 1.635e+03 1.000e+00], 10.0, 10.0
# [Mover.moveWASD] gonna move by angle 45
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_A&wtr=1& at 1735708617.7146814
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_A&wtr=1& at 1735708617.7156808
# [Mover] distance_to_target: 222.94842452908253 at 1735708617.8866777
# found rares []
# [LootPicker.collectLoot] call at 1735708617.8876982
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594B47F70>, <utils.gamehelper.Entity object at 0x000002A594B47D60>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (804, 176)
# [Mover.moveWASD] (630, 1600), (None, None)
# grid pos pp [584, 1628]
# [Mover.moveWASD] exact angle to move 58.67130713219581
# angle 45, 1.25, 35, [6.190e+02 1.593e+03 1.000e+00], 49.49747468305833, 61.87184335382291
# angle 90, 1, 15, [5.990e+02 1.628e+03 1.000e+00], 15.0, 15.0
# [Mover.moveWASD] gonna move by angle 45
# [Mover] distance_to_target: 216.0925727552893 at 1735708618.0526772
# found rares []
# ...
# distance_to_entity 19.209372712298546 in killUsual
# skill_use_delay 2.1
# kiting
# around
# [Mover.moveWASD] (1381, 391), (None, None)
# grid pos pp [1364, 436]
# [Mover.moveWASD] exact angle to move 20.695450734063286
# angle 0, 1.25, 1, [1.364e+03 4.350e+02 1.000e+00], 1.0, 1.25
# angle 45, 1, 1, [1.365e+03 4.350e+02 1.000e+00], 1.4142135623730951, 1.4142135623730951
# [Mover.moveWASD] gonna move by angle 45
# [Controller] debug recieved response for action=mouseRelease&button=right at 1735708964.41504
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_A&wtr=1& at 1735708964.4260414
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_A&wtr=1& at 1735708964.4260414
# found broken entity {'ls': [0, 0], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/rain_of_arrow_caustic', 'r': 'White', 'i': 4237, 'o': 0, 'h': 1, 'ia': 0, 't': 0, 'it': 0, 'em': 0, 'b': 0, 'gp': [0, 1909], 'wp': [0, 0, 0], 'l': None, 'rn': 'Empty', 'et': 'None', 'distance_to_player': 2008.9552010933444}
# entity_to_kill {'ls': [384, 312], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/ViperLegionnaireBow_@77', 'r': 'Rare', 'i': 2066, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [1352, 421], 'wp': [14728, 16206, -423], 'l': [167744, 52007, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Viper Legionnaire', 'et': 'm', 'distance_to_player': 19.1049731745428}
# distance_to_entity 19.1049731745428 in killUsual
# getting closer in killUsual
# found broken entity {'ls': [0, 0], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/rain_of_arrow_caustic', 'r': 'White', 'i': 4237, 'o': 0, 'h': 1, 'ia': 0, 't': 0, 'it': 0, 'em': 0, 'b': 0, 'gp': [0, 1909], 'wp': [0, 0, 0], 'l': None, 'rn': 'Empty', 'et': 'None', 'distance_to_player': 2010.3146519885888}
# [Mover] distance_to_target: 29.20616373302047 at 1735708964.7034943
# check first_attack_time 1735708962.7604547
# first_attack_time + max_kill_time_sec < _t 1735708962.7604547 + 90 < 1735708964.706507
# first_attack_time 1735708962.7604547
# #build.killUsual {'ls': [-79, -120], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/ViperLegionnaireBow_@77', 'r': 'Rare', 'i': 2066, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1333, 404], 'wp': [14521, 16391, -423], 'l': [167744, 167744, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Viper Legionnaire', 'et': 'm', 'distance_to_player': 165.01212076693034}
# entity_to_kill {'ls': [357, 325], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/ViperLegionnaireBow_@77', 'r': 'Rare', 'i': 2066, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [1352, 421], 'wp': [14728, 16206, -423], 'l': [167744, 37165, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Viper Legionnaire', 'et': 'm', 'distance_to_player': 20.518284528683193}
# distance_to_entity 20.518284528683193 in killUsual
# getting closer in killUsual
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594BB6220>, <utils.gamehelper.Entity object at 0x000002A594BB6580>, <utils.gamehelper.Entity object at 0x000002A594BB61C0>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (606, 429)
# [Mover.moveWASD] (1353, 427), (None, None)
# grid pos pp [1367, 435]
# [Mover.moveWASD] exact angle to move 299.74488129694225
# angle 270, 1, 16, [1.351e+03 4.350e+02 1.000e+00], 16.0, 16.0
# angle 315, 1.25, 0, [1366.  434.    0.], 1.4142135623730951, 1.7677669529663689
# [Mover.moveWASD] gonna move by angle 270
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_S&wtr=1& at 1735708964.7094944
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_S&wtr=1& at 1735708964.7104914
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_W&wtr=1& at 1735708964.7104914
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_W&wtr=1& at 1735708964.7104914
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_A&wtr=1& at 1735708964.7104914
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_A&wtr=1& at 1735708964.7114918
# found broken entity {'ls': [0, 0], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/rain_of_arrow_caustic', 'r': 'White', 'i': 4237, 'o': 0, 'h': 1, 'ia': 0, 't': 0, 'it': 0, 'em': 0, 'b': 0, 'gp': [0, 1909], 'wp': [0, 0, 0], 'l': None, 'rn': 'Empty', 'et': 'None', 'distance_to_player': 2013.0367607174987}
# [Mover] distance_to_target: 32.449961479175904 at 1735708964.8404958
# check first_attack_time 1735708962.7604547
# first_attack_time + max_kill_time_sec < _t 1735708962.7604547 + 90 < 1735708964.8444922
# first_attack_time 1735708962.7604547
# #build.killUsual {'ls': [-79, -120], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/ViperLegionnaireBow_@77', 'r': 'Rare', 'i': 2066, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1333, 404], 'wp': [14521, 16391, -423], 'l': [167744, 167744, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Viper Legionnaire', 'et': 'm', 'distance_to_player': 165.01212076693034}
# entity_to_kill {'ls': [346, 332], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/ViperLegionnaireBow_@77', 'r': 'Rare', 'i': 2066, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [1352, 421], 'wp': [14728, 16206, -423], 'l': [167744, 22324, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Viper Legionnaire', 'et': 'm', 'distance_to_player': 23.60084744241189}
# distance_to_entity 23.60084744241189 in killUsual
# getting closer in killUsual
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594BB6670>, <utils.gamehelper.Entity object at 0x000002A594BB6A60>, <utils.gamehelper.Entity object at 0x000002A594BB6610>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (607, 442)
# [Mover.moveWASD] (1353, 429), (None, None)
# grid pos pp [1371, 435]
# [Mover.moveWASD] exact angle to move 288.434948822922
# angle 270, 1.25, 18, [1.353e+03 4.350e+02 1.000e+00], 18.0, 22.5
# angle 315, 1, 0, [1370.  434.    0.], 1.4142135623730951, 1.4142135623730951
# [Mover.moveWASD] gonna move by angle 270
# found broken entity {'ls': [0, 0], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/rain_of_arrow_caustic', 'r': 'White', 'i': 4237, 'o': 0, 'h': 1, 'ia': 0, 't': 0, 'it': 0, 'em': 0, 'b': 0, 'gp': [0, 1909], 'wp': [0, 0, 0], 'l': None, 'rn': 'Empty', 'et': 'None', 'distance_to_player': 2011.6751725862703}
# [Mover] distance_to_target: 30.80584360149873 at 1735708964.9924953
# check first_attack_time 1735708962.7604547
# first_attack_time + max_kill_time_sec < _t 1735708962.7604547 + 90 < 1735708964.9944892
# first_attack_time 1735708962.7604547
# #build.killUsual {'ls': [-79, -120], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/ViperLegionnaireBow_@77', 'r': 'Rare', 'i': 2066, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1333, 404], 'wp': [14521, 16391, -423], 'l': [167744, 167744, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Viper Legionnaire', 'et': 'm', 'distance_to_player': 165.01212076693034}
# entity_to_kill {'ls': [356, 324], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/ViperLegionnaireBow_@77', 'r': 'Rare', 'i': 2066, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [1352, 421], 'wp': [14728, 16206, -423], 'l': [167744, 128841, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Viper Legionnaire', 'et': 'm', 'distance_to_player': 22.022715545545243}
# distance_to_entity 22.022715545545243 in killUsual
# getting closer in killUsual
# calling usual routine
# removing explosion zone 1735708960.994196 with [1296.0, 1336.0, 417.0, 457.0] , expired
# removing explosion zone 1735708960.9951959 with [1291, 1331, 401, 441] , expired
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594BB6F70>, <utils.gamehelper.Entity object at 0x000002A594BB6BE0>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (609, 431)
# [Mover.moveWASD] (1353, 428), (None, None)
# grid pos pp [1369, 435]
# [Mover.moveWASD] exact angle to move 293.6293777306568
# angle 270, 1, 17, [1.352e+03 4.350e+02 1.000e+00], 17.0, 17.0
# angle 315, 1.25, 0, [1368.  434.    0.], 1.4142135623730951, 1.7677669529663689
# [Mover.moveWASD] gonna move by angle 270
# found broken entity {'ls': [0, 0], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/rain_of_arrow_caustic', 'r': 'White', 'i': 4237, 'o': 0, 'h': 1, 'ia': 0, 't': 0, 'it': 0, 'em': 0, 'b': 0, 'gp': [0, 1909], 'wp': [0, 0, 0], 'l': None, 'rn': 'Empty', 'et': 'None', 'distance_to_player': 2010.3146519885888}
# [Mover] distance_to_target: 29.20616373302047 at 1735708965.149493
# check first_attack_time 1735708962.7604547
# first_attack_time + max_kill_time_sec < _t 1735708962.7604547 + 90 < 1735708965.1524944
# first_attack_time 1735708962.7604547
# #build.killUsual {'ls': [-79, -120], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/ViperLegionnaireBow_@77', 'r': 'Rare', 'i': 2066, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1333, 404], 'wp': [14521, 16391, -423], 'l': [167744, 167744, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Viper Legionnaire', 'et': 'm', 'distance_to_player': 165.01212076693034}
# entity_to_kill {'ls': [369, 312], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/ViperLegionnaireBow_@77', 'r': 'Rare', 'i': 2066, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [1352, 421], 'wp': [14728, 16206, -423], 'l': [167744, 111411, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Viper Legionnaire', 'et': 'm', 'distance_to_player': 20.518284528683193}
# distance_to_entity 20.518284528683193 in killUsual
# getting closer in killUsual
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x000002A594BB6E20>, <utils.gamehelper.Entity object at 0x000002A594BB67F0>]
# going to clear
# no enemies outside of the zone
# [Mover] making step to (623, 410)
# [Mover.moveWASD] (1353, 427), (None, None)
# grid pos pp [1367, 435]
# [Mover.moveWASD] exact angle to move 299.74488129694225
# angle 270, 1, 16, [1.351e+03 4.350e+02 1.000e+00], 16.0, 16.0
# angle 315, 1.25, 0, [1366.  434.    0.], 1.4142135623730951, 1.7677669529663689
# [Mover.moveWASD] gonna move by angle 270
# found broken entity {'ls': [0, 0], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/rain_of_arrow_caustic', 'r': 'White', 'i': 4237, 'o': 0, 'h': 1, 'ia': 0, 't': 0, 'it': 0, 'em': 0, 'b': 0, 'gp': [0, 1909], 'wp': [0, 0, 0], 'l': None, 'rn': 'Empty', 'et': 'None', 'distance_to_player': 2006.9180351972525}
# [Mover] distance_to_target: 25.455844122715714 at 1735708965.2974935
# check first_attack_time 1735708962.7604547
# first_attack_time + max_kill_time_sec < _t 1735708962.7604547 + 90 < 1735708965.2974935
# first_attack_time 1735708962.7604547
# #build.killUsual {'ls': [-79, -120], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/ViperLegionnaireBow_@77', 'r': 'Rare', 'i': 2066, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1333, 404], 'wp': [14521, 16391, -423], 'l': [167744, 167744, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Viper Legionnaire', 'et': 'm', 'distance_to_player': 165.01212076693034}
# entity_to_kill {'ls': [395, 294], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/ViperLegionnaireBow_@77', 'r': 'Rare', 'i': 2066, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1352, 421], 'wp': [14728, 16206, -423], 'l': [167744, 75342, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Viper Legionnaire', 'et': 'm', 'distance_to_player': 17.204650534085253}
# distance_to_entity 17.204650534085253 in killUsual
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=609&y=334&mtm=-1&msm=1&wtr=1& at 1735708965.2974935
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=609&y=334&mtm=-1&msm=1&wtr=1& at 1735708965.3034916
# found broken entity {'ls': [0, 0], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/rain_of_arrow_caustic', 'r': 'White', 'i': 4237, 'o': 0, 'h': 1, 'ia': 0, 't': 0, 'it': 0, 'em': 0, 'b': 0, 'gp': [0, 1909], 'wp': [0, 0, 0], 'l': None, 'rn': 'Empty', 'et': 'None', 'distance_to_player': 2006.2395171065693}
# entity_to_kill {'ls': [402, 289], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/ViperLegionnaireBow_@77', 'r': 'Rare', 'i': 2066, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1352, 421], 'wp': [14728, 16206, -423], 'l': [167744, 66158, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Viper Legionnaire', 'et': 'm', 'distance_to_player': 16.64331697709324}
# distance_to_entity 16.64331697709324 in killUsual
# skill_use_delay 2.9
# [Skill throw_flask_poison] using  at 1735708965.3584902
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=616&y=329&mtm=-1&msm=1&wtr=1& at 1735708965.3584902
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=616&y=329&mtm=-1&msm=1&wtr=1& at 1735708965.3624916
# [SkillWithDelay throw_flask_poison]  can be used after 1735708965.3924916 1735708965.3624916 0.03
# [Skill throw_flask_poison] successfully used  at 1735708965.3624916
# kiting
# around
# [Mover.moveWASD] (1352, 455), (None, None)
# grid pos pp [1361, 435]
# [Mover.moveWASD] exact angle to move 204.22774531795417
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=right at 1735708965.3634906
# angle 180, 1, 19, [1.361e+03 4.540e+02 1.000e+00], 19.0, 19.0
# angle 225, 1.25, 15, [1.346e+03 4.500e+02 1.000e+00], 21.213203435596427, 26.516504294495533
# [Mover.moveWASD] gonna move by angle 225
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=right at 1735708965.4354944
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_A&wtr=1& at 1735708965.4374952
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_A&wtr=1& at 1735708965.4394934
# entity_to_kill {'ls': [435, 265], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/ViperLegionnaireBow_@77', 'r': 'Rare', 'i': 2066, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1352, 421], 'wp': [14728, 16206, -423], 'l': [167744, 43196, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Viper Legionnaire', 'et': 'm', 'distance_to_player': 14.317821063276352}
# distance_to_entity 14.317821063276352 in killUsual
# skill_use_delay 2.3
# kiting
# away
# angle 180, 1, 14, [1.355e+03 4.490e+02 1.000e+00], 14.0, 14.0
# angle 225, 0.75, 10, [1.345e+03 4.450e+02 1.000e+00], 14.142135623730951, 10.606601717798213
# angle 135, 0.75, 10, [1.365e+03 4.450e+02 1.000e+00], 14.142135623730951, 10.606601717798213
# angle 270, 0.5625, 5, [1.35e+03 4.35e+02 1.00e+00], 5.0, 2.8125
# angle 90, 0.5625, 14, [1.369e+03 4.350e+02 1.000e+00], 14.0, 7.875
# angle 315, 0.421875, 5, [1.35e+03 4.30e+02 1.00e+00], 7.0710678118654755, 2.9831067331307475
# angle 45, 0.421875, 5, [1.36e+03 4.30e+02 1.00e+00], 7.0710678118654755, 2.9831067331307475
# [Mover.moveWASD] (1355, 449), (None, None)
# grid pos pp [1355, 435]
# [Mover.moveWASD] exact angle to move 180.0
# angle 180, 1.25, 14, [1.355e+03 4.490e+02 1.000e+00], 14.0, 17.5
# angle 225, 1, 9, [1.346e+03 4.440e+02 1.000e+00], 12.727922061357857, 12.727922061357857
# [Mover.moveWASD] gonna move by angle 180
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_D&wtr=1& at 1735708965.5294917
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_D&wtr=1& at 1735708965.530491
# [Controller] debug sending action=mouseRelease&button=right at 1735708965.5811217
# [Controller] debug recieved response for action=mouseRelease&button=right at 1735708965.5851223
# entity_to_kill {'ls': [443, 237], 'p': 'Metadata/Monsters/VaalMonsters/ViperLegionnaire/ViperLegionnaireBow_@77', 'r': 'Rare', 'i': 2066, 'o': 0, 'h': 1, 'ia': 1, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1352, 421], 'wp': [14728, 16206, -423], 'l': [167744, 14482, 0, 200, 200, 0, 0, 0, 0], 'rn': 'Viper Legionnaire', 'et': 'm', 'distance_to_player': 16.492422502470642}
# distance_to_entity 16.492422502470642 in killUsual
# getting closer in killUsual
# [Mover] distance_to_target: 27.16615541441225 at 1735708965.915137
# entities_to_kill not found, looks like dead
# entities_to_kill not found, looks like dead
# mover.goToPoint result True
# poe_bot.game_data.map_info.map_completed == True

# %%
# open portal and enter it
def openPortal():
  poe_bot.bot_controls.releaseAll()

  time.sleep(random.randint(40,80)/100)
  pos_x, pos_y = random.randint(709,711), random.randint(694,696)
  pos_x, pos_y = poe_bot.convertPosXY(pos_x, pos_y, safe=False)
  poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
  time.sleep(random.randint(40,80)/100)
  poe_bot.bot_controls.mouse.click()
  time.sleep(random.randint(30,60)/100)

while True:
  poe_bot.refreshInstanceData()
  loot_collected = poe_bot.loot_picker.collectLoot()
  if loot_collected == True:
    continue
  killed_smth = poe_bot.combat_module.clearAreaAroundPoint(poe_bot.game_data.player.grid_pos.toList())
  
  if poe_bot.game_data.invites_panel_visible == False and killed_smth == False:
    openPortal()
    poe_bot.helper_functions.waitForPortalNearby()
    poe_bot.helper_functions.getToPortal(check_for_map_device=False, refresh_area=False)
    poe_bot.refreshInstanceData()
    killed_smth = poe_bot.combat_module.clearAreaAroundPoint(poe_bot.game_data.player.grid_pos.toList())
# Out:
# [LootPicker.collectLoot] call at 1735708966.0831196
# {'id': 4240, 'a': 'Art/2DItems/Currency/Ruthless/CoinPileTier2.dds', 'l': None, 'r': None, 'gp': [1317, 477], 'sz': [475, 528, 574, 593]}
# item label added to ignored {'id': 4240, 'a': 'Art/2DItems/Currency/Ruthless/CoinPileTier2.dds', 'l': None, 'r': None, 'gp': [1317, 477], 'sz': [475, 528, 574, 593]}
# {'id': 4241, 'a': 'Art/2DItems/Weapons/TwoHandWeapons/Crossbows/2HCrossbow02.dds', 'l': None, 'r': 'Magic', 'gp': [1330, 469], 'sz': [466, 592, 434, 452]}
# {'id': 4244, 'a': 'Art/2DItems/Armours/Gloves/Basetypes/GlovesIntStr03.dds', 'l': None, 'r': 'Magic', 'gp': [1352, 471], 'sz': [581, 722, 391, 410]}
# {'id': 4254, 'a': 'Art/2DItems/Currency/CurrencyUpgradeToMagic.dds', 'l': None, 'r': None, 'gp': [1351, 429], 'sz': [372, 496, 234, 253]}
# {'id': 4255, 'a': 'Art/2DItems/Weapons/TwoHandWeapons/Bows/Basetypes/Bow06.dds', 'l': None, 'r': 'Rare', 'gp': [1351, 429], 'sz': [370, 497, 216, 234]}
# {'id': 4256, 'a': 'Art/2DItems/Armours/Helmets/Basetypes/HelmetInt05.dds', 'l': None, 'r': 'Rare', 'gp': [1351, 429], 'sz': [371, 495, 272, 291]}
# {'id': 4257, 'a': 'Art/2DItems/Currency/CurrencyUpgradeToMagic.dds', 'l': None, 'r': None, 'gp': [1351, 429], 'sz': [372, 496, 291, 309]}
# {'id': 4258, 'a': 'Art/2DItems/Weapons/TwoHandWeapons/WarStaves/Warstaff07.dds', 'l': None, 'r': 'Magic', 'gp': [1352, 429], 'sz': [364, 515, 197, 216]}
# {'id': 4270, 'a': 'Art/2DItems/Weapons/TwoHandWeapons/TwoHandMaces/Basetypes/2HMace08.dds', 'l': None, 'r': 'Rare', 'gp': [1352, 421], 'sz': [331, 481, 178, 197]}
# {'id': 4271, 'a': 'Art/2DItems/Weapons/OneHandWeapons/OneHandMaces/Basetypes/1HMace07.dds', 'l': None, 'r': 'Rare', 'gp': [1352, 421], 'sz': [319, 492, 159, 178]}
# {'id': 4272, 'a': 'Art/2DItems/Currency/Ruthless/CoinPileTier2.dds', 'l': None, 'r': None, 'gp': [1355, 418], 'sz': [380, 433, 253, 272]}
# item label added to ignored {'id': 4272, 'a': 'Art/2DItems/Currency/Ruthless/CoinPileTier2.dds', 'l': None, 'r': None, 'gp': [1355, 418], 'sz': [380, 433, 253, 272]}
# {'id': 4273, 'a': 'Art/2DItems/Armours/BodyArmours/Basetypes/BodyStrDex02.dds', 'l': None, 'r': 'Magic', 'gp': [1352, 421], 'sz': [336, 475, 141, 159]}
# {'id': 4274, 'a': 'Art/2DItems/Currency/Ruthless/CoinPileTier2.dds', 'l': None, 'r': None, 'gp': [1349, 418], 'sz': [317, 370, 221, 239]}
# item label added to ignored {'id': 4274, 'a': 'Art/2DItems/Currency/Ruthless/CoinPileTier2.dds', 'l': None, 'r': None, 'gp': [1349, 418], 'sz': [317, 370, 221, 239]}
# {'id': 4275, 'a': 'Art/2DItems/Gems/UncutSkillGem.dds', 'l': None, 'r': None, 'gp': [1352, 421], 'sz': [360, 451, 309, 328]}
# item label added to ignored {'id': 4241, 'a': 'Art/2DItems/Weapons/TwoHandWeapons/Crossbows/2HCrossbow02.dds', 'l': None, 'r': 'Magic', 'gp': [1330, 469], 'sz': [466, 592, 434, 452]}
# item label added to ignored {'id': 4244, 'a': 'Art/2DItems/Armours/Gloves/Basetypes/GlovesIntStr03.dds', 'l': None, 'r': 'Magic', 'gp': [1352, 471], 'sz': [581, 722, 391, 410]}
# item label added to ignored {'id': 4254, 'a': 'Art/2DItems/Currency/CurrencyUpgradeToMagic.dds', 'l': None, 'r': None, 'gp': [1351, 429], 'sz': [372, 496, 234, 253]}
# item label added to ignored {'id': 4255, 'a': 'Art/2DItems/Weapons/TwoHandWeapons/Bows/Basetypes/Bow06.dds', 'l': None, 'r': 'Rare', 'gp': [1351, 429], 'sz': [370, 497, 216, 234]}
# item label added to ignored {'id': 4256, 'a': 'Art/2DItems/Armours/Helmets/Basetypes/HelmetInt05.dds', 'l': None, 'r': 'Rare', 'gp': [1351, 429], 'sz': [371, 495, 272, 291]}
# item label added to ignored {'id': 4257, 'a': 'Art/2DItems/Currency/CurrencyUpgradeToMagic.dds', 'l': None, 'r': None, 'gp': [1351, 429], 'sz': [372, 496, 291, 309]}
# item label added to ignored {'id': 4258, 'a': 'Art/2DItems/Weapons/TwoHandWeapons/WarStaves/Warstaff07.dds', 'l': None, 'r': 'Magic', 'gp': [1352, 429], 'sz': [364, 515, 197, 216]}
# item label added to ignored {'id': 4270, 'a': 'Art/2DItems/Weapons/TwoHandWeapons/TwoHandMaces/Basetypes/2HMace08.dds', 'l': None, 'r': 'Rare', 'gp': [1352, 421], 'sz': [331, 481, 178, 197]}
# item label added to ignored {'id': 4271, 'a': 'Art/2DItems/Weapons/OneHandWeapons/OneHandMaces/Basetypes/1HMace07.dds', 'l': None, 'r': 'Rare', 'gp': [1352, 421], 'sz': [319, 492, 159, 178]}
# item label added to ignored {'id': 4273, 'a': 'Art/2DItems/Armours/BodyArmours/Basetypes/BodyStrDex02.dds', 'l': None, 'r': 'Magic', 'gp': [1352, 421], 'sz': [336, 475, 141, 159]}
# item label added to ignored {'id': 4275, 'a': 'Art/2DItems/Gems/UncutSkillGem.dds', 'l': None, 'r': None, 'gp': [1352, 421], 'sz': [360, 451, 309, 328]}
# #clearLocationAroundPoint around point {'X': 1347, 'Y': 446} ignore_keys: []
# going to {'X': 1347, 'Y': 446}
# #goToPoint point: [1347, 446], min_distance: 40, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: True, random_val: 1
# custom_break_function:<function alwaysFalseFunction at 0x000002A5FFDAE9D0>, custom_continue_function:<bound method PathfinderPoisonConc2.usualRoutine of <utils.combat.PathfinderPoisonConc2 object at 0x000002A594BFAF40>>
# heist_transition: False, step_size: 28possible_transition: False
# end pos to go 1346 445
# useless call of gotopoint arrived = True
# [Controller] debug sending action=releaseAll at 1735708966.097121
# [Controller] debug recieved response for action=releaseAll at 1735708966.1051226
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=925&y=735&mtm=-1&msm=1 at 1735708966.5997534
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=925&y=735&mtm=-1&msm=1 at 1735708966.7457514
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735708967.236768
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735708967.2657719
# [Controller] debug sending action=mouseRelease&button=left at 1735708967.380751
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735708967.3817658
# #waitForNewPortals 1735708967.6973832
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# [Controller] debug sending action=releaseAll at 1735708969.4370189
# [Controller] debug recieved response for action=releaseAll at 1735708969.438006
# #resurrectAtCheckpoint call 1735708969.438006
# initial_area_instance MapVaalFactory_NoBoss
# waiting for resurrect panel to appear
# resurrect panel appeared
# current_area MapVaalFactory_NoBoss
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=662&y=605&mtm=-1&msm=1 at 1735708970.1676564
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=662&y=605&mtm=-1&msm=1 at 1735708970.25966
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735708970.945259
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735708970.9802575
# [Controller] debug sending action=mouseRelease&button=left at 1735708971.0712554
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735708971.072258
# resurrect panel disappeared
# #resurrectAtCheckpoint return 1735708971.520259
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[25], line 22
#      20 if poe_bot.game_data.invites_panel_visible == False and killed_smth == False:
#      21   openPortal()
# ---> 22   poe_bot.helper_functions.waitForPortalNearby()
#      23   poe_bot.helper_functions.getToPortal(check_for_map_device=False, refresh_area=False)
#      24   poe_bot.refreshInstanceData()
#
# File c:\p2\1_host\utils\helper_functions.py:336, in HelperFunctions.waitForPortalNearby(self, wait_for_seconds, distance)
#     334 while time_now < start_time + wait_for_seconds:
#     335   time_now = time.time()
# --> 336   poe_bot.refreshInstanceData()
#     337   nearby_portals = list(filter(lambda e: "Metadata/MiscellaneousObjects/MultiplexPortal" in e.path and e.distance_to_player < distance, poe_bot.game_data.entities.all_entities))
#     338   print("checking if portals around")
#
# File c:\p2\1_host\utils\gamehelper.py:219, in PoeBot.refreshInstanceData(self, refreshed_data, force, check_if_lag, reset_timer, raise_if_loading)
#     217 self.bot_controls.releaseAll()
#     218 if self.on_death_function is not None:
# --> 219   self.on_death_function()
#     220 else:
#     221   raise Exception("player is dead")
#
# File c:\p2\1_host\utils\gamehelper.py:256, in PoeBot.defaultOnDeathFunction(self)
#     254 def defaultOnDeathFunction(self):
#     255   self.resurrectAtCheckpoint()
# --> 256   raise Exception("character is dead")
#
# Exception: character is dead

# %%
raise 404

# %%
prefer_high_tier = True

# %%
poe_bot.refreshAll()

# %%
tsp = TSP(poe_bot)

tsp.generatePointsForDiscovery()
#TODO astar sorting
discovery_points = tsp.sortedPointsForDiscovery()

# %%
poe_bot.game_data.player.grid_pos.toList()

# %%
discovery_points

# %%
poe_bot.backend.getMapInfo()

# %%
poe_bot.backend.getMapInfo()

# %%
poe_bot.game_data.map_info.update()

# %%
poe_bot.game_data.map_info.map_completed

# %%
poe_bot.refreshAll()

# %%
poe_bot.game_data.player.grid_pos.toList()

# %%
poe_bot.mover.move(*poe_bot.game_data.player.grid_pos.toList())

# %%
# poe_bot.mo

# %%
import matplotlib.pyplot as plt

plt.imshow(poe_bot.game_data.terrain.passable)

# %%
poe_bot.refreshAll()
for e in poe_bot.game_data.labels_on_ground_entities:
  print(e.raw)
