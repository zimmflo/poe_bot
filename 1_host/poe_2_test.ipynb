# %%
import time
import random
import sys
from ast import literal_eval

from utils.gamehelper import Poe2Bot

# %%
from utils.combat import InfernalistZoomancer

# %%
notebook_dev = False
# readability
poe_bot_class = Poe2Bot
poe_bot: poe_bot_class

# %%
default_config = {
  "REMOTE_IP": '172.22.159.221', # z2
  "unique_id": "poe_2_test",
  "build": "EaBallistasEle",
  "password": None,
  "max_lvl": 101,
  "chromatics_recipe": True,
  "force_reset_temp": False,
}



try:
  i = sys.argv[1]
  print(i)
  parsed_config = literal_eval(i)
  print(f'successfully parsed cli config')
  print(f'parsed_config: {parsed_config}')
except:
  print(f'cannot parse config from cli, using default\dev one')
  notebook_dev = True
  parsed_config = default_config
  parsed_config['unique_id'] = poe_bot_class.getDevKey()

config = {

}

for key in default_config.keys():
  config[key] = parsed_config.get(key, default_config[key])

print(f'config to run {config}')
# Out:
# --f=c:\Users\1\AppData\Roaming\jupyter\runtime\kernel-v2-12992YTbZcBmAPW7Z.json
# cannot parse config from cli, using default\dev one
# config to run {'REMOTE_IP': '172.22.159.221', 'unique_id': '7d1165934e24534a1ba5', 'build': 'EaBallistasEle', 'password': None, 'max_lvl': 101, 'chromatics_recipe': True, 'force_reset_temp': False}

# %%
REMOTE_IP = config['REMOTE_IP'] # REMOTE_IP
UNIQUE_ID = config['unique_id'] # unique id
MAX_LVL = config.get('max_lvl')
CHROMATICS_RECIPE = config['chromatics_recipe']
BUILD_NAME = config['build'] # build_name
password = config['password']
force_reset_temp = config['force_reset_temp']
print(f'running aqueduct using: REMOTE_IP: {REMOTE_IP} unique_id: {UNIQUE_ID} max_lvl: {MAX_LVL} chromatics_recipe: {CHROMATICS_RECIPE} force_reset_temp: {force_reset_temp}')
# Out:
# running aqueduct using: REMOTE_IP: 172.22.159.221 unique_id: 7d1165934e24534a1ba5 max_lvl: 101 chromatics_recipe: True force_reset_temp: False

# %%
poe_bot = Poe2Bot(unique_id = UNIQUE_ID, remote_ip = REMOTE_IP, password=password)
poe_bot.refreshAll()
# poe_bot.game_data.terrain.getCurrentlyPassableArea()
# Out:
# [Controller] establishing connection with ('172.22.159.221', 50007)
# [temp] loaded from file AfkTempData
# [temp] loaded from file StashTempData
# build is not assigned, using any functions may throw errors
# poe bot, v: 3.25.15 init at 1735292674.9842455
# [temp] loaded from file StashTempData
# [poebot] #refreshAll call at 1735292674.9872444

# %%
from utils.loot_filter import PickableItemLabel

ARTS_TO_PICK = [
  "Art/2DItems/Currency/CurrencyModValues.dds", # divine
  "Art/2DItems/Currency/CurrencyGemQuality.dds", # gemcutter
  "Art/2DItems/Currency/CurrencyRerollRare.dds", # chaos
  "Art/2DItems/Currency/CurrencyAddModToRare.dds", # exalt
  "Art/2DItems/Currency/CurrencyUpgradeToUnique.dds", # chance
]

# big piles of gold
for tier in range(2,17):
  ARTS_TO_PICK.append(f"Art/2DItems/Currency/Ruthless/CoinPileTier{tier}.dds")
# waystones
for tier in range(1,17):
  ARTS_TO_PICK.append(f"Art/2DItems/Maps/EndgameMaps/EndgameMap{tier}.dds")

# "Art/2DItems/Currency/Essence/GreaterFireEssence.dds"

def isItemHasPickableKey(item_label:PickableItemLabel):
  if item_label.icon_render in ARTS_TO_PICK:
    return True
  return False
poe_bot.loot_picker.loot_filter.special_rules = [isItemHasPickableKey]

# %%
# poe_bot.mover.setMoveType('wasd')

# %%
from utils.combat import PathfinderPoisonConc2

# poe_bot.combat_module.build = InfernalistZoomancer(poe_bot=poe_bot)
poe_bot.combat_module.build = PathfinderPoisonConc2(poe_bot=poe_bot)

def activateSwitchesNearby():
  switch_nearby = next( (e for e in poe_bot.game_data.entities.all_entities if e.is_targetable and e.path == "Metadata/Terrain/Maps/Crypt/Objects/CryptSecretDoorSwitch" and e.distance_to_player < 30), None)
  if switch_nearby:
    poe_bot.mover.goToEntitysPoint(switch_nearby)
    poe_bot.combat_module.clearAreaAroundPoint(switch_nearby.grid_position.toList())
    switch_nearby.clickTillNotTargetable()
    return True
  return False

def custom_default_continue_function(*args, **kwargs):
  pass

poe_bot.mover.default_continue_function = poe_bot.combat_module.build.usualRoutine
# Out:
# throw_flask_poison

# %%
# raise 404

# %%
# poe_bot.game_data.terrain.getCurrentlyPassableArea()

# from utils.constants import ESSENCES_KEYWORD
# essences = list(filter(lambda e: e.is_targetable is True and ESSENCES_KEYWORD in e.path and poe_bot.game_data.terrain.checkIfPointPassable(e.grid_position.x, e.grid_position.y), poe_bot.game_data.entities.all_entities))
# essences[0].id

# %%
# poe_bot.backend.getVisibleLabels()

# %%
# raise 404

# %%
from utils.encounters import EssenceEncounter
from utils.constants import ESSENCES_KEYWORD

rares_detection_radius = 999



def seekForEssences(search_loc = None):
  '''
  search_loc: [gridx,gridy]
  '''
  essences = list(filter(lambda e: e.is_targetable is True and ESSENCES_KEYWORD in e.path and poe_bot.game_data.terrain.checkIfPointPassable(e.grid_position.x, e.grid_position.y), poe_bot.game_data.entities.all_entities))
  return essences

def runnerBreakFunction(*args, **kwargs):

  '''crypt map'''
  if activateSwitchesNearby() == True:
    return True
  '''crypt map'''

  if rares_detection_radius != 0:
    rares_nearby = list(filter(lambda e: e.distance_to_player < rares_detection_radius, poe_bot.game_data.entities.attackable_entities_rares))
    for rare_mob in rares_nearby:
      updated_entity = list(filter(lambda e: e.id == rare_mob.id, poe_bot.game_data.entities.attackable_entities_rares))
      if len(updated_entity) != 0:
        updated_entity = updated_entity[0]
        def custom_continue_func(*args, **kwargs):
          if activateSwitchesNearby() == True:
            return True
          if poe_bot.loot_picker.collectLoot() == True:
            return True
          return False
        while True:
          res = poe_bot.mover.goToEntitysPoint(updated_entity,custom_break_function=custom_continue_func, min_distance=50)
          if res is None:
            break
        poe_bot.combat_module.killTillCorpseOrDisappeared(updated_entity)
        return True
  essences = seekForEssences()
  if len(essences) != 0:
    essence_encounter = EssenceEncounter(poe_bot, essences[0])
    essence_encounter.doEncounter()
    poe_bot.loot_picker.collectLoot()
    return True

  loot_collected = poe_bot.loot_picker.collectLoot()
  if loot_collected is True:
    return loot_collected
  return False

# %%
# raise 404
poe_bot.refreshAll()
# Out:
# [poebot] #refreshAll call at 1735292675.3063936

# %%
prefer_high_tier = True
alch_map_if_possible = True

# free inventory if neededS
poe_bot.ui.inventory.update()
empty_slots = poe_bot.ui.inventory.getEmptySlots()
if len(empty_slots) < 40:
  poe_bot.ui.stash.open()
  items_to_keep = []
  poe_bot.ui.inventory.update()
  waystones_to_keep = list(filter(lambda i: i.map_tier, poe_bot.ui.inventory.items))
  waystones_to_keep.sort(key=lambda i: i.map_tier, reverse=prefer_high_tier)
  items_to_keep.extend(waystones_to_keep[:4])
  alchemy_orbs = list(filter(lambda i: i.name == "Orb of Alchemy", poe_bot.ui.inventory.items))
  items_to_keep.extend(alchemy_orbs[:1])
  items_can_stash = list(filter(lambda i: i not in items_to_keep, poe_bot.ui.inventory.items))
  poe_bot.ui.clickMultipleItems(items_can_stash)
  poe_bot.ui.closeAll()
  time.sleep(random.uniform(0.3, 1.4))

# open map device
poe_bot.refreshInstanceData()
map_device_entity = next( (e for e in poe_bot.game_data.entities.all_entities if e.path == "Metadata/Terrain/Missions/Hideouts/Objects/MapDeviceVariants/ZigguratMapDevice"), None)
map_device_entity.hover()
poe_bot.refreshInstanceData()
map_device_entity = next( (e for e in poe_bot.game_data.entities.all_entities if e.path == "Metadata/Terrain/Missions/Hideouts/Objects/MapDeviceVariants/ZigguratMapDevice"), None)
if map_device_entity.is_targeted == True:
  print('targeted')
  map_device_entity.click()
  _i = 0
  while True:
    _i += 1
    if _i == 100:
      poe_bot.raiseLongSleepException('cannot open map device')

    poe_bot.ui.map_device.update()
    if poe_bot.ui.map_device.is_opened == True:
      break
    time.sleep(random.uniform(1.3, 1.4))
  time.sleep(random.uniform(1.3, 1.4))
else:
  poe_bot.raiseLongSleepException("couldnt target map device, restart or debug")
# move to map, open dropdown
poe_bot.ui.map_device.update()
possible_to_run_maps = list(filter(lambda m: 
  m.is_boss == False and # some bosses have unique logic?
  m.is_tower == False and# cant run tower maps yet
  m.name_raw != 'MapAugury_NoBoss' # activators
, poe_bot.ui.map_device.avaliable_maps))
map_obj = random.choice(possible_to_run_maps)
print(map_obj.raw)
poe_bot.ui.map_device.moveScreenTo(map_obj)
time.sleep(random.uniform(0.15, 0.35))


poe_bot.ui.map_device.update()
for i in range(3):
  updated_map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == map_obj.id))
  time.sleep(random.uniform(0.15, 0.35))
  updated_map_obj.hover()
  time.sleep(random.uniform(0.15, 0.35))
  updated_map_obj.click(hover=False)
  time.sleep(random.uniform(0.15, 0.35))
  poe_bot.ui.map_device.update()

  if poe_bot.ui.map_device.place_map_window_opened == True:
    break
if poe_bot.ui.map_device.place_map_window_opened != True:
  poe_bot.raiseLongSleepException("cant open dropdown for map device")
# Out:
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=932&y=358&mtm=-1&msm=1 at 1735292675.5769048
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=932&y=358&mtm=-1&msm=1 at 1735292675.651208
# targeted
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=932&y=358&mtm=-1&msm=1&wtr=1& at 1735292675.7772007
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=932&y=358&mtm=-1&msm=1&wtr=1& at 1735292675.7792053
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735292675.780205
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735292675.8534553
# [Controller] debug sending action=mouseRelease&button=left at 1735292675.9700963
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735292675.9710972
# {'sz': [1341, 1370, -316, -287], 'id': 21, 'name': 'Deserted', 'name_raw': 'MapDeserted_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}
# going to drag to 21
# {'sz': [1341, 1370, -316, -287], 'id': 21, 'name': 'Deserted', 'name_raw': 'MapDeserted_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}
# roi borders [397, 597, 149, 449]
# borders [25, 969, 80, 618]
# map_obj.screen_pos [1355, -301]
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=1139&y=136&mtm=-1&msm=1 at 1735292679.1364899
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=1139&y=136&mtm=-1&msm=1 at 1735292679.234044
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735292679.5006244
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735292679.512629
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=764&y=440&mtm=-1&msm=1 at 1735292679.7062588
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=764&y=440&mtm=-1&msm=1 at 1735292679.83826
# [Controller] debug sending action=mouseRelease&button=left at 1735292680.0844598
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735292680.0864663
# {'sz': [1016, 1045, -157, -129], 'id': 21, 'name': 'Deserted', 'name_raw': 'MapDeserted_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}
# roi borders [397, 597, 149, 449]
# borders [25, 969, 80, 618]
# map_obj.screen_pos [1030, -143]
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=1062&y=136&mtm=-1&msm=1 at 1735292680.5547128
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=1062&y=136&mtm=-1&msm=1 at 1735292680.687715
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735292681.0337174
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735292681.0517173
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=764&y=440&mtm=-1&msm=1 at 1735292681.3633163
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=764&y=440&mtm=-1&msm=1 at 1735292681.479899
# [Controller] debug sending action=mouseRelease&button=left at 1735292681.7588916
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735292681.7599123
# {'sz': [727, 755, 24, 53], 'id': 21, 'name': 'Deserted', 'name_raw': 'MapDeserted_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}
# roi borders [397, 597, 149, 449]
# borders [25, 969, 80, 618]
# map_obj.screen_pos [741, 38]
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=965&y=136&mtm=-1&msm=1 at 1735292682.3485222
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=965&y=136&mtm=-1&msm=1 at 1735292682.456137
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735292682.832133
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735292682.845133
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=764&y=440&mtm=-1&msm=1 at 1735292683.210757
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=764&y=440&mtm=-1&msm=1 at 1735292683.317763
# [Controller] debug sending action=mouseRelease&button=left at 1735292683.6996071
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735292683.7006216
# {'sz': [505, 534, 238, 267], 'id': 21, 'name': 'Deserted', 'name_raw': 'MapDeserted_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}
# roi borders [397, 597, 149, 449]
# borders [25, 969, 80, 618]
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=771&y=308&mtm=-1&msm=1 at 1735292684.6338313
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=771&y=308&mtm=-1&msm=1 at 1735292684.7038367
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735292684.995251
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735292685.0272508
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=771&y=308&mtm=-1&msm=1 at 1735292685.0272508
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=771&y=308&mtm=-1&msm=1 at 1735292685.0772507
# [Controller] debug sending action=mouseRelease&button=left at 1735292685.0772507
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735292685.0782504

# %%
# screen_pos_x, screen_pos_y = poe_bot.game_window.center_point
# pos_x, pos_y = poe_bot.game_window.convertPosXY(screen_pos_x, screen_pos_y)
# poe_bot.bot_controls.mouse.setPos(pos_x, pos_y)


# poe_bot.ui.map_device.update()
# updated_map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == map_obj.id))

# screen_pos_x, screen_pos_y = updated_map_obj.screen_pos.toList()
# pos_x, pos_y = poe_bot.game_window.convertPosXY(screen_pos_x, screen_pos_y)
# # poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
# poe_bot.bot_controls.mouse.setPos(pos_x, pos_y)

# %%
poe_bot.ui.inventory.update()
maps_in_inventory = list(filter(lambda i: i.map_tier, poe_bot.ui.inventory.items))
maps_in_inventory.sort(key=lambda i: i.map_tier, reverse=prefer_high_tier)
map_to_run = maps_in_inventory[0]
print(f'placing map {map_to_run.raw}')

if alch_map_if_possible == True:
  ARTS_TO_PICK.append("Art/2DItems/Currency/CurrencyUpgradeToRare.dds")
  for _i in range(1):
    if map_to_run.rarity != "Normal":
      break
    alchemy_orbs = list(filter(lambda i: i.name == "Orb of Alchemy", poe_bot.ui.inventory.items))
    if len(alchemy_orbs) == 0:
      break
    alchemy_orb = alchemy_orbs[0]
    alchemy_orb.click(button="right")
    time.sleep(random.uniform(0.4, 1.2))
    map_to_run.click()
    time.sleep(random.uniform(0.8, 1.2))

map_to_run.click(hold_ctrl=True)
poe_bot.ui.map_device.update()
#TODO sometimes activate button is outside roi
poe_bot.ui.map_device.checkIfActivateButtonIsActive()
# Out:
# placing map {'l': None, 'tt': None, 'Name': 'Waystone (Tier 9)', 'a': 'Art/2DItems/Maps/EndgameMaps/EndgameMap9.dds', 'unique_name': '', 'rarity': 'Magic', 'Class': None, 'ItemType': None, 'm_t': 9, 'c': 0, 'i': 0, 'RenderArt': 'Metadata/Items/Maps/MapKeyTier9', 'items_in_stack': 0, 'item_mods': [], 'imr': ['MapMonsterSpeedIncrease2'], 'g': [3, 4, 0, 1], 's': [675, 712, 420, 457], 'ti': 0, 'LocationTopLeft': None, 'LocationBottomRight': None, 'TopLeft': None, 'BottomRight': None}
# [Controller] debug sending action=keyboard_pressKey&button_code=DIK_LCONTROL at 1735292685.4955041
# [Controller] debug recieved response for action=keyboard_pressKey&button_code=DIK_LCONTROL at 1735292685.4955041
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=943&y=482&mtm=-1&msm=1 at 1735292685.4964883
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=943&y=482&mtm=-1&msm=1 at 1735292685.5944915
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735292685.8285058
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735292685.8484912
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=950&y=503&mtm=-1&msm=1 at 1735292685.8484912
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=950&y=503&mtm=-1&msm=1 at 1735292685.8884926
# [Controller] debug sending action=mouseRelease&button=left at 1735292685.8884926
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735292685.8884926
# [Controller] debug sending action=keyboard_releaseKey&button_code=DIK_LCONTROL at 1735292685.9405067
# [Controller] debug recieved response for action=keyboard_releaseKey&button_code=DIK_LCONTROL at 1735292685.9414923
# [Controller] debug sending action=getPartialScreen&x1=252&y1=56&x2=1276&y2=824& at 1735292686.2034388
# [Controller] data_size_raw b'\x00$\x15\xa8'
# [Controller] data_size 2364840
# activate_button_is_active True
# True

# %%
poe_bot.ui.map_device.activate()

time.sleep(random.uniform(0.8, 1.6))
poe_bot.helper_functions.waitForNewPortals()

poe_bot.refreshInstanceData()
try:
  poe_bot.helper_functions.getToPortal(check_for_map_device=False)
except Exception as e:
  if e.__str__() == 'Portal is too far away':
    print(f'portal became too far away')
    original_area_name = poe_bot.game_data.area_raw_name
    _i = 0
    while True:
      _i += 1
      if _i == 100:
        poe_bot.raiseLongSleepException('coudlnt get to portal')
      poe_bot.refreshAll()
      
      if poe_bot.game_data.area_raw_name != original_area_name:
        break

  else:
    print(e.__str__())
    raise Exception('smth happened on getToPortal')
# Out:
# [Controller] debug sending action=getPartialScreen&x1=252&y1=56&x2=1276&y2=824& at 1735292686.5191243
# [Controller] data_size_raw b'\x00$\x15\xa8'
# [Controller] data_size 2364840
# activate_button_is_active True
# activate button pos (686, 545)
# activate button pos <utils.components.Posx1x2y1y2 object at 0x0000017AB80BFE50>
# activate button pos {'ap_o': True, 'wm_o': True, 'av_m': [{'sz': [-1182, -1153, 1421, 1450], 'id': 147, 'name': 'Hidden Grotto', 'name_raw': 'MapHiddenGrotto_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentExpedition.dds']}, {'sz': [-1459, -1430, 905, 933], 'id': 225, 'name': 'Seepage', 'name_raw': 'MapSeepage_NoBoss', 'icons': []}, {'sz': [-1004, -976, 1547, 1576], 'id': 141, 'name': 'Riverside', 'name_raw': 'MapRiverside_NoBoss', 'icons': []}, {'sz': [-1204, -1175, 1164, 1193], 'id': 157, 'name': 'Savannah', 'name_raw': 'MapSavanna_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}, {'sz': [-411, -382, 2121, 2150], 'id': 278, 'name': 'Fortress', 'name_raw': 'MapFortress_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentExpedition.dds']}, {'sz': [-869, -841, 1482, 1511], 'id': 137, 'name': 'Slick', 'name_raw': 'MapSlick_NoBoss', 'icons': []}, {'sz': [-1006, -970, 1104, 1183], 'id': 154, 'name': 'Lost Towers', 'name_raw': 'MapLostTowers', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}, {'sz': [-1224, -1188, 725, 804], 'id': 226, 'name': 'Lost Towers', 'name_raw': 'MapLostTowers', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}, {'sz': [-415, -386, 1899, 1928], 'id': 282, 'name': 'Abyss', 'name_raw': 'MapAbyss_NoBoss', 'icons': []}, {'sz': [41, 70, 2207, 2236], 'id': 271, 'name': 'Savannah', 'name_raw': 'MapSavanna_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentDelirium.dds']}, {'sz': [-89, -60, 2058, 2087], 'id': 274, 'name': 'Willow', 'name_raw': 'MapWillow_NoBoss', 'icons': []}, {'sz': [-719, -683, 1028, 1107], 'id': 149, 'name': 'Lost Towers', 'name_raw': 'MapLostTowers', 'icons': []}, {'sz': [435, 471, 2404, 2483], 'id': 263, 'name': 'Lost Towers', 'name_raw': 'MapLostTowers', 'icons': []}, {'sz': [-84, -55, 1664, 1693], 'id': 281, 'name': 'Seepage', 'name_raw': 'MapSeepage_NoBoss', 'icons': []}, {'sz': [-388, -359, 1317, 1346], 'id': 134, 'name': 'Deserted', 'name_raw': 'MapDeserted_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentRitual.dds']}, {'sz': [-459, -430, 1218, 1247], 'id': 139, 'name': 'Sulphuric Caverns', 'name_raw': 'MapSulphuricCaverns_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentExpedition.dds', 'Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}, {'sz': [-1079, -1050, 346, 375], 'id': 243, 'name': 'Seepage', 'name_raw': 'MapSeepage_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentDelirium.dds', 'Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}, {'sz': [-541, -513, 963, 991], 'id': 150, 'name': 'Wetlands', 'name_raw': 'MapWetlands_NoBoss', 'icons': []}, {'sz': [-717, -681, 683, 762], 'id': 161, 'name': 'Lost Towers', 'name_raw': 'MapLostTowers', 'icons': []}, {'sz': [-955, -926, 404, 433], 'id': 234, 'name': 'Vaal Factory', 'name_raw': 'MapVaalFactory_NoBoss', 'icons': []}, {'sz': [125, 154, 1629, 1658], 'id': 280, 'name': 'Steppe', 'name_raw': 'MapSteppe_NoBoss', 'icons': []}, {'sz': [-15, 12, 1483, 1512], 'id': 284, 'name': 'Crypt', 'name_raw': 'MapCrypt_NoBoss', 'icons': []}, {'sz': [-708, -679, 564, 592], 'id': 223, 'name': 'Hidden Grotto', 'name_raw': 'MapHiddenGrotto_NoBoss', 'icons': ['Art/Textures/Interface/2D/2DArt/UIImages/InGame/AtlasScreen/AtlasIconContent/AtlasIconContentCorruption.dds']}, {'sz': [266, 302, 1651, 1730], 'id': 276, 'name': 'Lost Towers', 'name_raw': 'M ...
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=686&y=545&mtm=-1&msm=3 at 1735292686.5551503
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=686&y=545&mtm=-1&msm=3 at 1735292686.7701266
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735292686.8821406
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735292686.8881295
# [Controller] debug sending action=mouseRelease&button=left at 1735292687.0411284
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735292687.0461295
# #waitForNewPortals 1735292688.6289554
# checking if portals changed
# portals changed
# original_area_raw_name HideoutShrine
# portal_to_enter {'ls': [527, 301], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 53, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [373, 497], 'wp': [4080, 4373, -95], 'l': None, 'rn': 'Deserted', 'et': 'TownPortal', 'distance_to_player': 2.23606797749979}
# getting into portal {'ls': [527, 301], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 53, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [373, 497], 'wp': [4080, 4373, -95], 'l': None, 'rn': 'Deserted', 'et': 'TownPortal', 'distance_to_player': 2.23606797749979}
# 779 357
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=779&y=357&mtm=-1&msm=1 at 1735292692.091322
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=779&y=357&mtm=-1&msm=1 at 1735292692.1868978
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735292692.5924654
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735292692.605451
# [Controller] debug sending action=mouseRelease&button=left at 1735292692.7184513
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735292692.71945
# clicked on a portal {'ls': [527, 301], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 53, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [373, 497], 'wp': [4080, 4373, -95], 'l': None, 'rn': 'Deserted', 'et': 'TownPortal', 'distance_to_player': 2.23606797749979}
# portal_to_enter {'ls': [527, 301], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 53, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [373, 497], 'wp': [4080, 4373, -95], 'l': None, 'rn': 'Deserted', 'et': 'TownPortal', 'distance_to_player': 2.23606797749979}
# getting into portal {'ls': [527, 301], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 53, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [373, 497], 'wp': [4080, 4373, -95], 'l': None, 'rn': 'Deserted', 'et': 'TownPortal', 'distance_to_player': 2.23606797749979}
# 779 357
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=779&y=357&mtm=-1&msm=1 at 1735292694.3192158
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=779&y=357&mtm=-1&msm=1 at 1735292694.3632188
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735292694.770817
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735292694.7918158
# [Controller] debug sending action=mouseRelease&button=left at 1735292694.927814
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735292694.9288132
# clicked on a portal {'ls': [527, 301], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 53, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [373, 497], 'wp': [4080, 4373, -95], 'l': None, 'rn': 'Deserted', 'et': 'TownPortal', 'distance_to_player': 2.23606797749979}
# portal_to_enter {'ls': [527, 301], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 53, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [373, 497], 'wp': [4080, 4373, -95], 'l': None, 'rn': 'Deserted', 'et': 'TownPortal', 'distance_to_player': 2.23606797749979}
# getting into portal {'ls': [527, 301], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 53, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [373, 497], 'wp': [4080, 4373, -95], 'l': None, 'rn': 'Deserted', 'et': 'TownPortal', 'distance_to_player': 2.23606797749979}
# 779 357
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=779&y=357&mtm=-1&msm=1 at 1735292695.5809982
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=779&y=357&mtm=-1&msm=1 at 1735292695.6160028
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735292696.0303366
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735292696.0503333
# [Controller] debug sending action=mouseRelease&button=left at 1735292696.2039936
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735292696.208993
# clicked on a portal {'ls': [527, 301], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 53, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [373, 497], 'wp': [4080, 4373, -95], 'l': None, 'rn': 'Deserted', 'et': 'TownPortal', 'distance_to_player': 2.23606797749979}
# [Controller] debug sending action=releaseAll at 1735292697.8348057
# [Controller] debug recieved response for action=releaseAll at 1735292697.8368094
# Area changed but refreshInstanceData was called before refreshAll
# [poebot] #refreshAll call at 1735292697.8368094
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=328&y=116&mtm=-1&msm=1 at 1735292698.7157457
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=328&y=116&mtm=-1&msm=1 at 1735292698.860753

# %%
# raise 404

# %%
from utils.pathing import TSP


tsp = TSP(poe_bot=poe_bot)
# tsp.generatePointsForDiscovery()
mover = poe_bot.mover
map_complete = False
while map_complete is False:
  poe_bot.refreshInstanceData()
  print(f'generating pathing points')
  tsp.generatePointsForDiscovery()
  #TODO astar sorting
  discovery_points = tsp.sortedPointsForDiscovery()
  print(f'len(discovery_points) {len(discovery_points)}')
  discovery_points = list(filter(lambda p: poe_bot.game_data.terrain.checkIfPointPassable(p[0], p[1]), discovery_points))
  print(f'len(discovery_points) {len(discovery_points)} after sorting')
  print(f'discovery_points {discovery_points}')
  if len(discovery_points) == 0:
    print(f'len(discovery_points) == 0 after points generation')
    map_complete = True
    break
  point_to_go = discovery_points.pop(0)
  while point_to_go is not None:
    need_to_explore = poe_bot.helper_functions.needToExplore(point_to_go=point_to_go)
    if need_to_explore is True:
      print(f'exploring point {point_to_go}')
    else:
      print(f'surrounding around {point_to_go} discovered, skipping')
      try:
        point_to_go = discovery_points.pop(0)
      except:
        point_to_go = None
      continue

    # go to point to make it explored
    result = mover.goToPoint(
      point=point_to_go,
      min_distance=50,
      release_mouse_on_end=False,
      custom_break_function=runnerBreakFunction,
      step_size=random.randint(30,35)
    )
    # then, it result is True, False or None
    print(f"mover.goToPoint result {result}")


    # if we arrived to discovery point and nothing happened
    if result is None:
      while True:
        if len(discovery_points) == 0:
          point_to_go = None
          map_complete = True
          print(f'len(discovery_points) == 0, breaking')
          break

        point_to_go = discovery_points.pop(0)
        print(f'willing to explore next point {point_to_go}')
        need_to_explore = poe_bot.helper_functions.needToExplore(point_to_go=point_to_go)

        if need_to_explore is True:
          print(f'exploring point {point_to_go}')
          break
        else:
          print(f'surrounding around {point_to_go} discovered, skipping')
          continue
    
    # if explorer_break_function() is True:
    #   map_complete = True
    #   break

    poe_bot.refreshInstanceData()
    poe_bot.last_action_time = 0
  # if possible_transition to explore, go to it, run discovery again
# Out:
# generating pathing points
# 1735292698.9927475
# len(discovery_points) 34
# len(discovery_points) 34 after sorting
# discovery_points [(1176, 2670), (1171, 2454), (1011, 2384), (1007, 2216), (1139, 2105), (997, 1980), (1032, 1747), (878, 1562), (725, 1653), (725, 1460), (574, 1246), (723, 1160), (794, 1001), (962, 1002), (926, 1277), (1014, 1444), (1165, 1227), (1297, 1459), (1464, 1526), (1553, 1669), (1450, 1863), (1265, 1908), (1266, 1657), (750, 1896), (792, 2130), (844, 2363), (693, 2516), (733, 2682), (930, 2665), (1311, 2278), (561, 976), (575, 765), (730, 838), (576, 584)]
# exploring point (1176, 2670)
# #goToPoint point: (1176, 2670), min_distance: 50, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: True, random_val: 1
# custom_break_function:<function runnerBreakFunction at 0x0000017AB8417550>, custom_continue_function:None
# heist_transition: False, step_size: 33possible_transition: False
# [LootPicker.collectLoot] call at 1735292701.7398245
# end pos to go 1176 2671
# [Mover] distance_to_target: 100.9752444909147 at 1735292701.7856777
# [LootPicker.collectLoot] call at 1735292701.7856777
# [Mover] making step to (540, 673)
# [Mover] making first step, placing a mouse on (540, 673) and going
# [Controller] debug sending action=mouseSetCursorPosSmooth&x
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=651&y=268&mtm=-1&msm=1&wtr=1& at 1735292712.6352043
# [Mover] distance_to_target: 136.0 at 1735292712.7732015
# [LootPicker.collectLoot] call at 1735292712.7772024
# calling usual routine
# removing explosion zone 1735292708.775541 with [1013.25, 1043.25, 2574.0, 2604.0] , expired
# nearby_enemies: [<utils.gamehelper.Entity object at 0x0000017AB80CC9D0>, <utils.gamehelper.Entity object at 0x0000017AB80CCF10>, <utils.gamehelper.Entity object at 0x0000017AB80CC040>, <utils.gamehelper.Entity object at 0x0000017AB945A250>, <utils.gamehelper.Entity object at 0x0000017AB945ACD0>, <utils.gamehelper.Entity object at 0x0000017AB945A5E0>, <utils.gamehelper.Entity object at 0x0000017AB841BF70>, <utils.gamehelper.Entity object at 0x0000017AB841BF40>, <utils.gamehelper.Entity object at 0x0000017AB80BF040>, <utils.gamehelper.Entity object at 0x0000017AB80BFA60>, <utils.gamehelper.Entity object at 0x0000017AB80BF3A0>, <utils.gamehelper.Entity object at 0x0000017AB8099670>, <utils.gamehelper.Entity object at 0x0000017AB8099C10>]
# going to clear
# internal cd for clear 2
# [Mover] making step to (667, 286)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=667&y=286&mtm=-1&msm=1&wtr=1& at 1735292712.7832248
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=667&y=286&mtm=-1&msm=1&wtr=1& at 1735292712.784223
# [Mover] distance_to_target: 135.1332675546625 at 1735292712.9072044
# [LootPicker.collectLoot] call at 1735292712.9122043
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x0000017AB9453AC0>, <utils.gamehelper.Entity object at 0x0000017AB9453B80>, <utils.gamehelper.Entity object at 0x0000017AB9453610>, <utils.gamehelper.Entity object at 0x0000017AB9459790>, <utils.gamehelper.Entity object at 0x0000017AB9459AC0>, <utils.gamehelper.Entity object at 0x0000017AB9459A60>, <utils.gamehelper.Entity object at 0x0000017AB80CC6A0>, <utils.gamehelper.Entity object at 0x0000017AB80CC0D0>, <utils.gamehelper.Entity object at 0x0000017AB80BF370>, <utils.gamehelper.Entity object at 0x0000017AB80BFF10>, <utils.gamehelper.Entity object at 0x0000017AB80BFA30>, <utils.gamehelper.Entity object at 0x0000017AB80BF400>, <utils.gamehelper.Entity object at 0x0000017AB8424F10>, <utils.gamehelper.Entity object at 0x0000017AB8441190>]
# going to clear
# internal cd for clear 2
# [Mover] making step to (684, 297)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=684&y=297&mtm=-1&msm=1&wtr=1& at 1735292712.9172027
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=684&y=297&mtm=-1&msm=1&wtr=1& at 1735292712.9262064
# [Mover] distance_to_target: 133.37541002748594 at 1735292713.0482047
# [LootPicker.collectLoot] call at 1735292713.0542045
# calling usual routine
# nearby_enemies: [<utils.gamehelper.Entity object at 0x0000017AB945A670>, <utils.gamehelper.Entity object at 0x0000017AB841B580>, <utils.gamehelper.Entity object at 0x0000017AB841BCD0>, <utils.gamehelper.Entity object at 0x0000017AB841B2B0>, <utils.gamehelper.Entity object at 0x0000017AB841BA90>, <utils.gamehelper.Entity object at 0x0000017AB80EE700>, <utils.gamehelper.Entity object at 0x0000017AB80EE5E0>, <utils.gamehelper.Entity object at 0x0000017AB80EED30>, <utils.gamehelper.Entity object at 0x0000017AB80BFD90>, <utils.gamehelper.Entity object at 0x0000017AB80BF730>, <utils.gamehelper.Entity object at 0x0000017AB80D4B20>, <utils.gamehelper.Entity object at 0x0000017AB80D4940>]
# going to clear
# internal cd for clear 2
# [Mover] making step to (704, 322)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=704&y=322&mtm=-1&msm=1&wtr=1& at 1735292713.0612042
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=1011&y=209&mtm=-1&msm=1&wtr=1& at 1735293119.4508762
# [Mover] distance_to_target: 244.7733645640391 at 1735293119.583882
# [LootPicker.collectLoot] call at 1735293119.583882
# calling usual routine
# nearby_enemies: []
# [Mover] making step to (1001, 210)
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=1001&y=210&mtm=-1&msm=1&wtr=1& at 1735293119.5898795
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=1001&y=210&mtm=-1&msm=1&wtr=1& at 1735293119.5908773

# %%
# open portal and enter it
def openPortal():
  poe_bot.bot_controls.releaseAll()

  time.sleep(random.randint(40,80)/100)
  pos_x, pos_y = random.randint(709,711), random.randint(694,696)
  pos_x, pos_y = poe_bot.convertPosXY(pos_x, pos_y, safe=False)
  poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
  time.sleep(random.randint(40,80)/100)
  poe_bot.bot_controls.mouse.click()
  time.sleep(random.randint(30,60)/100)

while True:
  try:
    poe_bot.refreshInstanceData()
    killed_smth = poe_bot.combat_module.clearAreaAroundPoint(poe_bot.game_data.player.grid_pos.toList())
    if killed_smth == False:
      openPortal()
      poe_bot.helper_functions.waitForPortalNearby()
      poe_bot.helper_functions.getToPortal(check_for_map_device=False, refresh_area=False)
      poe_bot.refreshInstanceData()
      killed_smth = poe_bot.combat_module.clearAreaAroundPoint(poe_bot.game_data.player.grid_pos.toList())
      if killed_smth:
        continue
  except Exception as e:
    if e.__str__() == 'Area changed but refreshInstanceData was called before refreshAll':
      time.sleep(5)
      break
# Out:
# #clearLocationAroundPoint around point {'X': 1304, 'Y': 1329} ignore_keys: []
# going to {'X': 1304, 'Y': 1329}
# #goToPoint point: [1304, 1329], min_distance: 40, release_mouse_on_end:False, release_mouse_on_start:False
# randomize_grid_pos_to_go: True, random_val: 1
# custom_break_function:<function alwaysFalseFunction at 0x000001E838B70790>, custom_continue_function:<bound method PathfinderPoisonConc2.usualRoutine of <utils.combat.PathfinderPoisonConc2 object at 0x000001E8398A4EE0>>
# heist_transition: False, step_size: 28possible_transition: False
# end pos to go 1305 1330
# useless call of gotopoint arrived = True
# [Controller] debug sending action=releaseAll at 1735282504.0698354
# [Controller] debug recieved response for action=releaseAll at 1735282504.0718353
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=900&y=733&mtm=-1&msm=1 at 1735282504.7412848
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=900&y=733&mtm=-1&msm=1 at 1735282504.824289
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735282505.5370674
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735282505.5690606
# [Controller] debug sending action=mouseRelease&button=left at 1735282505.7230818
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735282505.7240658
# #waitForNewPortals 1735282506.2686687
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# checking if portals around
# there is a portal nearby
# original_area_raw_name MapSpiderWoods_NoBoss
# portal_to_enter {'ls': [511, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 2, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1306, 1373], 'wp': [14221, 3852, -95], 'l': None, 'rn': 'Shrine Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# getting into portal {'ls': [511, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 2, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1306, 1373], 'wp': [14221, 3852, -95], 'l': None, 'rn': 'Shrine Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# 701 336
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=701&y=336&mtm=-1&msm=1 at 1735282507.665034
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=701&y=336&mtm=-1&msm=1 at 1735282507.8095849
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735282508.2191818
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735282508.2401772
# [Controller] debug sending action=mouseRelease&button=left at 1735282508.3941953
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735282508.3951783
# clicked on a portal {'ls': [511, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 2, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1306, 1373], 'wp': [14221, 3852, -95], 'l': None, 'rn': 'Shrine Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# portal_to_enter {'ls': [511, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 2, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [1306, 1373], 'wp': [14221, 3852, -95], 'l': None, 'rn': 'Shrine Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# getting into portal {'ls': [511, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 2, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [1306, 1373], 'wp': [14221, 3852, -95], 'l': None, 'rn': 'Shrine Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# 701 336
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=701&y=336&mtm=-1&msm=1 at 1735282509.2355018
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=701&y=336&mtm=-1&msm=1 at 1735282509.2735062
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735282509.6853342
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735282509.7193313
# [Controller] debug sending action=mouseRelease&button=left at 1735282509.8283448
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735282509.8293478
# clicked on a portal {'ls': [511, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 2, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 1, 'em': 0, 'b': 1, 'gp': [1306, 1373], 'wp': [14221, 3852, -95], 'l': None, 'rn': 'Shrine Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# portal_to_enter {'ls': [511, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 2, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1306, 1373], 'wp': [14221, 3852, -95], 'l': None, 'rn': 'Shrine Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# getting into portal {'ls': [511, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 2, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1306, 1373], 'wp': [14221, 3852, -95], 'l': None, 'rn': 'Shrine Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# 701 336
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=701&y=336&mtm=-1&msm=1 at 1735282510.960541
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=701&y=336&mtm=-1&msm=1 at 1735282510.996537
# [Controller] debug sending action=mousePress&x=-1&y=-1&button=left at 1735282511.4077737
# [Controller] debug recieved response for action=mousePress&x=-1&y=-1&button=left at 1735282511.4387734
# [Controller] debug sending action=mouseRelease&button=left at 1735282511.5655766
# [Controller] debug recieved response for action=mouseRelease&button=left at 1735282511.5665574
# clicked on a portal {'ls': [511, 298], 'p': 'Metadata/MiscellaneousObjects/MultiplexPortal', 'r': 'White', 'i': 2, 'o': 0, 'h': 1, 'ia': 0, 't': 1, 'it': 0, 'em': 0, 'b': 1, 'gp': [1306, 1373], 'wp': [14221, 3852, -95], 'l': None, 'rn': 'Shrine Hideout', 'et': 'TownPortal', 'distance_to_player': 0.0}
# [Controller] debug sending action=releaseAll at 1735282512.2101521
# [Controller] debug recieved response for action=releaseAll at 1735282512.2121413
# Area changed but refreshInstanceData was called before refreshAll
# [Controller] debug sending action=mouseSetCursorPosSmooth&x=266&y=98&mtm=-1&msm=1 at 1735282512.2121413
# [Controller] debug recieved response for action=mouseSetCursorPosSmooth&x=266&y=98&mtm=-1&msm=1 at 1735282512.3451352
# [Controller] debug sending action=releaseAll at 1735282512.3601348
# [Controller] debug recieved response for action=releaseAll at 1735282512.3611348

# %%
raise 404
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 raise 404
#
# TypeError: exceptions must derive from BaseException

# %%
prefer_high_tier = True

# %%
poe_bot.refreshAll()

# %%
# pos_x, pos_y = random.randint(580,640), random.randint(408,409)
# pos_x, pos_y = poe_bot.convertPosXY(pos_x, pos_y)
# time.sleep(random.randint(20,80)/100)
# poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
# time.sleep(random.randint(20,80)/100)
# poe_bot.bot_controls.mouse.click()
# time.sleep(random.randint(30,60)/100)

# %%
start_time = time.time()

def destroyCorpse(corpse_entity:Entity):
  print(f'destroying corpse {corpse_entity.raw}')
  while True:
    poe_bot.refreshInstanceData()
    updated_corpse_entity = next( (e for e in poe_bot.game_data.entities.all_entities if e.id == corpse_entity.id), None)
    if updated_corpse_entity:
      if updated_corpse_entity.distance_to_player > 25:
        poe_bot.mover.goToEntitysPoint(updated_corpse_entity)
      else:
        if poe_bot.combat_module.build.detonate_dead:
          if poe_bot.combat_module.build.detonate_dead.use(updated_entity=updated_corpse_entity, force=True) != False:
            continue
        if poe_bot.combat_module.build.unearth and poe_bot.combat_module.build.unearth.canUse():
          if poe_bot.combat_module.build.unearth.use(updated_entity=updated_corpse_entity) != False:
            continue
    else:
      break
beetle_corpse = next( (e for e in poe_bot.game_data.entities.all_entities if e.render_name == "The Ninth Treasure of Keth"), None)
if beetle_corpse:
  destroyCorpse(beetle_corpse)

# %%
entity_to_run_around = None
if beetle_corpse:
  print(f'running around corpse {beetle_corpse}')
  entity_to_run_around = beetle_corpse
elif beetle_entity:
  print(f'running around entity {beetle_entity}')

  entity_to_run_around = beetle_entity

if entity_to_run_around:
  start_time = time.time()
  run_duration_seconds = 5
  end_at = start_time + run_duration_seconds
  kite_distance = 10
  reversed_run = random.choice([True, False])
  while time.time() < end_at:
    poe_bot.refreshInstanceData()
    poe_bot.combat_module.build.auto_flasks.useFlasks()  
    print('kiting')
    point = poe_bot.game_data.terrain.pointToRunAround(entity_to_run_around.grid_position.x, entity_to_run_around.grid_position.y, kite_distance+random.randint(-1,1), check_if_passable=True, reversed=reversed_run)
    poe_bot.mover.move(grid_pos_x = point[0], grid_pos_y = point[1])
else:
  poe_bot.refreshInstanceData()

# %%
poe_bot.loot_picker.collectLootWhilePresented()

# %%
def respawnAtCheckPoint():
  poe_bot.bot_controls.keyboard.tap('DIK_ESCAPE')
  time.sleep(random.randint(40,80)/100)
  pos_x, pos_y = random.randint(450,550), random.randint(289,290)
  pos_x, pos_y = poe_bot.convertPosXY(pos_x, pos_y)
  poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
  time.sleep(random.randint(40,80)/100)
  poe_bot.bot_controls.mouse.click()
  time.sleep(random.randint(30,60)/100)

  pos_x, pos_y = random.randint(580,640), random.randint(408,409)
  pos_x, pos_y = poe_bot.convertPosXY(pos_x, pos_y)
  time.sleep(random.randint(20,80)/100)
  poe_bot.bot_controls.mouse.setPosSmooth(pos_x, pos_y)
  time.sleep(random.randint(20,80)/100)
  poe_bot.bot_controls.mouse.click()
  time.sleep(random.randint(30,60)/100)
  return True
poe_bot.bot_controls.releaseAll()
respawnAtCheckPoint()
while True:
  poe_bot.refreshInstanceData()
  beetle_entity = next( (e for e in poe_bot.game_data.entities.all_entities if e.render_name == "The Ninth Treasure of Keth"), None)
  if beetle_entity:
    break

# %%
raise 404

# %%
poe_bot.refreshInstanceData()
poe_bot.loot_picker.collectLoot()

# %%
from utils.utils import getAngle

# %%
poe_bot.refreshAll()

# %%
poe_bot.refreshInstanceData()
map_device_entity = next( (e for e in poe_bot.game_data.entities.all_entities if e.path == "Metadata/Terrain/Missions/Hideouts/Objects/MapDeviceVariants/ZigguratMapDevice"), None)
map_device_entity.hover()
poe_bot.refreshInstanceData()
map_device_entity = next( (e for e in poe_bot.game_data.entities.all_entities if e.path == "Metadata/Terrain/Missions/Hideouts/Objects/MapDeviceVariants/ZigguratMapDevice"), None)
if map_device_entity.is_targeted == True:
  print('targeted')
  map_device_entity.click()

# %%
import time
while True:
  time.sleep(0.2)
  poe_bot.refreshInstanceData()
  player_pos = poe_bot.game_data.player.grid_pos.toList()
  p1 = player_pos
  p0 = (player_pos[0], player_pos[1]+50)

  for e in poe_bot.game_data.entities.all_entities:
    if e.id != 11:
      continue
    print(e.raw)
    print(getAngle(p0, p1, (e.grid_position.x, e.grid_position.y), abs_180=True))

# %%
poe_bot.refreshAll()
poe_bot.bot_controls.releaseAll()

our_pos = [poe_bot.game_data.player.grid_pos.x, poe_bot.game_data.player.grid_pos.y]
# entity pos
pos_x, pos_y = poe_bot.game_data.player.grid_pos.x, poe_bot.game_data.player.grid_pos.y

distance_to_point = 45

reversed = True
check_if_passable = True

# %%
import time
from math import dist

while True:
  time.sleep(0.2)
  poe_bot.refreshInstanceData()

  our_pos = [poe_bot.game_data.player.grid_pos.x, poe_bot.game_data.player.grid_pos.y]
  points_around = [
    [pos_x+distance_to_point,pos_y], # 90
    [int(pos_x+distance_to_point*0.7),int(pos_y-distance_to_point*0.7)], # 45
    [pos_x,pos_y-distance_to_point], # 0
    [int(pos_x-distance_to_point*0.7),int(pos_y-distance_to_point*0.7)], # 315
    [pos_x-distance_to_point,pos_y], # 270
    [int(pos_x-distance_to_point*0.7),int(pos_y+distance_to_point*0.7)], # 215
    [pos_x,pos_y+distance_to_point], # 180
    [int(pos_x+distance_to_point*0.7),int(pos_y+distance_to_point*0.7)], # 135
  ]
  if reversed is True:
    points_around.reverse()
  distances = list(map(lambda p: dist(our_pos, p),points_around))
  nearset_pos_index = distances.index(min(distances))
  distances = list(map(lambda p: dist(our_pos, p),points_around))
  nearset_pos_index = distances.index(min(distances))
  # TODO check if next point is passable
  current_pos_index = nearset_pos_index+1
  if current_pos_index > len(points_around)-1: current_pos_index -= len(points_around)
  point = points_around[current_pos_index]
  if check_if_passable is True:
    if poe_bot.game_data.terrain.checkIfPointPassable(point[0], point[1], radius=1) is False:
      start_index = current_pos_index+1
      point_found = False
      for i in range(len(points_around)-2):
        current_index = start_index + i
        if current_index > len(points_around)-1: current_index -= len(points_around)
        point = points_around[current_index]
        if poe_bot.game_data.terrain.checkIfPointPassable(point[0], point[1], radius=1) is True:
          point_found = True
          break
      if point_found is True:
        pass
  print(point)
  poe_bot.mover.move(point[0], point[1])

# %%
# move back or move to safe grid if enemies on a way
# map device
poe_bot.ui.map_device.update()

# %%
from utils.ui import MapDevice_Poe2
poe_bot.ui.map_device = MapDevice_Poe2(poe_bot)
poe_bot.ui.map_device.update()

# %%
raise 404

# %%
from utils.utils import sortByHSV
x1 = poe_bot.ui.map_device.activate_button_pos.x1 +5
x2 = poe_bot.ui.map_device.activate_button_pos.x2 -5
y1 = poe_bot.ui.map_device.activate_button_pos.y1 +5
y2 = poe_bot.ui.map_device.activate_button_pos.y2 -5
game_img = poe_bot.getImage()
activate_button_img = game_img[y1:y2, x1:x2]
# print('activate_button_img')
# plt.imshow(activate_button_img);plt.show()
# plt.imshow(third_skill);plt.show()
sorted_img = sortByHSV(activate_button_img, 0, 0, 0, 255, 30, 180)
# plt.imshow(sorted_img);plt.show()
activate_button_is_active = not len(sorted_img[sorted_img != 0]) > 30
# print(sorted_img[sorted_img != 0])
print(f"activate_button_is_active {activate_button_is_active}")

# %%
x1 = poe_bot.ui.map_device.activate_button_pos.x1 +5
x2 = poe_bot.ui.map_device.activate_button_pos.x2 -5
y1 = poe_bot.ui.map_device.activate_button_pos.y1 +5
y2 = poe_bot.ui.map_device.activate_button_pos.y2 -5
game_img = poe_bot.getImage()
active_button = game_img[y1:y2, x1:x2]

# %%
x1 = poe_bot.ui.map_device.activate_button_pos.x1 +5
x2 = poe_bot.ui.map_device.activate_button_pos.x2 -5
y1 = poe_bot.ui.map_device.activate_button_pos.y1 +5
y2 = poe_bot.ui.map_device.activate_button_pos.y2 -5
game_img = poe_bot.getImage()
inactive_button = game_img[y1:y2, x1:x2]

# %%
active_sorted_img = sortByHSV(active_button, 0,0,0, 255, 30, 180)
plt.imshow(active_sorted_img);plt.show()
inactive_sorted_img = sortByHSV(inactive_button, 0,0,0, 255, 30, 180)
plt.imshow(inactive_sorted_img);plt.show()

# %%
raise 404

# %%
from utils.ui import MapDevice_Poe2
poe_bot.ui.map_device = MapDevice_Poe2(poe_bot)
poe_bot.ui.map_device.update()
map_obj = random.choice(poe_bot.ui.map_device.avaliable_maps)
print(map_obj.raw)
poe_bot.ui.map_device.moveScreenTo(map_obj)
time.sleep(random.uniform(0.15, 0.35))
poe_bot.ui.map_device.update()
updated_map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == map_obj.id))
time.sleep(random.uniform(0.15, 0.35))
updated_map_obj.hover()
time.sleep(random.uniform(0.15, 0.35))
updated_map_obj.click()

# %%
poe_bot.ui.map_device.update()
updated_map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == map_obj.id))
time.sleep(random.uniform(0.15, 0.35))
updated_map_obj.hover()
time.sleep(random.uniform(0.15, 0.35))
updated_map_obj.click()

# %%
poe_bot.ui.map_device.update()
# find a map to go
# for map_obj in poe_bot.ui.map_device.avaliable_maps[0:1]:
map_obj = random.choice(poe_bot.ui.map_device.avaliable_maps)
print(f'going to drag to {map_obj.id}')
orig_id = map_obj.id
while True:
  poe_bot.ui.map_device.update()
  if poe_bot.ui.map_device.is_opened == False:
    raise poe_bot.raiseLongSleepException('map device closed during dragging to map object')
  map_obj = next( (m for m in poe_bot.ui.map_device.avaliable_maps if m.id == orig_id))

  poe_bot.ui.inventory.update()
  x_center = poe_bot.game_window.center_point[0]
  borders = poe_bot.game_window.borders[:]
  borders[2] = 80
  if poe_bot.ui.inventory.is_opened:
    borders[1] = 545
    x_center = int(x_center)/2
  roi_borders = [
    int((borders[0] + borders[1])/2 - 100),
    int((borders[0] + borders[1])/2 + 100),
    int((borders[2] + borders[3])/2 - 150),
    int((borders[2] + borders[3])/2 + 50),
  ]

  if poe_bot.game_window.isInRoi(map_obj.screen_pos.x, map_obj.screen_pos.y, custom_borders=roi_borders):
    break
  print(f"map_obj.screen_pos {map_obj.screen_pos.toList()}")
  drag_from = poe_bot.game_window.convertPosXY(map_obj.screen_pos.x, map_obj.screen_pos.y, custom_borders=borders)
  # ignore the inventory panel if it's opened
  if poe_bot.ui.inventory.is_opened == True:
    print('inventory is opened, different borders and roi')
  drag_to = poe_bot.game_window.convertPosXY(x_center, poe_bot.game_window.center_point[1], custom_borders=borders)
  poe_bot.bot_controls.mouse.drag(drag_from, drag_to)
  time.sleep(random.uniform(0.15, 0.35))
# map_obj.click()
# time.sleep(random.uniform(0.15, 0.35))

# %%
poe_bot.refreshAll()

# %%
player_pos = poe_bot.game_data.player.grid_pos.toList()
pos_to_go = [player_pos[0]+3, player_pos[1]-50]
print(player_pos, pos_to_go)

# %%
from utils.utils import angleOfLine, pointOnCircleByAngleAndLength, createLineIteratorWithValues

def findBackwardsPoint(current_point, point_to_go):
  next_angle = angleOfLine(current_point, point_to_go)
  distance = math.dist(current_point, point_to_go)
  backwards_angle_raw = next_angle - 180
  if backwards_angle_raw < 0:
    backwards_angle_raw += 360
  if backwards_angle_raw == 360:
    backwards_angle_raw = 0
  angle_mult = backwards_angle_raw // 45
  angle_leftover = backwards_angle_raw % 45
  if angle_leftover > 22.5:
    angle_mult += 1

  backwards_angle = int(angle_mult * 45)
  if backwards_angle == 360:
    backwards_angle = 0
  backwards_angle
  backwards_angles = [backwards_angle]
  for _i in [-1,1]:
    branch = backwards_angle + 45 * _i
    if branch < 0:
      branch += 360
    if branch > 360:
      branch -= 360
    if branch == 360:
      branch = 0
    backwards_angles.append(branch)

  furthest_point = current_point
  furthest_point_distance = 0
  for angle in backwards_angles:
    line_end = pointOnCircleByAngleAndLength(angle, distance, current_point)
    line_points_vals = createLineIteratorWithValues(current_point, line_end, poe_bot.game_data.terrain.passable)
    length = 0
    last_point = line_points_vals[0]
    for point in line_points_vals:
      if point[2] != 1:
        break
      last_point = point 
      length += 1
    dist_to_last_point = math.dist(current_point, (last_point[0], last_point[1]))
    if furthest_point_distance < dist_to_last_point:
      furthest_point_distance = dist_to_last_point
      furthest_point = [int(last_point[0]), int(last_point[1])]
    print(f"angle {angle} {length}, {last_point}, {dist_to_last_point}")
  return furthest_point
findBackwardsPoint(player_pos, pos_to_go)

# %%
from utils.pathing import TSP

# %%
tsp = TSP(poe_bot)

tsp.generatePointsForDiscovery()
#TODO astar sorting
discovery_points = tsp.sortedPointsForDiscovery()

# %%
poe_bot.game_data.player.grid_pos.toList()

# %%
discovery_points
